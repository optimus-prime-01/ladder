# %%
import requests
from datetime import datetime
import pandas as pd
df=pd.read_csv('df19.csv')
import json
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1200
    target_upper = 1400

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 20 <= days_taken <= 40:
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
df.to_csv('outdf19.csv', index=False)
# Out:
# SonicML did not cross the rating margin within the specified range.
# T_For_TLE did not cross the rating margin within the specified range.
# 69iq did not cross the rating margin within the specified range.
# natyam did not cross the rating margin within the specified range.
# Failed to fetch rating history for notsofranksinatra. Status code: 503
# sksshivam007 did not cross the rating margin within the specified range.
# Hoppa did not cross the rating margin within the specified range.
# turuthok did not cross the rating margin within the specified range.
# wdjuruo did not cross the rating margin within the specified range.
# janekri did not cross the rating margin within the specified range.
# Failed to fetch rating history for 1nvince. Status code: 503
# Failed to fetch rating history for EvenToWorldFinal. Status code: 502
# Failed to fetch rating history for Iura_Shch. Status code: 502
# Failed to fetch rating history for JKJeong. Status code: 502
# Failed to fetch rating history for Sayleyd. Status code: 502
# Failed to fetch rating history for Shadow___Monarch. Status code: 502
# Failed to fetch rating history for Vik_555. Status code: 502
# Failed to fetch rating history for Xbir. Status code: 502
# Failed to fetch rating history for ayushsahu_123. Status code: 502
# Failed to fetch rating history for clemenceparis. Status code: 502
# mamodul-kabir did not cross the rating margin within the specified range.
# Ahnaf.Shahriar.Asif did not cross the rating margin within the specified range.
# Failed to fetch rating history for Divyam_Sharad. Status code: 503
# Failed to fetch rating history for Kurakkoheaddo. Status code: 503
# Tadas did not cross the rating margin within the specified range.
# Failed to fetch rating history for Temporary_Name. Status code: 503
# Failed to fetch rating history for arthpatwari. Status code: 503
# Failed to fetch rating history for divyateja. Status code: 503
# jooncco did not cross the rating margin within the specified range.
# kekenx did not cross the rating margin within the specified range.
# Failed to fetch rating history for shuind. Status code: 503
# Failed to fetch rating history for Gainsboroow. Status code: 503
# Failed to fetch rating history for Salty__fish. Status code: 503
# Failed to fetch rating history for utkarsh_raj_13. Status code: 503
# Failed to fetch rating history for 10086rrt. Status code: 503
# Failed to fetch rating history for CF22190218. Status code: 503
# DrMattsuu did not cross the rating margin within the specified range.
# Failed to fetch rating history for Jackyjuman. Status code: 503
# Failed to fetch rating history for date3k2. Status code: 503
# Failed to fetch rating history for Arvi_saleque. Status code: 503
# Failed to fetch rating history for Hitham. Status code: 503
# Failed to fetch rating history for pipixia-9527. Status code: 503
# Failed to fetch rating history for Ecstiar. Status code: 503
# Failed to fetch rating history for Rydolf_sikorski-Baal. Status code: 503
# Failed to fetch rating history for ilija_IR_13. Status code: 503
# prizer did not cross the rating margin within the specified range.
# Failed to fetch rating history for timurkn. Status code: 503
# Failed to fetch rating history for Anushkag_21. Status code: 503
# Failed to fetch rating history for CodeGPT. Status code: 503
# Faizan2.0 did not cross the rating margin within the specified range.
# Failed to fetch rating history for IBMG. Status code: 503
# SongJl did not cross the rating margin within the specified range.
# Failed to fetch rating history for dazai_chan. Status code: 503
# Failed to fetch rating history for hsayhsay. Status code: 503
# Failed to fetch rating history for mtppp. Status code: 503
# welen did not cross the rating margin within the specified range.
# Failed to fetch rating history for A.Hazem_2003. Status code: 503
# Failed to fetch rating history for HashBuke. Status code: 503
# Failed to fetch rating history for KI-RA. Status code: 503
# Failed to fetch rating history for Tahmid76. Status code: 503
# Failed to fetch rating history for bot1132. Status code: 503
# kyasa did not cross the rating margin within the specified range.
# Failed to fetch rating history for lifeadventurer. Status code: 503
# Failed to fetch rating history for mrhga_incognito. Status code: 503
# Failed to fetch rating history for pro_musu. Status code: 503
# Failed to fetch rating history for saiprem_k. Status code: 503
# Failed to fetch rating history for Lambd47. Status code: 503
# Failed to fetch rating history for crimcrim. Status code: 503
# Failed to fetch rating history for prathamesh.pawar. Status code: 503
# Failed to fetch rating history for zhouzepeng_2023. Status code: 503
# Failed to fetch rating history for 2516_lord. Status code: 503
# Failed to fetch rating history for Hunny_Bunny. Status code: 503
# Failed to fetch rating history for StepanDv. Status code: 503
# Failed to fetch rating history for harsh_8484. Status code: 503
# marcktony did not cross the rating margin within the specified range.
# Failed to fetch rating history for susanzhishen1234. Status code: 503
# Failed to fetch rating history for 1divergent1. Status code: 503
# Failed to fetch rating history for MZG_. Status code: 503
# Failed to fetch rating history for a_z_c. Status code: 503
# Failed to fetch rating history for JEE_MAIN_LOOSER. Status code: 503
# Failed to fetch rating history for dazai119. Status code: 503
# Failed to fetch rating history for ishraqfatin7. Status code: 503
# Failed to fetch rating history for ukr.25. Status code: 503
# Failed to fetch rating history for Evadra_jiangly. Status code: 503
# Failed to fetch rating history for I_know_8. Status code: 503
# Failed to fetch rating history for SergHambardzumyan. Status code: 503
# Failed to fetch rating history for Yugaaditya_Achhara. Status code: 503
# Failed to fetch rating history for jvatsal0709. Status code: 503
# orange_trie did not cross the rating margin within the specified range.
# Failed to fetch rating history for parth_kayal. Status code: 503
# Failed to fetch rating history for Atokensis. Status code: 503
# Failed to fetch rating history for Marios.K.R.Marouditsis. Status code: 503
# Failed to fetch rating history for Teranj. Status code: 503
# down__ did not cross the rating margin within the specified range.
# Failed to fetch rating history for litterdog. Status code: 503
#                Handle  Max Rating Result
# 0             gjain_7        1436    Yes
# 1             haazalt        1468     No
# 2    louisfghbvc_tail        1551     No
# 3         shenghang16        1423     No
# 4          shiv_31416        1654    Yes
# ..                ...         ...    ...
# 495         Ventasoul        1403     No
# 496       _shoaib_221        1538    Yes
# 497      abhishekHero        1632     No
# 498            down__        1412    N/A
# 499         litterdog        1469    N/A
#
# [500 rows x 3 columns]
