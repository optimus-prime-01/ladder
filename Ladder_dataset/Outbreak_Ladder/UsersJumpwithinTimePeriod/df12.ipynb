# %%
import requests
from datetime import datetime
import pandas as pd
df=pd.read_csv('df12.csv')
import json
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1200
    target_upper = 1400

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 20 <= days_taken <= 40:
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
# Out:
# chenreddy did not cross the rating margin within the specified range.
# DeepBorys did not cross the rating margin within the specified range.
# Duy_e did not cross the rating margin within the specified range.
# luoZH111 did not cross the rating margin within the specified range.
# MohammadHijaz did not cross the rating margin within the specified range.
# Failed to fetch rating history for ritik_369. Status code: 503
# Failed to fetch rating history for LVDT_. Status code: 503
# OnlyLatinLetters did not cross the rating margin within the specified range.
# Failed to fetch rating history for kg_26. Status code: 503
# Failed to fetch rating history for myheartwaing. Status code: 503
# xwchen did not cross the rating margin within the specified range.
# Failed to fetch rating history for xyfern. Status code: 503
# Failed to fetch rating history for MegalovaniaJ. Status code: 503
# Failed to fetch rating history for achhadahappy. Status code: 503
# Failed to fetch rating history for shinjan99. Status code: 503
# Failed to fetch rating history for Atyou. Status code: 503
# Failed to fetch rating history for Haruka. Status code: 503
# Failed to fetch rating history for KiprasD. Status code: 503
# Failed to fetch rating history for XH_v. Status code: 503
# Failed to fetch rating history for betal. Status code: 503
# Failed to fetch rating history for original_handle. Status code: 503
# Failed to fetch rating history for waffle2316. Status code: 503
# Failed to fetch rating history for De3bOo. Status code: 503
# Kartoshkasmyasom did not cross the rating margin within the specified range.
# Failed to fetch rating history for _Raihan__. Status code: 503
# Failed to fetch rating history for ccdfw. Status code: 503
# Failed to fetch rating history for imMIQ. Status code: 503
# Failed to fetch rating history for menezesd2. Status code: 503
# Failed to fetch rating history for sxpl. Status code: 503
# Failed to fetch rating history for Azzpg7. Status code: 503
# Failed to fetch rating history for Null_Resot. Status code: 503
# QuaJ did not cross the rating margin within the specified range.
# Failed to fetch rating history for Tianshuohu. Status code: 503
# TselmegKh did not cross the rating margin within the specified range.
# Failed to fetch rating history for Xuoline. Status code: 503
# Failed to fetch rating history for b_for_ball. Status code: 503
# Failed to fetch rating history for kapishv. Status code: 503
# Failed to fetch rating history for vivek2943. Status code: 503
# Failed to fetch rating history for Klinashka. Status code: 503
# Failed to fetch rating history for amyt. Status code: 503
# Failed to fetch rating history for iloveyouinalluniverse. Status code: 503
# Failed to fetch rating history for pulkitchauhan03. Status code: 503
# Failed to fetch rating history for Mishok2503. Status code: 503
# Failed to fetch rating history for bobthestickman. Status code: 503
# Creeping_Death_ did not cross the rating margin within the specified range.
# chuka231 did not cross the rating margin within the specified range.
# Failed to fetch rating history for jiujiumaomaoniang. Status code: 503
# Failed to fetch rating history for sandeep0404. Status code: 503
# Failed to fetch rating history for 87109145. Status code: 503
# Failed to fetch rating history for Mehul_Gupta. Status code: 503
# Failed to fetch rating history for almeidaraul. Status code: 503
# Failed to fetch rating history for wakeup__. Status code: 503
# AWPer did not cross the rating margin within the specified range.
# Matthew_hpg did not cross the rating margin within the specified range.
# Failed to fetch rating history for RyuZU. Status code: 503
# Shkiper did not cross the rating margin within the specified range.
# Failed to fetch rating history for fushar. Status code: 503
# geyanlu3 did not cross the rating margin within the specified range.
# Failed to fetch rating history for jatinxkirito. Status code: 503
# lhy_hanhan did not cross the rating margin within the specified range.
# Failed to fetch rating history for maple_1016. Status code: 503
# nehan_der_thal did not cross the rating margin within the specified range.
# Failed to fetch rating history for nishu2002. Status code: 503
# sinak03 did not cross the rating margin within the specified range.
# Failed to fetch rating history for 200389. Status code: 503
# KingofField did not cross the rating margin within the specified range.
# Failed to fetch rating history for OMEGAftw. Status code: 503
# Failed to fetch rating history for ak47itout. Status code: 503
# Failed to fetch rating history for andhBhakt. Status code: 503
# Failed to fetch rating history for lfxxx. Status code: 503
# Failed to fetch rating history for yzh_Error404. Status code: 503
# zrzring did not cross the rating margin within the specified range.
# AbolphazlAsadi8 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Ahmed_Ashraf_f. Status code: 503
# Failed to fetch rating history for Knightz. Status code: 503
# Failed to fetch rating history for dakshdixit183. Status code: 503
# Failed to fetch rating history for dk_sensei. Status code: 503
# Failed to fetch rating history for shaw_chick. Status code: 503
# Failed to fetch rating history for slivolymp. Status code: 503
# Failed to fetch rating history for JXNUvjudge2. Status code: 503
# Failed to fetch rating history for SU_30MKI. Status code: 503
# Failed to fetch rating history for X_LX. Status code: 503
# luchinkinkos did not cross the rating margin within the specified range.
# Failed to fetch rating history for utkarsh.rai. Status code: 503
# Kumzericov did not cross the rating margin within the specified range.
# Failed to fetch rating history for LittleFatSheep. Status code: 503
# Failed to fetch rating history for MasterOfBugs. Status code: 503
# Failed to fetch rating history for Sourav.Kumar007. Status code: 503
# Failed to fetch rating history for formidablechief_27. Status code: 503
# Failed to fetch rating history for kira98k. Status code: 503
# Failed to fetch rating history for U_U-zzz. Status code: 503
# Failed to fetch rating history for harman_69. Status code: 503
# Failed to fetch rating history for pka5667. Status code: 503
# finkery did not cross the rating margin within the specified range.
# scriptozaur did not cross the rating margin within the specified range.
# BeYourSven did not cross the rating margin within the specified range.
# snailbaron did not cross the rating margin within the specified range.
# DhruvP did not cross the rating margin within the specified range.
# gagan_6730 did not cross the rating margin within the specified range.
# Gorane did not cross the rating margin within the specified range.
# Hikiri did not cross the rating margin within the specified range.
# ayhon did not cross the rating margin within the specified range.
# Failed to fetch rating history for csustyyt. Status code: 503
# myj128128 did not cross the rating margin within the specified range.
# Failed to fetch rating history for schant. Status code: 503
# Failed to fetch rating history for Awa_. Status code: 503
# Failed to fetch rating history for WaveBreaker. Status code: 503
# Failed to fetch rating history for utkarshrai5678. Status code: 503
# Earl_of_Lemongrab did not cross the rating margin within the specified range.
# Failed to fetch rating history for Susie.Rain. Status code: 503
# Failed to fetch rating history for akshay_1. Status code: 503
# crystaalroo did not cross the rating margin within the specified range.
# Failed to fetch rating history for daoqi. Status code: 503
# Failed to fetch rating history for Sinlin. Status code: 503
# Failed to fetch rating history for daniilgrbic. Status code: 503
# sanyam2248 did not cross the rating margin within the specified range.
# Failed to fetch rating history for justbaka. Status code: 503
# Failed to fetch rating history for sr2005roy. Status code: 503
# Failed to fetch rating history for ABlueCat. Status code: 503
# Failed to fetch rating history for DarthCoder33. Status code: 503
# Failed to fetch rating history for Mohamed_Saad62. Status code: 503
# Failed to fetch rating history for linuxed. Status code: 503
# Failed to fetch rating history for sparkblit. Status code: 503
# Failed to fetch rating history for -V-. Status code: 503
# Failed to fetch rating history for Peter2505. Status code: 503
# Failed to fetch rating history for circle977. Status code: 503
# Failed to fetch rating history for lamda24. Status code: 503
# Failed to fetch rating history for shivambhadani_. Status code: 503
# Failed to fetch rating history for BhupinderJ. Status code: 503
# Failed to fetch rating history for K_DIS. Status code: 503
# Failed to fetch rating history for Saimun_Islam. Status code: 503
# Failed to fetch rating history for cp_only. Status code: 503
# Failed to fetch rating history for m3tr0. Status code: 503
# Failed to fetch rating history for sswcdak. Status code: 503
# Failed to fetch rating history for u_u_. Status code: 503
# Failed to fetch rating history for Ahmad7_7. Status code: 503
# Failed to fetch rating history for KeshavChib. Status code: 503
# Failed to fetch rating history for Tlk_Aver. Status code: 503
# Failed to fetch rating history for ZyadFva. Status code: 503
# Failed to fetch rating history for kakakaa. Status code: 503
# pravin014 did not cross the rating margin within the specified range.
#              Handle  Max Rating Result
# 0        Potoccino.        1767     No
# 1         Yes_about        1601     No
# 2         chenreddy        1708    N/A
# 3      damjandavkov        1601     No
# 4    forgotmyhandle        1613     No
# ..              ...         ...    ...
# 495     fireheart17        1715    Yes
# 496         kakakaa        1664    N/A
# 497     kitekat1__4        1579    Yes
# 498       lllsssccc        1571     No
# 499       pravin014        1645    N/A
#
# [500 rows x 3 columns]

# %%
df.head()
# Out:
#            Handle  Max Rating Result
# 0      Potoccino.        1767     No
# 1       Yes_about        1601     No
# 2       chenreddy        1708    N/A
# 3    damjandavkov        1601     No
# 4  forgotmyhandle        1613     No

# %%
df.to_csv('outdf11.csv', index=False)
