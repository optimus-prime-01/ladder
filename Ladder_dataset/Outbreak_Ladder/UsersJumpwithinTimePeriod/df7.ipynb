# %%
import requests
from datetime import datetime
import pandas as pd

# %%
df=pd.read_csv('df7.csv')

# %%
import json
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1200
    target_upper = 1400

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 20 <= days_taken <= 40:
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
# Out:
# Eleganty did not cross the rating margin within the specified range.
# Failed to fetch rating history for NimaAryan. Status code: 504
# Hazzu did not cross the rating margin within the specified range.
# ZiXeL did not cross the rating margin within the specified range.
# daniilzimin4 did not cross the rating margin within the specified range.
# Failed to fetch rating history for temp_tamora. Status code: 503
# Failed to fetch rating history for Black_Be4rD. Status code: 503
# Failed to fetch rating history for DoverHi. Status code: 503
# bashNewbie did not cross the rating margin within the specified range.
# jskhirtladze did not cross the rating margin within the specified range.
# Failed to fetch rating history for kushalgupta87. Status code: 503
# Failed to fetch rating history for _LONE__WOLF_. Status code: 503
# ahmad_alghadban did not cross the rating margin within the specified range.
# Failed to fetch rating history for areason. Status code: 503
# Failed to fetch rating history for lightblue_pikachu. Status code: 503
# Failed to fetch rating history for tongzhenxuan. Status code: 503
# Alan.sp did not cross the rating margin within the specified range.
# Failed to fetch rating history for MysteryGuy2. Status code: 503
# Failed to fetch rating history for eriktse. Status code: 503
# Failed to fetch rating history for CF.Symphonia. Status code: 503
# Failed to fetch rating history for Deamer. Status code: 503
# Failed to fetch rating history for PurpleHanHan. Status code: 503
# Failed to fetch rating history for rarewelsh. Status code: 503
# Failed to fetch rating history for srikkanthr. Status code: 503
# Failed to fetch rating history for AustinJiang. Status code: 503
# Failed to fetch rating history for HIJAZ. Status code: 503
# Failed to fetch rating history for NokSyte. Status code: 503
# Streamyue03 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Yuno08. Status code: 503
# Failed to fetch rating history for neo11235. Status code: 503
# MojeDes did not cross the rating margin within the specified range.
# Failed to fetch rating history for CarlosS48. Status code: 503
# Failed to fetch rating history for Sanam007. Status code: 503
# Tiagodfs did not cross the rating margin within the specified range.
# Failed to fetch rating history for Xiaochouzhu. Status code: 503
# Failed to fetch rating history for vbsinha. Status code: 503
# Failed to fetch rating history for Jamaisvu. Status code: 503
# Failed to fetch rating history for bwang1008. Status code: 503
# kinnikuma did not cross the rating margin within the specified range.
# Failed to fetch rating history for krzysiek_how. Status code: 503
# Failed to fetch rating history for sunnygreen. Status code: 503
# yaya did not cross the rating margin within the specified range.
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Failed to fetch rating history for __noob___. Status code: 503
# Invalid JSON response from the API
# Invalid JSON response from the API
# ywjylx did not cross the rating margin within the specified range.
# Failed to fetch rating history for Razvan_Rotaru. Status code: 503
# RedLeaf did not cross the rating margin within the specified range.
# dusty.and.rusty did not cross the rating margin within the specified range.
# limabeans did not cross the rating margin within the specified range.
# Failed to fetch rating history for bkdn23.SicilianDragonLvr. Status code: 503
# Failed to fetch rating history for Vladosiya. Status code: 503
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Failed to fetch rating history for rmwz. Status code: 503
# Invalid JSON response from the API
# Failed to fetch rating history for -Fainted-. Status code: 503
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# StrausKoldun did not cross the rating margin within the specified range.
# YakovPolykovsky did not cross the rating margin within the specified range.
# Failed to fetch rating history for futuo. Status code: 503
# sleepwalking643 did not cross the rating margin within the specified range.
# Failed to fetch rating history for unbengable. Status code: 503
# Failed to fetch rating history for Everything_Is_Connected. Status code: 503
# TypeYippie did not cross the rating margin within the specified range.
# Failed to fetch rating history for Ynoel. Status code: 503
# Failed to fetch rating history for rajbunsha. Status code: 503
# Failed to fetch rating history for SmartZX. Status code: 503
# Failed to fetch rating history for owensidarta. Status code: 503
# Belief_yfly did not cross the rating margin within the specified range.
# Failed to fetch rating history for lsxhyyds. Status code: 503
# lubei600 did not cross the rating margin within the specified range.
# thesis_or_die did not cross the rating margin within the specified range.
# Failed to fetch rating history for XCPC. Status code: 503
# kinoud did not cross the rating margin within the specified range.
# Failed to fetch rating history for wjwzbdx. Status code: 503
# AndZhi did not cross the rating margin within the specified range.
# rast.dan.rast did not cross the rating margin within the specified range.
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# Invalid JSON response from the API
# icefake did not cross the rating margin within the specified range.
# 2020akadaver did not cross the rating margin within the specified range.
# Failed to fetch rating history for EN_SA. Status code: 503
# Failed to fetch rating history for MoLotfi. Status code: 503
# Failed to fetch rating history for zabrouter. Status code: 503
# Failed to fetch rating history for Hhl8924. Status code: 503
# Failed to fetch rating history for Mr_Ell. Status code: 503
# Failed to fetch rating history for aviralarpan3301. Status code: 503
# 3JlOU_XJlE6UIIIEK did not cross the rating margin within the specified range.
# Failed to fetch rating history for 79975580. Status code: 503
# Absurd_ did not cross the rating margin within the specified range.
# Insta-x did not cross the rating margin within the specified range.
# Failed to fetch rating history for Zobayer_Abedin. Status code: 503
# Failed to fetch rating history for sleepyx_zZ. Status code: 503
# Failed to fetch rating history for Beautiful_Times. Status code: 503
# Failed to fetch rating history for baba_yaga_0_0_0. Status code: 503
# new_textfile did not cross the rating margin within the specified range.
# Failed to fetch rating history for 17_Msd. Status code: 503
# ayersz did not cross the rating margin within the specified range.
# Failed to fetch rating history for llinzy. Status code: 503
# kunaltawatia did not cross the rating margin within the specified range.
# Short_Bit did not cross the rating margin within the specified range.
# Failed to fetch rating history for adwsaef. Status code: 503
# Exeedo did not cross the rating margin within the specified range.
# Failed to fetch rating history for PCZ. Status code: 503
# Failed to fetch rating history for bubuwu. Status code: 503
# jianzuan did not cross the rating margin within the specified range.
# Failed to fetch rating history for Astrayt. Status code: 503
# Failed to fetch rating history for Wutip. Status code: 503
# Failed to fetch rating history for AlephZero01. Status code: 503
# Failed to fetch rating history for S_Neal. Status code: 503
# TakeAway did not cross the rating margin within the specified range.
# knon0501 did not cross the rating margin within the specified range.
# orzzz23333 did not cross the rating margin within the specified range.
# Failed to fetch rating history for rryh. Status code: 503
# egor4kus did not cross the rating margin within the specified range.
# Failed to fetch rating history for jzhsh1735. Status code: 503
# Failed to fetch rating history for Desertqwq. Status code: 503
# Failed to fetch rating history for byurak. Status code: 503
# Failed to fetch rating history for kriplani_123. Status code: 503
# Failed to fetch rating history for rkb_rd. Status code: 503
# 1234567892 did not cross the rating margin within the specified range.
# bestial-42-centroids did not cross the rating margin within the specified range.
# MrBekson119 did not cross the rating margin within the specified range.
# Scano did not cross the rating margin within the specified range.
# Failed to fetch rating history for CSUST_GXL. Status code: 503
# Failed to fetch rating history for Wolowitz. Status code: 503
# Failed to fetch rating history for orke2001. Status code: 503
# Failed to fetch rating history for Ameya27. Status code: 503
# Failed to fetch rating history for NU_ICPC. Status code: 503
# Failed to fetch rating history for The6thPlatonicSolid. Status code: 503
# coldwinds did not cross the rating margin within the specified range.
# xwoqlk did not cross the rating margin within the specified range.
# Failed to fetch rating history for -ilya-. Status code: 503
# 1234567891 did not cross the rating margin within the specified range.
# Failed to fetch rating history for zgock. Status code: 503
# Failed to fetch rating history for dtta. Status code: 503
#                 Handle  Max Rating Result
# 0            vuhuydiet        1784     No
# 1              wang_by        1830    Yes
# 2                 1660        1783     No
# 3           2021404292        1783    Yes
# 4    Aman113114_Bansal        1857     No
# ..                 ...         ...    ...
# 495              zgock        1841    N/A
# 496         _kingpin__        1738     No
# 497             new2ac        1790     No
# 498              Jean7        1734     No
# 499               dtta        1864    N/A
#
# [500 rows x 3 columns]

# %%
df.head()
# Out:
#               Handle  Max Rating Result
# 0          vuhuydiet        1784     No
# 1            wang_by        1830    Yes
# 2               1660        1783     No
# 3         2021404292        1783    Yes
# 4  Aman113114_Bansal        1857     No

# %%
df.to_csv('outdf7.csv', index=False)
