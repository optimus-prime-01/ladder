# %%
import requests
from datetime import datetime
import pandas as pd

# %%
df=pd.read_csv('df1.csv')

# %%
df_test=pd.read_csv('test.csv')

# %%
df.head()
# Out:
#          Handle  Max Rating  Result
# 0       tourist        3979     NaN
# 1     Radewoosh        3752     NaN
# 2          Benq        3813     NaN
# 3       jiangly        3859     NaN
# 4  orzdevinwang        3697     NaN

# %%
df_test
# Out:
#         Handle  Max Rating
# 0  seisiroNagi        1430
# 1      agrim07        1657

# %%
import json

# %%
# def get_codeforces_rating_history(username):
#     url = f"https://codeforces.com/api/user.rating?handle={username}"
#     response = requests.get(url)
    
#     if response.status_code == 200:
#         try:
#             data = response.json()
#             if data["status"] == "OK":
#                 return data["result"]
#             else:
#                 print(f"API Error: {data.get('comment', 'No specific error message provided')}")
#         except json.JSONDecodeError:
#             print("Invalid JSON response from the API")
#     else:
#         print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

#     return None

# def days_to_cross_margin(username, target_lower, target_upper):
#     rating_history = get_codeforces_rating_history(username)
    
#     if rating_history is None:
#         return None

#     current_rating = None
#     start_date = None
#     end_date = None

#     for entry in rating_history:
#         rating = entry["newRating"]
#         contest_time = entry["ratingUpdateTimeSeconds"]
#         contest_date = datetime.fromtimestamp(contest_time)

#         if rating <= target_lower:
#             start_date = contest_date
#         elif rating >= target_upper:
#             end_date = contest_date
#             break

#     if start_date and end_date:
#         days_taken = (end_date - start_date).days
#         return days_taken
#     else:
#         print(f"{username} did not cross the rating margin within the specified range.")
#         return None

# def add_result_to_dataframe(df):
#     df['Result'] = ""
#     target_lower = 1200
#     target_upper = 1400

#     for index, row in df.iterrows():
#         username = row['Handle']
#         days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
#         if days_taken is not None:
#             if 20 <= days_taken <= 40:
#                 df.at[index, 'Result'] = "Yes"
#             else:
#                 df.at[index, 'Result'] = "No"
#         else:
#             df.at[index, 'Result'] = "N/A"

#     return df

# if __name__ == "__main__":
    
#     df = add_result_to_dataframe(df_test)

#     print(df_test)

# %%
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1200
    target_upper = 1400

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 20 <= days_taken <= 40:
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
# Out:
# tourist did not cross the rating margin within the specified range.
# Radewoosh did not cross the rating margin within the specified range.
# Benq did not cross the rating margin within the specified range.
# jiangly did not cross the rating margin within the specified range.
# orzdevinwang did not cross the rating margin within the specified range.
# cnnfls_csy did not cross the rating margin within the specified range.
# maroonrk did not cross the rating margin within the specified range.
# amiya did not cross the rating margin within the specified range.
# Um_nik did not cross the rating margin within the specified range.
# ecnerwala did not cross the rating margin within the specified range.
# Geothermal did not cross the rating margin within the specified range.
# heno239 did not cross the rating margin within the specified range.
# Failed to fetch rating history for QAQAutoMaton. Status code: 503
# p_b_p_b did not cross the rating margin within the specified range.
# hos.lyric did not cross the rating margin within the specified range.
# Ormlis did not cross the rating margin within the specified range.
# isaf27 did not cross the rating margin within the specified range.
# neal did not cross the rating margin within the specified range.
# Qingyu did not cross the rating margin within the specified range.
# yosupo did not cross the rating margin within the specified range.
# Failed to fetch rating history for 244mhq. Status code: 503
# flowerletter did not cross the rating margin within the specified range.
# ugly2333 did not cross the rating margin within the specified range.
# gamegame did not cross the rating margin within the specified range.
# Failed to fetch rating history for sjcsjcsjc. Status code: 503
# 998batrr did not cross the rating margin within the specified range.
# Failed to fetch rating history for turmax. Status code: 503
# Kubic did not cross the rating margin within the specified range.
# gisp_zjz did not cross the rating margin within the specified range.
# fsy_jiaxun_when did not cross the rating margin within the specified range.
# ksun48 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Maksim1744. Status code: 503
# Endagorion did not cross the rating margin within the specified range.
# Failed to fetch rating history for kotatsugame. Status code: 503
# noimi did not cross the rating margin within the specified range.
# SSRS_ did not cross the rating margin within the specified range.
# Failed to fetch rating history for potato167. Status code: 503
# Crystally did not cross the rating margin within the specified range.
# A.K.E.E. did not cross the rating margin within the specified range.
# Failed to fetch rating history for dlalswp25. Status code: 503
# Merkurev did not cross the rating margin within the specified range.
# peti1234 did not cross the rating margin within the specified range.
# Failed to fetch rating history for jiangly_fan. Status code: 503
# Swistakk did not cross the rating margin within the specified range.
# dXqwq did not cross the rating margin within the specified range.
# Failed to fetch rating history for Alex_Wei. Status code: 503
# MagicSpark did not cross the rating margin within the specified range.
# Failed to fetch rating history for Vercingetorix. Status code: 503
# ainta did not cross the rating margin within the specified range.
# Failed to fetch rating history for The_Noble_Brahman_Bison. Status code: 503
# Golovanov399 did not cross the rating margin within the specified range.
# Failed to fetch rating history for youbot. Status code: 503
# tute7627 did not cross the rating margin within the specified range.
# Failed to fetch rating history for 1004535809. Status code: 503
# feecIe6418 did not cross the rating margin within the specified range.
# Failed to fetch rating history for EternalAlexander. Status code: 503
# yuto1115 did not cross the rating margin within the specified range.
# Failed to fetch rating history for hank55663. Status code: 503
# Failed to fetch rating history for i_will_be_less_than_blue. Status code: 503
# antontrygubO_o did not cross the rating margin within the specified range.
# E869120 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Kapt. Status code: 503
# Failed to fetch rating history for 275307894a. Status code: 503
# Failed to fetch rating history for 353cerega. Status code: 503
# qiuzx did not cross the rating margin within the specified range.
# PinkieRabbit did not cross the rating margin within the specified range.
# Failed to fetch rating history for Sol1. Status code: 503
# Amoo_Safar did not cross the rating margin within the specified range.
# Egor did not cross the rating margin within the specified range.
# Rubikun did not cross the rating margin within the specified range.
# Failed to fetch rating history for Sana. Status code: 503
# ppavic did not cross the rating margin within the specified range.
# kdh9949 did not cross the rating margin within the specified range.
# Failed to fetch rating history for BalintR. Status code: 503
# m_99 did not cross the rating margin within the specified range.
# LeoPro did not cross the rating margin within the specified range.
# peltorator did not cross the rating margin within the specified range.
# Failed to fetch rating history for kmjp. Status code: 503
# sansen did not cross the rating margin within the specified range.
# blackbori did not cross the rating margin within the specified range.
# Roundgod did not cross the rating margin within the specified range.
# antekb did not cross the rating margin within the specified range.
# hitonanode did not cross the rating margin within the specified range.
# QwertyPi did not cross the rating margin within the specified range.
# Licha06 did not cross the rating margin within the specified range.
# Nyaan did not cross the rating margin within the specified range.
# nantf did not cross the rating margin within the specified range.
# TadijaSebez did not cross the rating margin within the specified range.
# Failed to fetch rating history for CharlieV. Status code: 503
# thenymphsofdelphi did not cross the rating margin within the specified range.
# Failed to fetch rating history for foammm. Status code: 503
# Failed to fetch rating history for Kite_kuma. Status code: 503
# Farhod_Farmon did not cross the rating margin within the specified range.
# Failed to fetch rating history for RDDCCD. Status code: 503
# Failed to fetch rating history for qwerty787788. Status code: 503
# risujiroh did not cross the rating margin within the specified range.
# Failed to fetch rating history for Nachia. Status code: 503
# BigBag did not cross the rating margin within the specified range.
# Failed to fetch rating history for Morphymorphymorphy. Status code: 503
# soltanbh did not cross the rating margin within the specified range.
# Failed to fetch rating history for jacynkaa. Status code: 503
# AndreySergunin did not cross the rating margin within the specified range.
# Failed to fetch rating history for Potassium. Status code: 503
# kevinxiehk did not cross the rating margin within the specified range.
# Pyqe did not cross the rating margin within the specified range.
# AlternatingCurrent did not cross the rating margin within the specified range.
# chinerist did not cross the rating margin within the specified range.
# Isoeasy did not cross the rating margin within the specified range.
# milisav did not cross the rating margin within the specified range.
# _Peter_ did not cross the rating margin within the specified range.
# Keshi did not cross the rating margin within the specified range.
# -14 did not cross the rating margin within the specified range.
# Toxel did not cross the rating margin within the specified range.
# Brovko did not cross the rating margin within the specified range.
# Failed to fetch rating history for wygzgyw. Status code: 503
# ooOAM did not cross the rating margin within the specified range.
# Snow-Flower did not cross the rating margin within the specified range.
# Denisov did not cross the rating margin within the specified range.
# SomethingNew did not cross the rating margin within the specified range.
# Salley-Garden did not cross the rating margin within the specified range.
# cabbit did not cross the rating margin within the specified range.
# Temotoloraia did not cross the rating margin within the specified range.
# fengzhengwei did not cross the rating margin within the specified range.
# Failed to fetch rating history for KLPP. Status code: 503
# tfg did not cross the rating margin within the specified range.
# _Guoyh_ did not cross the rating margin within the specified range.
# emthrm did not cross the rating margin within the specified range.
# Karuna did not cross the rating margin within the specified range.
# rniya did not cross the rating margin within the specified range.
# Failed to fetch rating history for natofp. Status code: 503
# zidder did not cross the rating margin within the specified range.
# se1ka2 did not cross the rating margin within the specified range.
# Failed to fetch rating history for jdurie. Status code: 503
# Xylenox did not cross the rating margin within the specified range.
# Failed to fetch rating history for maxplus. Status code: 503
# Failed to fetch rating history for natsugiri. Status code: 503
# Xellos did not cross the rating margin within the specified range.
# Sulfox did not cross the rating margin within the specified range.
# Rafi22 did not cross the rating margin within the specified range.
# Failed to fetch rating history for nvmdava. Status code: 503
# namelessgugugu did not cross the rating margin within the specified range.
# TheScrasse did not cross the rating margin within the specified range.
# Failed to fetch rating history for BucketPotato. Status code: 503
# icecuber did not cross the rating margin within the specified range.
# LogHorizon did not cross the rating margin within the specified range.
# Failed to fetch rating history for kizen. Status code: 503
# Failed to fetch rating history for Dominater069. Status code: 503
# Sert did not cross the rating margin within the specified range.
# Andreasyan did not cross the rating margin within the specified range.
# Failed to fetch rating history for JoesSR_. Status code: 503
# platter did not cross the rating margin within the specified range.
# bashkort did not cross the rating margin within the specified range.
# physics0523 did not cross the rating margin within the specified range.
# Ronnie007 did not cross the rating margin within the specified range.
# tiger2005 did not cross the rating margin within the specified range.
# Rewenix did not cross the rating margin within the specified range.
# reedef did not cross the rating margin within the specified range.
# KrK did not cross the rating margin within the specified range.
# sevlll777 did not cross the rating margin within the specified range.
# AI_COre did not cross the rating margin within the specified range.
# fastmath did not cross the rating margin within the specified range.
# Peti did not cross the rating margin within the specified range.
# Ra16bit did not cross the rating margin within the specified range.
# gabrielwu did not cross the rating margin within the specified range.
# chen_zexing did not cross the rating margin within the specified range.
# triple__a did not cross the rating margin within the specified range.
# Alfalfa_w did not cross the rating margin within the specified range.
# AliShahali1382 did not cross the rating margin within the specified range.
# lightseba did not cross the rating margin within the specified range.
# Sorting did not cross the rating margin within the specified range.
# mtsd did not cross the rating margin within the specified range.
# jtnydv25 did not cross the rating margin within the specified range.
# Failed to fetch rating history for zihouzhong. Status code: 503
# TeaPot did not cross the rating margin within the specified range.
# Warriors_fsy did not cross the rating margin within the specified range.
# Failed to fetch rating history for _Serge_. Status code: 503
# chenxiaoyan did not cross the rating margin within the specified range.
# 0wuming0 did not cross the rating margin within the specified range.
# leaf1415 did not cross the rating margin within the specified range.
# Failed to fetch rating history for lambert0704. Status code: 503
# mraron did not cross the rating margin within the specified range.
# kyo20111 did not cross the rating margin within the specified range.
# al3xstr33t did not cross the rating margin within the specified range.
# olmrgcsi did not cross the rating margin within the specified range.
# Failed to fetch rating history for AmShZ. Status code: 503
# iakovlev.zakhar did not cross the rating margin within the specified range.
# cxaphoenix did not cross the rating margin within the specified range.
# Failed to fetch rating history for JovanB. Status code: 503
# Failed to fetch rating history for asdsasd. Status code: 503
# rama_pang did not cross the rating margin within the specified range.
# andrei_boaca did not cross the rating margin within the specified range.
# Failed to fetch rating history for W4P3R. Status code: 503
# fuyutsuki did not cross the rating margin within the specified range.
# Enchom did not cross the rating margin within the specified range.
# RobeZH did not cross the rating margin within the specified range.
# Barichek did not cross the rating margin within the specified range.
# zhouhuanyi did not cross the rating margin within the specified range.
# Omer223 did not cross the rating margin within the specified range.
# busamate did not cross the rating margin within the specified range.
# Jacob did not cross the rating margin within the specified range.
# filibuster did not cross the rating margin within the specified range.
# zhylj did not cross the rating margin within the specified range.
# yaoxi did not cross the rating margin within the specified range.
# Failed to fetch rating history for ALILILILILI-KHAN. Status code: 503
# DeadlyPillow did not cross the rating margin within the specified range.
# Failed to fetch rating history for hyforces. Status code: 503
# VladProg did not cross the rating margin within the specified range.
# atodo did not cross the rating margin within the specified range.
# Failed to fetch rating history for est_stella. Status code: 503
# installb did not cross the rating margin within the specified range.
# Kaitokid did not cross the rating margin within the specified range.
# irkstepanov did not cross the rating margin within the specified range.
# torisasami did not cross the rating margin within the specified range.
# Anonymous_Noob did not cross the rating margin within the specified range.
# Failed to fetch rating history for feeder1. Status code: 503
# flashmt did not cross the rating margin within the specified range.
# haruki_K did not cross the rating margin within the specified range.
# scanhex did not cross the rating margin within the specified range.
# Door_Dark_We did not cross the rating margin within the specified range.
# magnus.hegdahl did not cross the rating margin within the specified range.
# ace5 did not cross the rating margin within the specified range.
# EasonTAO did not cross the rating margin within the specified range.
# uwu did not cross the rating margin within the specified range.
# cuom1999 did not cross the rating margin within the specified range.
# Failed to fetch rating history for mumu.. Status code: 503
# ttttan did not cross the rating margin within the specified range.
# Rafbill did not cross the rating margin within the specified range.
# EnAnimant did not cross the rating margin within the specified range.
# Failed to fetch rating history for Marckess. Status code: 503
# Valera_Grinenko did not cross the rating margin within the specified range.
# fuppy did not cross the rating margin within the specified range.
# Timsei did not cross the rating margin within the specified range.
# Misericorde did not cross the rating margin within the specified range.
# ytkn did not cross the rating margin within the specified range.
# w0nsh did not cross the rating margin within the specified range.
# Redpojoe did not cross the rating margin within the specified range.
# Failed to fetch rating history for Be_dos. Status code: 503
# ialakhtin did not cross the rating margin within the specified range.
# JJLeo did not cross the rating margin within the specified range.
# valeriu did not cross the rating margin within the specified range.
# Nero did not cross the rating margin within the specified range.
# Septimelon did not cross the rating margin within the specified range.
# Unlimited_zero did not cross the rating margin within the specified range.
# Flamire did not cross the rating margin within the specified range.
# Tutis did not cross the rating margin within the specified range.
# limanjun did not cross the rating margin within the specified range.
# MateoCV did not cross the rating margin within the specified range.
# -is-this-fft- did not cross the rating margin within the specified range.
# Akulyat did not cross the rating margin within the specified range.
# Tlatoani did not cross the rating margin within the specified range.
# Everule did not cross the rating margin within the specified range.
# aibark did not cross the rating margin within the specified range.
# MrBrionix did not cross the rating margin within the specified range.
# Failed to fetch rating history for ggawryal. Status code: 503
# 2018LZY did not cross the rating margin within the specified range.
# minato did not cross the rating margin within the specified range.
# FelixMP did not cross the rating margin within the specified range.
# Failed to fetch rating history for sephrys. Status code: 503
# forxen did not cross the rating margin within the specified range.
# Failed to fetch rating history for SeiunSky. Status code: 503
# Failed to fetch rating history for lichenghan. Status code: 503
# DylanSmith did not cross the rating margin within the specified range.
# Failed to fetch rating history for yogahmad77. Status code: 503
# arnold518 did not cross the rating margin within the specified range.
# Failed to fetch rating history for EnEm. Status code: 503
# Failed to fetch rating history for queen. Status code: 503
# Failed to fetch rating history for zyxoi. Status code: 503
# Failed to fetch rating history for fzw. Status code: 503
# Failed to fetch rating history for Leasier. Status code: 503
# Failed to fetch rating history for Zeardoe. Status code: 503
# Failed to fetch rating history for using233. Status code: 503
# Onjo did not cross the rating margin within the specified range.
# cai_lw did not cross the rating margin within the specified range.
# ZCKevin did not cross the rating margin within the specified range.
# happy.potato did not cross the rating margin within the specified range.
# darnley did not cross the rating margin within the specified range.
# IceKnight1093 did not cross the rating margin within the specified range.
# Failed to fetch rating history for juliany2. Status code: 503
# Failed to fetch rating history for OdtreePrince. Status code: 503
# noya2 did not cross the rating margin within the specified range.
# Failed to fetch rating history for RGB_ICPC3. Status code: 503
# HuaJun did not cross the rating margin within the specified range.
# Failed to fetch rating history for hxhhxh. Status code: 503
# Failed to fetch rating history for darkkcyan. Status code: 503
# Elibay did not cross the rating margin within the specified range.
# Failed to fetch rating history for hypergraph_coloring. Status code: 503
# Failed to fetch rating history for bronze_coder. Status code: 503
# Retired_Isaunoya did not cross the rating margin within the specified range.
# czjxyz did not cross the rating margin within the specified range.
# Failed to fetch rating history for HOLlC. Status code: 503
# ..vince did not cross the rating margin within the specified range.
# Failed to fetch rating history for wrhaco. Status code: 503
# Bucketsmith did not cross the rating margin within the specified range.
# gubeiqg did not cross the rating margin within the specified range.
# Failed to fetch rating history for PolarFlea. Status code: 503
# _LeMur_ did not cross the rating margin within the specified range.
# maximumSHOT did not cross the rating margin within the specified range.
# Failed to fetch rating history for wh2005. Status code: 503
# Failed to fetch rating history for libobil. Status code: 503
# aymanriadsolh did not cross the rating margin within the specified range.
# dancho did not cross the rating margin within the specified range.
# Failed to fetch rating history for yydtq. Status code: 503
# JavierN did not cross the rating margin within the specified range.
# SGColin did not cross the rating margin within the specified range.
# UnstoppableChillMachine did not cross the rating margin within the specified range.
# 1021839 did not cross the rating margin within the specified range.
#                       Handle  Max Rating Result
# 0                    tourist        3979    N/A
# 1                  Radewoosh        3752    N/A
# 2                       Benq        3813    N/A
# 3                    jiangly        3859    N/A
# 4               orzdevinwang        3697    N/A
# ..                       ...         ...    ...
# 495                  SGColin        2309    N/A
# 496  UnstoppableChillMachine        2540    N/A
# 497                   t0mmyn        2309     No
# 498                   cmk666        2361     No
# 499                  1021839        2348    N/A
#
# [500 rows x 3 columns]

# %%
df.head()
# Out:
#          Handle  Max Rating Result
# 0       tourist        3979    N/A
# 1     Radewoosh        3752    N/A
# 2          Benq        3813    N/A
# 3       jiangly        3859    N/A
# 4  orzdevinwang        3697    N/A

# %%
df.to_csv('outdf1.csv', index=False)
