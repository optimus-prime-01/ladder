# %%
import requests
from datetime import datetime
import pandas as pd
df=pd.read_csv('df15.csv')
import json
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1200
    target_upper = 1400

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 20 <= days_taken <= 40:
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
df.to_csv('outdf15.csv', index=False)
# Out:
# Failed to fetch rating history for packkill. Status code: 503
# Failed to fetch rating history for znyee07. Status code: 503
# Inkyo did not cross the rating margin within the specified range.
# Failed to fetch rating history for NTHU_Daniel. Status code: 503
# Failed to fetch rating history for cpnoob1. Status code: 503
# Failed to fetch rating history for shreyas333. Status code: 503
# Foreverftip did not cross the rating margin within the specified range.
# Failed to fetch rating history for KeplerIV. Status code: 503
# PERAPRO did not cross the rating margin within the specified range.
# Failed to fetch rating history for Tang2. Status code: 503
# Failed to fetch rating history for guts__. Status code: 503
# the_batman did not cross the rating margin within the specified range.
# Failed to fetch rating history for xzh. Status code: 503
# yandou did not cross the rating margin within the specified range.
# ASIF_-_ASHIK did not cross the rating margin within the specified range.
# Failed to fetch rating history for Halcyflict. Status code: 503
# Failed to fetch rating history for TJ_ovo. Status code: 503
# _skyHigh did not cross the rating margin within the specified range.
# hby2004 did not cross the rating margin within the specified range.
# Failed to fetch rating history for nhphong207. Status code: 503
# Failed to fetch rating history for virat1906. Status code: 503
# Failed to fetch rating history for yaqiaqiashi. Status code: 503
# Failed to fetch rating history for ITE24. Status code: 503
# KobeWu did not cross the rating margin within the specified range.
# Failed to fetch rating history for SN0WM4N. Status code: 503
# Failed to fetch rating history for covert_insurgent. Status code: 503
# Failed to fetch rating history for jonathanji. Status code: 503
# Failed to fetch rating history for samagra1. Status code: 503
# Failed to fetch rating history for wcyived. Status code: 503
# Failed to fetch rating history for DheeruYS. Status code: 503
# Failed to fetch rating history for Ridham24. Status code: 503
# Failed to fetch rating history for aim-CM. Status code: 503
# Failed to fetch rating history for fantafan. Status code: 503
# Failed to fetch rating history for shympo. Status code: 503
# Failed to fetch rating history for Fan.. Status code: 503
# Failed to fetch rating history for Shifted777. Status code: 503
# Failed to fetch rating history for back_soon. Status code: 503
# bryceShakeair did not cross the rating margin within the specified range.
# Failed to fetch rating history for death_01. Status code: 503
# Failed to fetch rating history for hoilei_hoilo. Status code: 503
# Failed to fetch rating history for AloneMusk. Status code: 503
# Failed to fetch rating history for The_First_Avenger. Status code: 503
# Failed to fetch rating history for trick_trick. Status code: 503
# Failed to fetch rating history for tyang. Status code: 503
# Failed to fetch rating history for Razerxost. Status code: 503
# Failed to fetch rating history for anu-. Status code: 503
# Failed to fetch rating history for iamparthabhowmik. Status code: 503
# Failed to fetch rating history for noobcoder02. Status code: 503
# ronisds did not cross the rating margin within the specified range.
# Failed to fetch rating history for shiv3am. Status code: 503
# Failed to fetch rating history for tjj233233. Status code: 503
# Failed to fetch rating history for DevButani. Status code: 503
# Failed to fetch rating history for IlhanArda. Status code: 503
# Failed to fetch rating history for Mochu. Status code: 503
# Failed to fetch rating history for The.Stranger. Status code: 503
# Failed to fetch rating history for Warinchai_s. Status code: 503
# Failed to fetch rating history for codeheart. Status code: 503
# Failed to fetch rating history for om1429888. Status code: 503
# Failed to fetch rating history for tyWu. Status code: 503
# utoppia did not cross the rating margin within the specified range.
# Failed to fetch rating history for wizwilzo. Status code: 503
# Failed to fetch rating history for CS_17. Status code: 503
# Failed to fetch rating history for Gzi0604. Status code: 503
# Failed to fetch rating history for SeannH. Status code: 503
# Failed to fetch rating history for abhinav4279. Status code: 503
# Failed to fetch rating history for ja1n-aman. Status code: 503
# meki did not cross the rating margin within the specified range.
# Failed to fetch rating history for sarvesh_87. Status code: 503
# Failed to fetch rating history for DanRo23. Status code: 503
# Failed to fetch rating history for Kyr4. Status code: 503
# Failed to fetch rating history for Zhddd_. Status code: 503
# Failed to fetch rating history for ihgazi. Status code: 503
# Failed to fetch rating history for lixingyu. Status code: 503
# Failed to fetch rating history for parlimoos. Status code: 503
# Failed to fetch rating history for uniqua. Status code: 503
# Failed to fetch rating history for zwu2021016339. Status code: 503
# Failed to fetch rating history for Huaizhi. Status code: 503
# Failed to fetch rating history for MaBarsi_21. Status code: 503
# Malek_souissi did not cross the rating margin within the specified range.
# Failed to fetch rating history for Pal_J. Status code: 503
# RollBack did not cross the rating margin within the specified range.
# Failed to fetch rating history for Samiul2651. Status code: 503
# __noob__ did not cross the rating margin within the specified range.
# Failed to fetch rating history for alaa.A2. Status code: 503
# Failed to fetch rating history for alexpods. Status code: 503
# Failed to fetch rating history for happy_sisyphus. Status code: 503
# Failed to fetch rating history for naam_toh_suna_hoga. Status code: 503
# Failed to fetch rating history for rouduoduo2. Status code: 503
# Failed to fetch rating history for uchiha_madaraa. Status code: 503
# Failed to fetch rating history for DeltaV. Status code: 503
# Failed to fetch rating history for Harshit_Singh. Status code: 503
# Failed to fetch rating history for MK.Y. Status code: 503
# Failed to fetch rating history for NeXuS69. Status code: 503
# Failed to fetch rating history for Ujjwal_jain. Status code: 503
# Failed to fetch rating history for ankushdutt. Status code: 503
# -Javelin- did not cross the rating margin within the specified range.
# Prometheus_ did not cross the rating margin within the specified range.
# Failed to fetch rating history for Sarutobi. Status code: 503
# Failed to fetch rating history for Tolret. Status code: 503
# Failed to fetch rating history for chenkuiren. Status code: 503
# Failed to fetch rating history for eldestructojr3. Status code: 503
# Failed to fetch rating history for kavliaros7. Status code: 503
# Failed to fetch rating history for 444. Status code: 503
# Failed to fetch rating history for FarhaanGazi. Status code: 503
# Failed to fetch rating history for Kaushal_26. Status code: 503
# NerfThis did not cross the rating margin within the specified range.
# Failed to fetch rating history for RahulAhuja2901. Status code: 503
# Failed to fetch rating history for amit_n. Status code: 503
# Failed to fetch rating history for dcode786. Status code: 503
# Failed to fetch rating history for lucky_kushwaha. Status code: 503
# Failed to fetch rating history for navneet_1234. Status code: 503
# Failed to fetch rating history for uped. Status code: 503
# Failed to fetch rating history for xbzxzn. Status code: 503
# Failed to fetch rating history for AadiS. Status code: 503
# Failed to fetch rating history for Harshjain4001. Status code: 503
# KM_Parvez did not cross the rating margin within the specified range.
# Failed to fetch rating history for SaltyDonut. Status code: 503
# Failed to fetch rating history for Zanoo. Status code: 503
# fabo3000 did not cross the rating margin within the specified range.
# Failed to fetch rating history for gettingdarkat5. Status code: 503
# Failed to fetch rating history for justin_g_20. Status code: 503
# Failed to fetch rating history for man-ray. Status code: 503
# Failed to fetch rating history for payday3. Status code: 503
# Failed to fetch rating history for yukihira_pot. Status code: 503
# IneedAHero did not cross the rating margin within the specified range.
# Failed to fetch rating history for Ishan2658. Status code: 503
# PrideBlack did not cross the rating margin within the specified range.
# Failed to fetch rating history for TheEliteCoder. Status code: 503
# andrey.starodubtsev did not cross the rating margin within the specified range.
# Failed to fetch rating history for chetan2000. Status code: 503
# Failed to fetch rating history for iWillBe_theBlue. Status code: 503
# Failed to fetch rating history for nowlife. Status code: 503
# Failed to fetch rating history for pzpzpz. Status code: 503
# Failed to fetch rating history for varahamihira_. Status code: 503
# Failed to fetch rating history for 0000pnc. Status code: 503
# Failed to fetch rating history for FLOWPOWER. Status code: 503
# Failed to fetch rating history for MONISM. Status code: 503
# Failed to fetch rating history for Suraj1807. Status code: 503
# Failed to fetch rating history for _adoque. Status code: 503
# Failed to fetch rating history for akshat.singh. Status code: 503
# Failed to fetch rating history for master_by_july. Status code: 503
# milabako did not cross the rating margin within the specified range.
# Failed to fetch rating history for munhwas1140. Status code: 503
# Failed to fetch rating history for red_zone. Status code: 503
# Failed to fetch rating history for wangyuxianWBWYX. Status code: 503
# Failed to fetch rating history for M-Haboosh. Status code: 503
# Failed to fetch rating history for Prashant360. Status code: 503
# Failed to fetch rating history for User2654. Status code: 503
# n_wisteria did not cross the rating margin within the specified range.
# Failed to fetch rating history for Miku_Nakano_OwO. Status code: 503
# Failed to fetch rating history for NATURAL6. Status code: 503
# Failed to fetch rating history for Sycamore_Ma. Status code: 503
# ZeinDaner did not cross the rating margin within the specified range.
# Failed to fetch rating history for chethan78. Status code: 503
# Failed to fetch rating history for ho-oh. Status code: 503
# Failed to fetch rating history for kunal_goyal123. Status code: 503
# CLown1331 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Sindy. Status code: 503
# Failed to fetch rating history for rintar0. Status code: 503
# rsunny did not cross the rating margin within the specified range.
# Failed to fetch rating history for shishankrawat93774. Status code: 503
# Failed to fetch rating history for xy_yx. Status code: 503
# Failed to fetch rating history for Em1L. Status code: 503
# Failed to fetch rating history for Moksh2004. Status code: 503
# Failed to fetch rating history for PROG666. Status code: 503
# Failed to fetch rating history for deepanshusau. Status code: 503
# jonghyeok did not cross the rating margin within the specified range.
# Failed to fetch rating history for mhdi_bzrfkn. Status code: 503
# Failed to fetch rating history for rabby_061. Status code: 503
# Failed to fetch rating history for vladik3301. Status code: 503
# Failed to fetch rating history for Bsqaq. Status code: 503
# Failed to fetch rating history for Dr_AddictStein. Status code: 503
# Failed to fetch rating history for Miyano_Shiho. Status code: 503
# Failed to fetch rating history for aryan.barsaiya. Status code: 503
# Failed to fetch rating history for coder_ravan. Status code: 503
# Failed to fetch rating history for huakaishenliang. Status code: 503
# igoroogle did not cross the rating margin within the specified range.
# Failed to fetch rating history for iliyaafi. Status code: 503
# Failed to fetch rating history for mfctanzim_00. Status code: 503
# Failed to fetch rating history for tawfik_. Status code: 503
# Failed to fetch rating history for yunny_world. Status code: 503
# Failed to fetch rating history for CuteWhite. Status code: 503
# Failed to fetch rating history for JackTan2003. Status code: 503
# Failed to fetch rating history for Lazy__wizard. Status code: 503
# Failed to fetch rating history for alex2354. Status code: 503
#                Handle  Max Rating Result
# 0           nicnaknic        1624    Yes
# 1      riyadas.200208        1631    Yes
# 2                 rzi        1517    Yes
# 3    2022Zhangfenglai        1516    Yes
# 4           Blue_M00n        1516    Yes
# ..                ...         ...    ...
# 495        WarriorBob        1673    Yes
# 496     Zarif_Mustafa        1660     No
# 497          alex2354        1576    N/A
# 498  detective...dots        1527    Yes
# 499          fivefive        1492     No
#
# [500 rows x 3 columns]
