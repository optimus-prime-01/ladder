# %%
import requests
from datetime import datetime
import pandas as pd
df=pd.read_csv('df23.csv')
import json
def get_codeforces_rating_history(username):
    url = f"https:/codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1200
    target_upper = 1400

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 20 <= days_taken <= 40:
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
df.to_csv('outdf23.csv', index=False)
# Out:
# thelonesailor did not cross the rating margin within the specified range.
# Alakhator did not cross the rating margin within the specified range.
# adsk3003 did not cross the rating margin within the specified range.
# clement1n0t did not cross the rating margin within the specified range.
# Andoroid did not cross the rating margin within the specified range.
# Ease did not cross the rating margin within the specified range.
# Masorubka did not cross the rating margin within the specified range.
# bOgOmOl did not cross the rating margin within the specified range.
# Failed to fetch rating history for art22m. Status code: 503
# saurabhldg did not cross the rating margin within the specified range.
# Failed to fetch rating history for shakalaka. Status code: 503
# Lin_Xuan did not cross the rating margin within the specified range.
# Failed to fetch rating history for karan_ug. Status code: 503
# nooba did not cross the rating margin within the specified range.
# _Amantu_ did not cross the rating margin within the specified range.
# tao_genna did not cross the rating margin within the specified range.
# 1429066277 did not cross the rating margin within the specified range.
# Failed to fetch rating history for looeyWei. Status code: 503
# walrussociopath4652 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Artemproyd. Status code: 503
# answerend42 did not cross the rating margin within the specified range.
# Failed to fetch rating history for ezzzay. Status code: 503
# Failed to fetch rating history for swimseal. Status code: 503
# Failed to fetch rating history for manurag_20. Status code: 503
# mrrid did not cross the rating margin within the specified range.
# xxxyyyzzz did not cross the rating margin within the specified range.
# Failed to fetch rating history for Collin033. Status code: 503
# vlade087 did not cross the rating margin within the specified range.
# Failed to fetch rating history for moroccan-x. Status code: 503
# coffee-addict did not cross the rating margin within the specified range.
# zopchur did not cross the rating margin within the specified range.
# Dambola did not cross the rating margin within the specified range.
# Failed to fetch rating history for Ayo__. Status code: 503
# Failed to fetch rating history for srijan_de. Status code: 503
# Failed to fetch rating history for vishabh. Status code: 503
# Salimbek did not cross the rating margin within the specified range.
# Failed to fetch rating history for sarthakgoel97. Status code: 503
# myvaluska did not cross the rating margin within the specified range.
# Failed to fetch rating history for Lizter. Status code: 503
# DavidAA007 did not cross the rating margin within the specified range.
# Godspeeed did not cross the rating margin within the specified range.
# Failed to fetch rating history for _NABULSI. Status code: 503
# hash-tag did not cross the rating margin within the specified range.
# tejavk did not cross the rating margin within the specified range.
# Failed to fetch rating history for GRB777IITH. Status code: 503
# bbc_xu did not cross the rating margin within the specified range.
# ICraZZyBoY did not cross the rating margin within the specified range.
# Failed to fetch rating history for abdalkreem_bzoor. Status code: 503
# anacharsis did not cross the rating margin within the specified range.
# Gonline did not cross the rating margin within the specified range.
# a_Lena did not cross the rating margin within the specified range.
# Failed to fetch rating history for myway. Status code: 503
# Failed to fetch rating history for I_got_some_DREAMS. Status code: 503
# circless did not cross the rating margin within the specified range.
# Failed to fetch rating history for SV_aniket_2. Status code: 503
# avwl017 did not cross the rating margin within the specified range.
# Failed to fetch rating history for rong_nian. Status code: 503
# coderchamp7 did not cross the rating margin within the specified range.
# Failed to fetch rating history for KNaga. Status code: 503
# simonmysun did not cross the rating margin within the specified range.
# Failed to fetch rating history for tutjae. Status code: 503
# Failed to fetch rating history for jiojiajiu. Status code: 503
# Failed to fetch rating history for nosoymijatola. Status code: 503
# 2018331116 did not cross the rating margin within the specified range.
# Failed to fetch rating history for HiBroxD. Status code: 503
# hilbertmf did not cross the rating margin within the specified range.
# lordvidex did not cross the rating margin within the specified range.
# Failed to fetch rating history for fuck_rating. Status code: 503
# Failed to fetch rating history for Baoheyhey. Status code: 503
# stpn129 did not cross the rating margin within the specified range.
# viv_codes did not cross the rating margin within the specified range.
# FrosT did not cross the rating margin within the specified range.
# Failed to fetch rating history for HImIK. Status code: 503
# ichattopadhyaya did not cross the rating margin within the specified range.
# ShorifulSoumic did not cross the rating margin within the specified range.
# Failed to fetch rating history for yvedryno. Status code: 503
# DarthSomnium did not cross the rating margin within the specified range.
# Failed to fetch rating history for Lucifer_09. Status code: 503
# Failed to fetch rating history for hachi557. Status code: 503
# souhibsaleh132 did not cross the rating margin within the specified range.
# Lavis did not cross the rating margin within the specified range.
# Failed to fetch rating history for TopSafder. Status code: 503
# Failed to fetch rating history for mahim.error. Status code: 503
# wrick did not cross the rating margin within the specified range.
# Lee2004 did not cross the rating margin within the specified range.
# samyak_uttam did not cross the rating margin within the specified range.
# Failed to fetch rating history for Zvirbulis. Status code: 503
# shubham2201 did not cross the rating margin within the specified range.
# Failed to fetch rating history for RajShkekhar. Status code: 503
# Failed to fetch rating history for you_know_me_right. Status code: 503
# jai_hanuman_orz did not cross the rating margin within the specified range.
# Failed to fetch rating history for minion30031. Status code: 503
# nonsense did not cross the rating margin within the specified range.
# pandoomanda did not cross the rating margin within the specified range.
# rahul1995 did not cross the rating margin within the specified range.
# Failed to fetch rating history for kitkat9. Status code: 503
# xyy920 did not cross the rating margin within the specified range.
# GUESSER2 did not cross the rating margin within the specified range.
# egor.okhterov did not cross the rating margin within the specified range.
# Failed to fetch rating history for Uttam678. Status code: 503
# WillM did not cross the rating margin within the specified range.
# Failed to fetch rating history for alina.skvorcova. Status code: 503
# l_FoRbIdDeN_l did not cross the rating margin within the specified range.
# vafinaynurli1 did not cross the rating margin within the specified range.
# Lucky_Noob did not cross the rating margin within the specified range.
# Failed to fetch rating history for gabrudj. Status code: 503
# my_name_ did not cross the rating margin within the specified range.
# Failed to fetch rating history for poltor97. Status code: 503
# the_dark_kai_9 did not cross the rating margin within the specified range.
# Failed to fetch rating history for iooM. Status code: 503
# Anderswl did not cross the rating margin within the specified range.
# Failed to fetch rating history for struggling. Status code: 503
# Sxy_Limit did not cross the rating margin within the specified range.
# NguyenDucThanh did not cross the rating margin within the specified range.
# re2044 did not cross the rating margin within the specified range.
# alicezhang05 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Nestor1509. Status code: 503
# TheLich did not cross the rating margin within the specified range.
# ME-CA-NICA11 did not cross the rating margin within the specified range.
# Failed to fetch rating history for NOxBODY. Status code: 503
# Failed to fetch rating history for caphile98. Status code: 503
# vixx_ did not cross the rating margin within the specified range.
# Kishansingh47 did not cross the rating margin within the specified range.
# Mohammad_Shahrear did not cross the rating margin within the specified range.
# makcanik did not cross the rating margin within the specified range.
# Akarachudra did not cross the rating margin within the specified range.
# Failed to fetch rating history for karia. Status code: 503
# tonywayne123 did not cross the rating margin within the specified range.
# Failed to fetch rating history for jyx123. Status code: 503
# Loganwick did not cross the rating margin within the specified range.
# Fuehrer7 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Zero_to_Zero. Status code: 503
# PSG.LGD.Maybe did not cross the rating margin within the specified range.
# Failed to fetch rating history for akbar19. Status code: 503
# Failed to fetch rating history for hdn. Status code: 503
# kid_de did not cross the rating margin within the specified range.
# Failed to fetch rating history for anim786sharma. Status code: 503
# Failed to fetch rating history for ghost_00. Status code: 503
# Lei_Xufei did not cross the rating margin within the specified range.
# Failed to fetch rating history for MrChepe. Status code: 503
# Sriram96 did not cross the rating margin within the specified range.
# kshitiz1007 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Praveen2002. Status code: 503
# Failed to fetch rating history for RezRhyme. Status code: 503
# nipun753 did not cross the rating margin within the specified range.
# taki_3 did not cross the rating margin within the specified range.
# ahsan_prantik did not cross the rating margin within the specified range.
# kris48k did not cross the rating margin within the specified range.
# Failed to fetch rating history for Syeda_Raisa_Rahman. Status code: 503
# SebasKoria did not cross the rating margin within the specified range.
# wojiushilym123 did not cross the rating margin within the specified range.
# harry1995 did not cross the rating margin within the specified range.
# karroum did not cross the rating margin within the specified range.
# Akif_Azwad did not cross the rating margin within the specified range.
# Failed to fetch rating history for abhi97. Status code: 503
# Failed to fetch rating history for LordShrunkenant. Status code: 503
# avb008 did not cross the rating margin within the specified range.
# Sarcastic_Nastik did not cross the rating margin within the specified range.
# svinota did not cross the rating margin within the specified range.
# Superaleks did not cross the rating margin within the specified range.
# enter_handle did not cross the rating margin within the specified range.
# Failed to fetch rating history for strong_wings. Status code: 503
# MartiBook did not cross the rating margin within the specified range.
# nickus did not cross the rating margin within the specified range.
# Failed to fetch rating history for zwu_2018010492. Status code: 503
# IcanBEyourHero did not cross the rating margin within the specified range.
# jeanfack did not cross the rating margin within the specified range.
# 650iq did not cross the rating margin within the specified range.
# Failed to fetch rating history for krishna-10. Status code: 503
# Kratos_2604 did not cross the rating margin within the specified range.
# Vadim_Akimov did not cross the rating margin within the specified range.
# tanpeep did not cross the rating margin within the specified range.
# Failed to fetch rating history for NPC404. Status code: 503
# skull2106 did not cross the rating margin within the specified range.
# Looping did not cross the rating margin within the specified range.
# Failed to fetch rating history for veenitshukla20. Status code: 503
# manhtien did not cross the rating margin within the specified range.
# Failed to fetch rating history for bits0803. Status code: 503
# Failed to fetch rating history for pikachu365. Status code: 503
# wcytql did not cross the rating margin within the specified range.
# Sofianelewin did not cross the rating margin within the specified range.
# Failed to fetch rating history for manaranjanfav. Status code: 503
# abhi_shk27 did not cross the rating margin within the specified range.
# Failed to fetch rating history for blank22. Status code: 503
# strglntoexist did not cross the rating margin within the specified range.
# parth.m did not cross the rating margin within the specified range.
# kubik369 did not cross the rating margin within the specified range.
# achkoz did not cross the rating margin within the specified range.
# Failed to fetch rating history for kotprogrammist. Status code: 503
# pawanmsr did not cross the rating margin within the specified range.
# Failed to fetch rating history for Anik_MBSTU. Status code: 503
# kabir10 did not cross the rating margin within the specified range.
# Gigi11235 did not cross the rating margin within the specified range.
# Failed to fetch rating history for akshatbhutra. Status code: 503
# SomeGuyTookMyHandleToo did not cross the rating margin within the specified range.
# Failed to fetch rating history for sg0310461. Status code: 503
# CP_Sucks did not cross the rating margin within the specified range.
# pcruiher08 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Black_ShadowX. Status code: 503
# Usb-C did not cross the rating margin within the specified range.
# SanjidaAhmed did not cross the rating margin within the specified range.
# imstark007 did not cross the rating margin within the specified range.
# VTN_21 did not cross the rating margin within the specified range.
# Avinvini did not cross the rating margin within the specified range.
# Failed to fetch rating history for tomaso. Status code: 503
# yogesh9535 did not cross the rating margin within the specified range.
# Showgo178 did not cross the rating margin within the specified range.
# revanth9 did not cross the rating margin within the specified range.
# Mahmoud_Abd_El_Salam did not cross the rating margin within the specified range.
# RI3C did not cross the rating margin within the specified range.
# talha_iiita did not cross the rating margin within the specified range.
# perec1970 did not cross the rating margin within the specified range.
# Failed to fetch rating history for rsFalse. Status code: 503
# Loner_Knowledge did not cross the rating margin within the specified range.
# Liu_Xuanyao did not cross the rating margin within the specified range.
# mehdidamascus did not cross the rating margin within the specified range.
# Failed to fetch rating history for the__smasher. Status code: 503
# AnubhavPaul did not cross the rating margin within the specified range.
# _peacock did not cross the rating margin within the specified range.
# propashii did not cross the rating margin within the specified range.
# Failed to fetch rating history for AliAbdallah. Status code: 503
# uhtred did not cross the rating margin within the specified range.
# Failed to fetch rating history for hilbert12. Status code: 503
# Avlek did not cross the rating margin within the specified range.
# aaamiiiiii did not cross the rating margin within the specified range.
# gn25 did not cross the rating margin within the specified range.
# Uchiha... did not cross the rating margin within the specified range.
# Failed to fetch rating history for chandubaba. Status code: 503
# dhruvbhimani2512 did not cross the rating margin within the specified range.
# Failed to fetch rating history for phantomphoton_. Status code: 503
# srn did not cross the rating margin within the specified range.
# Sweat_TiT did not cross the rating margin within the specified range.
# azizbekmuminov_1 did not cross the rating margin within the specified range.
# Failed to fetch rating history for code_zerro. Status code: 503
# trubor did not cross the rating margin within the specified range.
# Failed to fetch rating history for Ernar17. Status code: 503
# amir.wpf did not cross the rating margin within the specified range.
# laboni_ansary did not cross the rating margin within the specified range.
# Failed to fetch rating history for froggy445. Status code: 503
# Aldijohn did not cross the rating margin within the specified range.
# elistark did not cross the rating margin within the specified range.
# LiaoJingyi did not cross the rating margin within the specified range.
# Failed to fetch rating history for GarbageValue. Status code: 503
# manohar_9 did not cross the rating margin within the specified range.
# Ryd did not cross the rating margin within the specified range.
# debug did not cross the rating margin within the specified range.
# Failed to fetch rating history for hoseingh.elahi. Status code: 503
# Ruban_Denic did not cross the rating margin within the specified range.
# OmarSaber did not cross the rating margin within the specified range.
# umme_habiba16 did not cross the rating margin within the specified range.
# Failed to fetch rating history for dusht0814. Status code: 503
# psychewolf did not cross the rating margin within the specified range.
# Failed to fetch rating history for The_Dragon_Warrior. Status code: 503
# drifter_kabir did not cross the rating margin within the specified range.
# Dukkha did not cross the rating margin within the specified range.
# isaba09 did not cross the rating margin within the specified range.
# aabbcc123 did not cross the rating margin within the specified range.
# 2018331124 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Roman_Serbul. Status code: 503
# sparsheatu did not cross the rating margin within the specified range.
# abhatter did not cross the rating margin within the specified range.
# Failed to fetch rating history for return_aim. Status code: 503
# Sorry_Formatci did not cross the rating margin within the specified range.
# Failed to fetch rating history for dn0pf902. Status code: 503
#                        Handle  Max Rating Result
# 0                cshrivastava        1549     No
# 1                    mitchelz        1421     No
# 2                  sreeharsha        1444     No
# 3                       wejih        1440    Yes
# 4    Naam_me_kya_hi_rakha_hai        1465    Yes
# ..                        ...         ...    ...
# 454              MisterReaper        1637     No
# 455                  homebrew        1627     No
# 456            Sorry_Formatci        1823    N/A
# 457                  dn0pf902        1470    N/A
# 458                  tibinyte        1609     No
#
# [459 rows x 3 columns]
