# %%
import requests
from datetime import datetime
import pandas as pd
df=pd.read_csv('df17.csv')
import json
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1200
    target_upper = 1400

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 20 <= days_taken <= 40:
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
df.to_csv('outdf17.csv', index=False)
# Out:
# Failed to fetch rating history for shadowRanYe. Status code: 503
# Failed to fetch rating history for vitosevski. Status code: 503
# Djhoker did not cross the rating margin within the specified range.
# Failed to fetch rating history for Rittin_Sehgal. Status code: 503
# Failed to fetch rating history for montonic. Status code: 503
# Failed to fetch rating history for shaomx. Status code: 503
# sr_hossain did not cross the rating margin within the specified range.
# Failed to fetch rating history for thumbass. Status code: 503
# Failed to fetch rating history for AnanasClassic. Status code: 503
# Failed to fetch rating history for FYBGC. Status code: 503
# Failed to fetch rating history for Maxwell01. Status code: 503
# Failed to fetch rating history for Poseidon.. Status code: 503
# Failed to fetch rating history for dlckswns. Status code: 503
# Failed to fetch rating history for sneha_chembeti. Status code: 503
# Failed to fetch rating history for 88ion. Status code: 503
# Failed to fetch rating history for Jakosa_ko_osaga. Status code: 503
# OLIN_ONE did not cross the rating margin within the specified range.
# Failed to fetch rating history for megaminion. Status code: 503
# Failed to fetch rating history for spreetdbhedbd. Status code: 503
# Failed to fetch rating history for suprit.s21. Status code: 503
# 2005zhw did not cross the rating margin within the specified range.
# Failed to fetch rating history for CN__Pro__Coder. Status code: 503
# Failed to fetch rating history for Linver. Status code: 503
# Failed to fetch rating history for Octanoic. Status code: 503
# Failed to fetch rating history for _ayushpatidar18. Status code: 503
# Failed to fetch rating history for andyp3. Status code: 503
# dmesadiaz did not cross the rating margin within the specified range.
# Failed to fetch rating history for efishel. Status code: 503
# Failed to fetch rating history for sjxcxz. Status code: 503
# Failed to fetch rating history for Damirem. Status code: 503
# Marcelolfz did not cross the rating margin within the specified range.
# Failed to fetch rating history for Rahul_Nikhate. Status code: 503
# Failed to fetch rating history for Tatsugiri. Status code: 503
# Failed to fetch rating history for abdalrahem.r.dado. Status code: 503
# Failed to fetch rating history for buburibu1234. Status code: 503
# czar_ime did not cross the rating margin within the specified range.
# Failed to fetch rating history for hemantpatil10125. Status code: 503
# hunghoang did not cross the rating margin within the specified range.
# Failed to fetch rating history for karlamun. Status code: 503
# Failed to fetch rating history for sksx085. Status code: 503
# Failed to fetch rating history for KaukuzzOwO. Status code: 503
# Failed to fetch rating history for Super_Misha. Status code: 503
# _santyssk_ did not cross the rating margin within the specified range.
# Failed to fetch rating history for akash_singh25. Status code: 503
# Failed to fetch rating history for dpd. Status code: 503
# rolandorh did not cross the rating margin within the specified range.
# Failed to fetch rating history for Christopher_Rdz. Status code: 503
# Ghayth.Moustapha did not cross the rating margin within the specified range.
# Failed to fetch rating history for Insane_110. Status code: 503
# Failed to fetch rating history for anominos. Status code: 503
# Failed to fetch rating history for Big_Feky. Status code: 503
# Failed to fetch rating history for Mudit_Loya. Status code: 503
# Failed to fetch rating history for akshin_. Status code: 503
# Failed to fetch rating history for antonov1lya. Status code: 503
# Failed to fetch rating history for fominmaxim3721. Status code: 503
# Failed to fetch rating history for kartikey_5960. Status code: 503
# Failed to fetch rating history for tanmay2808. Status code: 503
# Failed to fetch rating history for LJB00126. Status code: 503
# Failed to fetch rating history for NishuSharma. Status code: 503
# RAKIB_107 did not cross the rating margin within the specified range.
# Failed to fetch rating history for _Shimla_05_. Status code: 503
# Failed to fetch rating history for eanvarov09. Status code: 503
# Failed to fetch rating history for materekh. Status code: 503
# Failed to fetch rating history for root-shafi. Status code: 503
# Failed to fetch rating history for singh.bhanu568. Status code: 503
# Failed to fetch rating history for the_programeitor. Status code: 503
# Failed to fetch rating history for Asnkkzk. Status code: 503
# Failed to fetch rating history for Herb. Status code: 503
# Failed to fetch rating history for anugam_jain. Status code: 503
# Failed to fetch rating history for madarchod_RAP. Status code: 503
# Failed to fetch rating history for rohit1786. Status code: 503
# Failed to fetch rating history for 1723yangke. Status code: 503
# Failed to fetch rating history for M00li. Status code: 503
# Failed to fetch rating history for Sovi11. Status code: 503
# Failed to fetch rating history for hack41. Status code: 503
# Failed to fetch rating history for moonjihwan. Status code: 503
# Failed to fetch rating history for rcht. Status code: 503
# Failed to fetch rating history for vrehg. Status code: 503
# Failed to fetch rating history for zieve. Status code: 503
# Failed to fetch rating history for 7dharsh. Status code: 503
# Failed to fetch rating history for DSP-friendly. Status code: 503
# Failed to fetch rating history for IMackerI. Status code: 503
# Failed to fetch rating history for NeikuiColacat. Status code: 503
# Failed to fetch rating history for ShenQing. Status code: 503
# Failed to fetch rating history for garf1e1d. Status code: 503
# Failed to fetch rating history for hanage. Status code: 503
# Failed to fetch rating history for meimingzi1. Status code: 503
# Failed to fetch rating history for nikaru.Hakamura. Status code: 503
# rainbow_eating_cat did not cross the rating margin within the specified range.
# Failed to fetch rating history for shane245. Status code: 503
# songhongyi did not cross the rating margin within the specified range.
# Failed to fetch rating history for Big.Smoke. Status code: 503
# Failed to fetch rating history for December456. Status code: 503
# Failed to fetch rating history for MihirVai. Status code: 503
# Failed to fetch rating history for San_jida. Status code: 503
# Failed to fetch rating history for Yash_Tulsani. Status code: 503
# Failed to fetch rating history for bean3. Status code: 503
# Failed to fetch rating history for dkwhahaha. Status code: 503
# Failed to fetch rating history for lg040815. Status code: 503
# Failed to fetch rating history for nayeem2021. Status code: 503
# Failed to fetch rating history for wudya. Status code: 503
# Failed to fetch rating history for Colebum_20. Status code: 503
# Failed to fetch rating history for HEARTOWAVE. Status code: 503
# Failed to fetch rating history for SnowFlake_35. Status code: 503
# adi-vc did not cross the rating margin within the specified range.
# Failed to fetch rating history for chrysalis. Status code: 503
# Failed to fetch rating history for hk_brave. Status code: 503
# Failed to fetch rating history for nightcrawler0112. Status code: 503
# Failed to fetch rating history for spardhyer. Status code: 503
# Failed to fetch rating history for yyyyyd. Status code: 503
# Failed to fetch rating history for KocherginDaniil. Status code: 503
# Failed to fetch rating history for MrNanama. Status code: 503
# Failed to fetch rating history for aleonov. Status code: 503
# Failed to fetch rating history for grente. Status code: 503
# Failed to fetch rating history for math_hater. Status code: 503
# Failed to fetch rating history for mradul3703. Status code: 503
# Failed to fetch rating history for ravikjha7. Status code: 503
# Failed to fetch rating history for 3inf. Status code: 503
# Failed to fetch rating history for Chiho. Status code: 503
# Failed to fetch rating history for InamiAnju. Status code: 503
# Failed to fetch rating history for Poliker. Status code: 503
# Failed to fetch rating history for Rainhunter. Status code: 503
# Failed to fetch rating history for VinCenzo___. Status code: 503
# Failed to fetch rating history for _bverma512. Status code: 503
# Failed to fetch rating history for itscyclone. Status code: 503
# lnkkerst did not cross the rating margin within the specified range.
# Failed to fetch rating history for saagar2002. Status code: 503
# Failed to fetch rating history for sukaya. Status code: 503
# Failed to fetch rating history for walilili. Status code: 503
# Failed to fetch rating history for KaiYuan00. Status code: 503
# Failed to fetch rating history for WTH_LK. Status code: 503
# Failed to fetch rating history for kwothe. Status code: 503
# Failed to fetch rating history for mmaiti627. Status code: 503
# Failed to fetch rating history for sayan_b. Status code: 503
# Failed to fetch rating history for wly_sh. Status code: 503
# Failed to fetch rating history for Gr1nd_Maester. Status code: 503
# Failed to fetch rating history for Mohamed_Hamed. Status code: 503
# Failed to fetch rating history for arrey. Status code: 503
# Failed to fetch rating history for mvaja13. Status code: 503
# Failed to fetch rating history for poddar_28. Status code: 503
# Failed to fetch rating history for Hamdy_Salem. Status code: 503
# Failed to fetch rating history for Negm. Status code: 503
# Failed to fetch rating history for Yuvraj_Patel_30903. Status code: 503
# Failed to fetch rating history for samakshd. Status code: 503
# Failed to fetch rating history for squangg1701. Status code: 503
# xlz did not cross the rating margin within the specified range.
# Failed to fetch rating history for FateWielder. Status code: 503
# Failed to fetch rating history for IvanAndrei. Status code: 503
# Jose_Juan__SE did not cross the rating margin within the specified range.
# Failed to fetch rating history for Rezhou. Status code: 503
# Failed to fetch rating history for codedstrwahat. Status code: 503
# Failed to fetch rating history for hpquoc06dona. Status code: 503
# Failed to fetch rating history for iamaa_izuku. Status code: 503
# kctong529 did not cross the rating margin within the specified range.
# Failed to fetch rating history for lh_118. Status code: 503
# Failed to fetch rating history for 3inh. Status code: 503
# Al4 did not cross the rating margin within the specified range.
# Failed to fetch rating history for AmirMoris. Status code: 503
# Failed to fetch rating history for FanaticHound. Status code: 503
# Gacon did not cross the rating margin within the specified range.
# Failed to fetch rating history for InHng_. Status code: 503
# Failed to fetch rating history for NikhilSharma26. Status code: 503
# Failed to fetch rating history for Parag_AP. Status code: 503
# ankit-SM did not cross the rating margin within the specified range.
# Failed to fetch rating history for erikmetargon. Status code: 503
# Failed to fetch rating history for lonewolf154. Status code: 503
# Failed to fetch rating history for qiqinanzijing. Status code: 503
# Failed to fetch rating history for superhacker17. Status code: 503
# Failed to fetch rating history for vidz1. Status code: 503
# Failed to fetch rating history for D_coder22. Status code: 503
# Failed to fetch rating history for Pakpim. Status code: 503
# Failed to fetch rating history for dhairyamagnetar. Status code: 503
# Failed to fetch rating history for ekbachha. Status code: 503
# Failed to fetch rating history for mH4S4N. Status code: 503
# Failed to fetch rating history for shreeya_08. Status code: 503
# Failed to fetch rating history for ytxupw. Status code: 503
# Failed to fetch rating history for 2497201210. Status code: 503
# Failed to fetch rating history for Tharoboiz06. Status code: 503
# Failed to fetch rating history for okaragul. Status code: 503
#             Handle  Max Rating Result
# 0           Tandav        1531    Yes
# 1       close_fish        1480     No
# 2     electrojay27        1487    Yes
# 3      harshith_04        1606    Yes
# 4    jayantpranjal        1591     No
# ..             ...         ...    ...
# 495        WRuperD        1444     No
# 496    __ViLLiaN__        1515     No
# 497          gypsy        1657     No
# 498    hercules_04        1489     No
# 499       okaragul        1733    N/A
#
# [500 rows x 3 columns]
