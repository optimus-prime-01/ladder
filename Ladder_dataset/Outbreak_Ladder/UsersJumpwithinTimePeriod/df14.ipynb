# %%
import requests
from datetime import datetime
import pandas as pd
df=pd.read_csv('df14.csv')
import json
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1200
    target_upper = 1400

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 20 <= days_taken <= 40:
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
df.to_csv('outdf14.csv', index=False)
# Out:
# Failed to fetch rating history for vakhew1900. Status code: 503
# Failed to fetch rating history for 5k_sync_closer. Status code: 503
# Failed to fetch rating history for Nyanya_. Status code: 503
# Failed to fetch rating history for aplietexe. Status code: 503
# Failed to fetch rating history for tushar_104. Status code: 503
# Failed to fetch rating history for 996007. Status code: 503
# Failed to fetch rating history for DarK_SouL17. Status code: 503
# Failed to fetch rating history for Stortoise. Status code: 503
# Failed to fetch rating history for Vishnu767. Status code: 503
# Failed to fetch rating history for fitisovartyom123. Status code: 503
# Failed to fetch rating history for ollo. Status code: 503
# Failed to fetch rating history for Eftekhar_Nahim. Status code: 503
# Failed to fetch rating history for Nanuyyyy. Status code: 503
# Failed to fetch rating history for arodnap33. Status code: 503
# Failed to fetch rating history for itachi_1807. Status code: 503
# Failed to fetch rating history for rc_leon. Status code: 503
# Failed to fetch rating history for Captainfly. Status code: 503
# JakubLap did not cross the rating margin within the specified range.
# Failed to fetch rating history for MODDI. Status code: 503
# _Vadim_ did not cross the rating margin within the specified range.
# altbxy did not cross the rating margin within the specified range.
# 1271920576 did not cross the rating margin within the specified range.
# Failed to fetch rating history for NirbhayPaliwal. Status code: 503
# Failed to fetch rating history for antonio.mondejar. Status code: 503
# Failed to fetch rating history for gaud. Status code: 503
# Failed to fetch rating history for prabhatsingh21. Status code: 503
# somujena21 did not cross the rating margin within the specified range.
# Failed to fetch rating history for unknowndriver. Status code: 503
# Failed to fetch rating history for 1_Devil_1. Status code: 503
# Failed to fetch rating history for Izeed. Status code: 503
# Failed to fetch rating history for NenadDapic. Status code: 503
# Failed to fetch rating history for abobkr. Status code: 503
# Failed to fetch rating history for firizky. Status code: 503
# srossd did not cross the rating margin within the specified range.
# Failed to fetch rating history for vivkostov. Status code: 503
# Failed to fetch rating history for Classic_Adhom. Status code: 503
# FastPhysics did not cross the rating margin within the specified range.
# Failed to fetch rating history for proKodarKabra. Status code: 503
# Failed to fetch rating history for Bhargav4037. Status code: 503
# Failed to fetch rating history for TheAcrux. Status code: 503
# Failed to fetch rating history for deepakjsagarwal. Status code: 503
# Failed to fetch rating history for lujw. Status code: 503
# zhidian1 did not cross the rating margin within the specified range.
# Failed to fetch rating history for 2020liujinhan. Status code: 503
# Failed to fetch rating history for MasterVroom. Status code: 503
# Failed to fetch rating history for afeng111. Status code: 503
# Failed to fetch rating history for kgandhi22. Status code: 503
# mainex did not cross the rating margin within the specified range.
# Failed to fetch rating history for return_myself. Status code: 503
# Failed to fetch rating history for Blitz8301. Status code: 503
# Sitleman did not cross the rating margin within the specified range.
# Failed to fetch rating history for StranGePants. Status code: 503
# Failed to fetch rating history for passion_fruit. Status code: 503
# tranphuc8a did not cross the rating margin within the specified range.
# Chaves did not cross the rating margin within the specified range.
# Failed to fetch rating history for Southernwood. Status code: 503
# akwa_blue did not cross the rating margin within the specified range.
# Failed to fetch rating history for anymzx. Status code: 503
# javad_asadi did not cross the rating margin within the specified range.
# Failed to fetch rating history for lyxtyl. Status code: 503
# Failed to fetch rating history for wazz. Status code: 503
# wsk1202 did not cross the rating margin within the specified range.
# Failed to fetch rating history for ALESTA. Status code: 503
# Failed to fetch rating history for KK_1729. Status code: 503
# Failed to fetch rating history for Rip_Pro. Status code: 503
# Failed to fetch rating history for henriqueramos.qs. Status code: 503
# Failed to fetch rating history for nandapavan26. Status code: 503
# Failed to fetch rating history for qinglu09. Status code: 503
# 3013216027 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Jotinha. Status code: 503
# Failed to fetch rating history for ankan_0610. Status code: 503
# Failed to fetch rating history for saurabhs1206. Status code: 503
# Failed to fetch rating history for 863aditya. Status code: 503
# Failed to fetch rating history for FarFito. Status code: 503
# Failed to fetch rating history for QwQwf. Status code: 503
# Failed to fetch rating history for RealSnake. Status code: 503
# Failed to fetch rating history for atharvd. Status code: 503
# Failed to fetch rating history for beethOWEN. Status code: 503
# lanbae did not cross the rating margin within the specified range.
# Failed to fetch rating history for magga. Status code: 503
# mc_rodrix99 did not cross the rating margin within the specified range.
# Failed to fetch rating history for midsho. Status code: 503
# Failed to fetch rating history for priyanshbarya. Status code: 503
# Failed to fetch rating history for LeoG. Status code: 503
# Failed to fetch rating history for kosakkun. Status code: 503
# manzano did not cross the rating margin within the specified range.
# Failed to fetch rating history for pranavb.02. Status code: 503
# rifat6 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Ayush74. Status code: 503
# Failed to fetch rating history for IIIIIlIIIl. Status code: 503
# Failed to fetch rating history for SaiAnoop. Status code: 503
# Sunward_z did not cross the rating margin within the specified range.
# Failed to fetch rating history for VincentK. Status code: 503
# Failed to fetch rating history for aniruddhmodi03. Status code: 503
# ruban did not cross the rating margin within the specified range.
# Failed to fetch rating history for shaanjijoe2. Status code: 503
# sxrcodeforces did not cross the rating margin within the specified range.
# Failed to fetch rating history for AKM17. Status code: 503
# Failed to fetch rating history for E.lena. Status code: 503
# Litvin_Vlad did not cross the rating margin within the specified range.
# Failed to fetch rating history for Palmerin. Status code: 503
# Failed to fetch rating history for gelbelachente. Status code: 503
# ladisgin did not cross the rating margin within the specified range.
# nomiku99 did not cross the rating margin within the specified range.
# Failed to fetch rating history for AprLsity. Status code: 503
# Failed to fetch rating history for alex0511. Status code: 503
# shivamsalil did not cross the rating margin within the specified range.
# Failed to fetch rating history for Basekill. Status code: 503
# Benny20 did not cross the rating margin within the specified range.
# Failed to fetch rating history for K_sakkary. Status code: 503
# RBpencil did not cross the rating margin within the specified range.
# Failed to fetch rating history for Starswap. Status code: 503
# Failed to fetch rating history for catandcode. Status code: 503
# Failed to fetch rating history for halehu. Status code: 503
# Failed to fetch rating history for slappy. Status code: 503
# Failed to fetch rating history for Carl_Hu. Status code: 503
# CrispOuO did not cross the rating margin within the specified range.
# Failed to fetch rating history for __LAKSHAY__. Status code: 503
# Failed to fetch rating history for ankush.tyagi.07. Status code: 503
# Failed to fetch rating history for Advaid. Status code: 503
# Failed to fetch rating history for MojoLake. Status code: 503
# Failed to fetch rating history for juancs. Status code: 503
# mpanyavin did not cross the rating margin within the specified range.
# Failed to fetch rating history for nevikw39. Status code: 503
# Failed to fetch rating history for uttam20. Status code: 503
# Failed to fetch rating history for American_Eagle. Status code: 503
# Failed to fetch rating history for aaaaaac. Status code: 503
# agarwalaswastik did not cross the rating margin within the specified range.
# Failed to fetch rating history for nondeterministic. Status code: 503
# Failed to fetch rating history for Dhruv-Singh-Negi. Status code: 503
# Failed to fetch rating history for Norvezhskaya_8-klassnica. Status code: 503
# altais did not cross the rating margin within the specified range.
# Failed to fetch rating history for andriy.borzenkov. Status code: 503
# Failed to fetch rating history for puspendra_09. Status code: 503
# .Eddy did not cross the rating margin within the specified range.
# Cmndr_Salamander did not cross the rating margin within the specified range.
# Failed to fetch rating history for Gamakatsu. Status code: 503
# creampuffshu did not cross the rating margin within the specified range.
# Failed to fetch rating history for cyan0515. Status code: 503
# linwenqi did not cross the rating margin within the specified range.
#            Handle  Max Rating Result
# 0        Tvduring        1576     No
# 1            Y_LX        1687     No
# 2     __Tanzeel__        1742    Yes
# 3       amineriwa        1634     No
# 4      andy0liang        1620     No
# ..            ...         ...    ...
# 495          __AA        1517     No
# 496  creampuffshu        1639    N/A
# 497      cyan0515        1517    N/A
# 498      jontybot        1517     No
# 499      linwenqi        1684    N/A
#
# [500 rows x 3 columns]
