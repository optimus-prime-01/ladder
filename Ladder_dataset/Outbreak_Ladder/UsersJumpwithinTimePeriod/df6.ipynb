# %%
import requests
from datetime import datetime
import pandas as pd

# %%
df=pd.read_csv('df6.csv')

# %%
import json
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1200
    target_upper = 1400

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 20 <= days_taken <= 40:
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
# Out:
# rainboy did not cross the rating margin within the specified range.
# A.Kaan37 did not cross the rating margin within the specified range.
# Failed to fetch rating history for LaPluma. Status code: 503
# Failed to fetch rating history for Mar1gold. Status code: 503
# Failed to fetch rating history for alinp. Status code: 503
# Failed to fetch rating history for mxfld. Status code: 503
# Failed to fetch rating history for Go8. Status code: 503
# Failed to fetch rating history for Angriliset. Status code: 503
# Failed to fetch rating history for NanQin. Status code: 503
# Failed to fetch rating history for hztmax_zero. Status code: 503
# withinlover did not cross the rating margin within the specified range.
# Failed to fetch rating history for Rayanx. Status code: 503
# poplpr did not cross the rating margin within the specified range.
# Failed to fetch rating history for QuandaleDingle. Status code: 503
# Failed to fetch rating history for adityagamer. Status code: 503
# skeep194 did not cross the rating margin within the specified range.
# Failed to fetch rating history for xu826281112. Status code: 503
# Failed to fetch rating history for Zxcigan. Status code: 503
# Apachee did not cross the rating margin within the specified range.
# HMAXS did not cross the rating margin within the specified range.
# Failed to fetch rating history for Macrosteam. Status code: 503
# 3fukin did not cross the rating margin within the specified range.
# Failed to fetch rating history for Sbak. Status code: 503
# xtremegamer2k19 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Kither. Status code: 503
# STommydx did not cross the rating margin within the specified range.
# alavrov did not cross the rating margin within the specified range.
# bitoy did not cross the rating margin within the specified range.
# GTR.3910 did not cross the rating margin within the specified range.
# k1rill_fedoseev did not cross the rating margin within the specified range.
# yuanyuxuan did not cross the rating margin within the specified range.
# Harmony_ did not cross the rating margin within the specified range.
# Hasib_16 did not cross the rating margin within the specified range.
# PiscesDream did not cross the rating margin within the specified range.
# Failed to fetch rating history for rek. Status code: 503
# MinhazIbnMizan did not cross the rating margin within the specified range.
# TakeMe did not cross the rating margin within the specified range.
# Failed to fetch rating history for rushitote. Status code: 503
# sumit_kk10 did not cross the rating margin within the specified range.
# Failed to fetch rating history for H2J. Status code: 503
# Failed to fetch rating history for julinek. Status code: 503
# liaojiqing did not cross the rating margin within the specified range.
# dmlocdmloc did not cross the rating margin within the specified range.
# Failed to fetch rating history for Coder_Fang. Status code: 503
# Failed to fetch rating history for _Gawd_. Status code: 503
# seeeeeeven7 did not cross the rating margin within the specified range.
# shojin_pro did not cross the rating margin within the specified range.
# Failed to fetch rating history for EnonyaBTe. Status code: 503
# Failed to fetch rating history for Paranoid-LS. Status code: 503
# Rippr did not cross the rating margin within the specified range.
# Failed to fetch rating history for big_owner. Status code: 503
# rohan.p did not cross the rating margin within the specified range.
# .Nik. did not cross the rating margin within the specified range.
# QuinnG did not cross the rating margin within the specified range.
# wtz2333 did not cross the rating margin within the specified range.
# Failed to fetch rating history for xenofil. Status code: 503
# Failed to fetch rating history for hanchangseo. Status code: 503
# Failed to fetch rating history for shubhargava. Status code: 503
# zilioner did not cross the rating margin within the specified range.
# Failed to fetch rating history for Emy_Ycc. Status code: 503
# only_xiaohuang did not cross the rating margin within the specified range.
# Failed to fetch rating history for wallacelw. Status code: 503
# Failed to fetch rating history for 2114992323. Status code: 503
# Failed to fetch rating history for Anemone_. Status code: 503
# Failed to fetch rating history for maraHuaAadmi. Status code: 503
# Failed to fetch rating history for regain0002. Status code: 503
# LightBrand99 did not cross the rating margin within the specified range.
# Failed to fetch rating history for OctoberEstuary. Status code: 503
# Failed to fetch rating history for ZhanqiWang. Status code: 503
# Failed to fetch rating history for panhuachao. Status code: 503
# Lin1043 did not cross the rating margin within the specified range.
# Failed to fetch rating history for _C_O_D_E_F_O_R_C_E_S_. Status code: 503
# Failed to fetch rating history for ggboyy. Status code: 503
# Failed to fetch rating history for shreyanshshikhar2910. Status code: 503
# zengzk did not cross the rating margin within the specified range.
# Failed to fetch rating history for JorD. Status code: 503
# PaoloB did not cross the rating margin within the specified range.
# Failed to fetch rating history for chillhouse7773. Status code: 503
# Failed to fetch rating history for efe0. Status code: 503
# Failed to fetch rating history for Amanydv0081. Status code: 503
# Failed to fetch rating history for Pavarishko. Status code: 503
# Failed to fetch rating history for Ryuga_. Status code: 503
# Failed to fetch rating history for i_just_practice. Status code: 503
# pill did not cross the rating margin within the specified range.
# Failed to fetch rating history for Ghulam_Junaid. Status code: 503
# Vaness did not cross the rating margin within the specified range.
# Failed to fetch rating history for ayush_raj.21. Status code: 503
# Failed to fetch rating history for rsa_op. Status code: 503
# Failed to fetch rating history for BDFCL. Status code: 503
# Failed to fetch rating history for Hanari. Status code: 503
# Failed to fetch rating history for weakweakweak. Status code: 503
# Failed to fetch rating history for DevMAG. Status code: 503
# Failed to fetch rating history for AllDirections. Status code: 503
# Failed to fetch rating history for Georggg999. Status code: 503
# Failed to fetch rating history for Kusmir. Status code: 503
# Failed to fetch rating history for ereoth. Status code: 503
# Failed to fetch rating history for li_yuang. Status code: 503
# Failed to fetch rating history for Habibulda. Status code: 503
# Failed to fetch rating history for YazanAlattar. Status code: 503
# Failed to fetch rating history for tdsb. Status code: 503
# Failed to fetch rating history for yy__zq. Status code: 503
# Failed to fetch rating history for Lemontea_. Status code: 503
# Failed to fetch rating history for NourhanHanna. Status code: 503
# Failed to fetch rating history for Raywithyou. Status code: 503
# Failed to fetch rating history for ktq_cpp. Status code: 503
# kylych03 did not cross the rating margin within the specified range.
# Failed to fetch rating history for linxd. Status code: 503
# Failed to fetch rating history for rakshith21mohan. Status code: 503
# Failed to fetch rating history for Aaron_wch. Status code: 503
# Failed to fetch rating history for RGB_ICPC6. Status code: 503
# Failed to fetch rating history for EasonCookie197. Status code: 503
# Maksimka_coolhacker did not cross the rating margin within the specified range.
# Failed to fetch rating history for bashem. Status code: 503
# Failed to fetch rating history for dbaumg. Status code: 503
# gabmei did not cross the rating margin within the specified range.
# Failed to fetch rating history for xelsink1. Status code: 503
# ant.ermilov did not cross the rating margin within the specified range.
# disjointset did not cross the rating margin within the specified range.
# Failed to fetch rating history for ohmygodtosbryantooorz. Status code: 503
# Failed to fetch rating history for ZhangwuKitten. Status code: 503
# figdan did not cross the rating margin within the specified range.
# Failed to fetch rating history for krigare. Status code: 503
# lobserver did not cross the rating margin within the specified range.
# Failed to fetch rating history for robert.barbu27. Status code: 503
# Failed to fetch rating history for carlosad1. Status code: 503
# Failed to fetch rating history for dantoper556. Status code: 503
# Failed to fetch rating history for tanaka255. Status code: 503
# Failed to fetch rating history for __Shinigami__. Status code: 503
# Failed to fetch rating history for molhaam1. Status code: 503
# Failed to fetch rating history for nelch. Status code: 503
# nibabin did not cross the rating margin within the specified range.
# Failed to fetch rating history for saturnbored. Status code: 503
# Failed to fetch rating history for SUZUKO_DAZE. Status code: 503
# Failed to fetch rating history for Serik2003. Status code: 503
# Vequis did not cross the rating margin within the specified range.
# Failed to fetch rating history for cocomos. Status code: 503
# Failed to fetch rating history for CWJ_123. Status code: 503
# Mirbek did not cross the rating margin within the specified range.
# Failed to fetch rating history for OutsiderZz. Status code: 503
# Failed to fetch rating history for cheng1202. Status code: 503
# Failed to fetch rating history for fattybug. Status code: 503
# Failed to fetch rating history for lucassala. Status code: 503
# Failed to fetch rating history for 233L. Status code: 503
# Failed to fetch rating history for ArgintLaAnu. Status code: 503
# Failed to fetch rating history for astilate. Status code: 503
# Failed to fetch rating history for Shirotsume. Status code: 503
# coderbd did not cross the rating margin within the specified range.
# Failed to fetch rating history for luanyi. Status code: 503
# Failed to fetch rating history for EgorSav. Status code: 503
# Failed to fetch rating history for Litusiano_. Status code: 503
# Tagl did not cross the rating margin within the specified range.
# Failed to fetch rating history for kazeninvladimir. Status code: 503
# Failed to fetch rating history for ringup. Status code: 503
# Failed to fetch rating history for yunetive29. Status code: 503
# AcPlusOne did not cross the rating margin within the specified range.
# Failed to fetch rating history for Farhan20. Status code: 503
# Failed to fetch rating history for tejpavan. Status code: 503
# Failed to fetch rating history for KlayThompson11. Status code: 503
# Failed to fetch rating history for ivls. Status code: 503
# vit_72 did not cross the rating margin within the specified range.
# Failed to fetch rating history for zxx. Status code: 503
# Failed to fetch rating history for Leonardo_Toral. Status code: 503
# mkisic did not cross the rating margin within the specified range.
# Failed to fetch rating history for scotchtape13. Status code: 503
# Failed to fetch rating history for Bailyeden. Status code: 503
# LovelyFairy did not cross the rating margin within the specified range.
# Failed to fetch rating history for VahanAbraham. Status code: 503
# Failed to fetch rating history for null0124. Status code: 503
# tanvirtareq did not cross the rating margin within the specified range.
# Failed to fetch rating history for withher. Status code: 503
# 0Oo.oO0 did not cross the rating margin within the specified range.
# Failed to fetch rating history for doccocaubai. Status code: 503
# Failed to fetch rating history for n_m_p. Status code: 503
# Khaled_Mardini did not cross the rating margin within the specified range.
# Failed to fetch rating history for Shielder. Status code: 503
# Failed to fetch rating history for canidae. Status code: 503
# Failed to fetch rating history for de_coding_life. Status code: 503
# Failed to fetch rating history for ramaaa. Status code: 503
# Failed to fetch rating history for zhangzhimo. Status code: 503
# Failed to fetch rating history for MOD-Essam. Status code: 503
# an_interesting_name did not cross the rating margin within the specified range.
# Failed to fetch rating history for clean100s. Status code: 503
# Failed to fetch rating history for ekys. Status code: 503
# Failed to fetch rating history for njustbacon. Status code: 503
# Failed to fetch rating history for Crypthicc. Status code: 503
# TamimEhsan did not cross the rating margin within the specified range.
# Failed to fetch rating history for ZzRuiKai. Status code: 503
# Failed to fetch rating history for secret-550504. Status code: 503
# Failed to fetch rating history for GennadiySosnov. Status code: 503
# Failed to fetch rating history for Ngeces. Status code: 503
# Failed to fetch rating history for Sai-17. Status code: 503
# Failed to fetch rating history for pskobx. Status code: 503
# Failed to fetch rating history for A_Very_Serious_Man. Status code: 503
# Failed to fetch rating history for _Aghost. Status code: 503
# yanke did not cross the rating margin within the specified range.
# Failed to fetch rating history for Bharath_1729. Status code: 503
# Failed to fetch rating history for Bogdan_fake. Status code: 503
# Failed to fetch rating history for Sleekassassin. Status code: 503
# Failed to fetch rating history for bianyuxuan. Status code: 503
# Failed to fetch rating history for kawaii0922. Status code: 503
# Failed to fetch rating history for xiaoququsd. Status code: 503
# Failed to fetch rating history for Abhishek_Srivastava. Status code: 503
# FedeNQ did not cross the rating margin within the specified range.
# Failed to fetch rating history for Mikunyan. Status code: 503
# Failed to fetch rating history for Sortt. Status code: 503
# Failed to fetch rating history for mikle8244. Status code: 503
#             Handle  Max Rating Result
# 0      xxwip30utxx        1845     No
# 1       DinoHadzic        1965    Yes
# 2          GK_Leo0        1844     No
# 3      _priyanshu_        1844     No
# 4         pera2008        1935    Yes
# ..             ...         ...    ...
# 495       Mikunyan        1784    N/A
# 496        Satinii        1917     No
# 497          Sortt        1829    N/A
# 498      mikle8244        1784    N/A
# 499  omsgunjal2003        1862    Yes
#
# [500 rows x 3 columns]

# %%
df.head()
# Out:
#         Handle  Max Rating Result
# 0  xxwip30utxx        1845     No
# 1   DinoHadzic        1965    Yes
# 2      GK_Leo0        1844     No
# 3  _priyanshu_        1844     No
# 4     pera2008        1935    Yes

# %%
df.to_csv('outdf6.csv', index=False)
