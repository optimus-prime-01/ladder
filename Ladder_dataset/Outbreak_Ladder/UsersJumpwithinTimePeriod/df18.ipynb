# %%
import requests
from datetime import datetime
import pandas as pd
df=pd.read_csv('df18.csv')
import json
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1200
    target_upper = 1400

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 20 <= days_taken <= 40:
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
df.to_csv('outdf18.csv', index=False)
# Out:
# yu__xuan did not cross the rating margin within the specified range.
# Akash_Tike did not cross the rating margin within the specified range.
# Failed to fetch rating history for abhinav520. Status code: 503
# Failed to fetch rating history for coutjorhua. Status code: 503
# nifengfly did not cross the rating margin within the specified range.
# vladOS did not cross the rating margin within the specified range.
# noobiesAG did not cross the rating margin within the specified range.
# shamir0xe did not cross the rating margin within the specified range.
# Failed to fetch rating history for Dregen_Yor. Status code: 503
# Rising_Date did not cross the rating margin within the specified range.
# Failed to fetch rating history for fortypercentyaar. Status code: 503
# Failed to fetch rating history for iam.nikita.kostin. Status code: 503
# Failed to fetch rating history for testZR. Status code: 503
# Failed to fetch rating history for yashratnani. Status code: 503
# Anhedonia did not cross the rating margin within the specified range.
# Failed to fetch rating history for DatMomoAgain. Status code: 503
# GuomingWu did not cross the rating margin within the specified range.
# Failed to fetch rating history for TANGRA. Status code: 503
# Failed to fetch rating history for kartik1240. Status code: 503
# paulohltc did not cross the rating margin within the specified range.
# Jamik did not cross the rating margin within the specified range.
# Failed to fetch rating history for Thesircastor. Status code: 503
# UncleBobbyB did not cross the rating margin within the specified range.
# beginner19 did not cross the rating margin within the specified range.
# Failed to fetch rating history for darklight4414. Status code: 503
# Failed to fetch rating history for lddc. Status code: 503
# Failed to fetch rating history for Misaki--Mei. Status code: 503
# Failed to fetch rating history for Nelox228. Status code: 503
# Failed to fetch rating history for ayushraghuwanshi22. Status code: 503
# Failed to fetch rating history for kunkun2007. Status code: 503
# Failed to fetch rating history for rajadium. Status code: 503
# vishnesh did not cross the rating margin within the specified range.
# Failed to fetch rating history for A20221218. Status code: 503
# Failed to fetch rating history for Nichido. Status code: 503
# Failed to fetch rating history for Vaidurya. Status code: 503
# basalov_yurij did not cross the rating margin within the specified range.
# Failed to fetch rating history for s010456. Status code: 503
# Failed to fetch rating history for yingchengjie. Status code: 503
# Escaquejant did not cross the rating margin within the specified range.
# ShattajiT_ did not cross the rating margin within the specified range.
# andpar did not cross the rating margin within the specified range.
# Failed to fetch rating history for ck219. Status code: 503
# Failed to fetch rating history for nhuhung37. Status code: 503
# Failed to fetch rating history for ProgrammMaster. Status code: 503
# AbdalrhmanEssam did not cross the rating margin within the specified range.
# Failed to fetch rating history for AndrijaMlad. Status code: 503
# JustinLamCF did not cross the rating margin within the specified range.
# Failed to fetch rating history for alihew841. Status code: 503
# Doubleen233 did not cross the rating margin within the specified range.
# Huntercam did not cross the rating margin within the specified range.
# Failed to fetch rating history for Vraj123. Status code: 503
# linweiway67 did not cross the rating margin within the specified range.
# Failed to fetch rating history for practice_20. Status code: 503
# Failed to fetch rating history for DarshilThakkar. Status code: 503
# Failed to fetch rating history for Pratik8696. Status code: 503
# Yash57 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Yelei. Status code: 503
# Failed to fetch rating history for garysun2. Status code: 503
# Failed to fetch rating history for solarblight. Status code: 503
# Failed to fetch rating history for 21bcs197. Status code: 503
# Failed to fetch rating history for AnishchukT. Status code: 503
# Failed to fetch rating history for H3HunTer. Status code: 503
# Failed to fetch rating history for NoLove. Status code: 503
# Failed to fetch rating history for ProNooB47. Status code: 503
# RULO did not cross the rating margin within the specified range.
# Failed to fetch rating history for Truly_. Status code: 503
# Failed to fetch rating history for humroush. Status code: 503
# Failed to fetch rating history for kriminalac_2. Status code: 503
# Failed to fetch rating history for negative1. Status code: 503
# Failed to fetch rating history for rollking. Status code: 503
# Failed to fetch rating history for striker_45. Status code: 503
# Failed to fetch rating history for DCODER_13. Status code: 503
# Failed to fetch rating history for IbrahimHiarea. Status code: 503
# Failed to fetch rating history for RusherRG. Status code: 503
# Failed to fetch rating history for To_Be__Unknown. Status code: 503
# Failed to fetch rating history for coder_adi07. Status code: 503
# Failed to fetch rating history for imtangx. Status code: 503
# Failed to fetch rating history for probro007. Status code: 503
# Failed to fetch rating history for ptishang. Status code: 503
# Failed to fetch rating history for singh_ujjain07. Status code: 503
# Failed to fetch rating history for wow_Wonderful. Status code: 503
# Failed to fetch rating history for zhouyifeng. Status code: 503
# Failed to fetch rating history for MehradSh. Status code: 503
# Failed to fetch rating history for Mowind. Status code: 503
# Failed to fetch rating history for Rishi_Kumar_Singh. Status code: 503
# blackmart did not cross the rating margin within the specified range.
# ibrahim_habib did not cross the rating margin within the specified range.
# Failed to fetch rating history for tymond. Status code: 503
# Failed to fetch rating history for Aneko. Status code: 503
# MohamedTaha did not cross the rating margin within the specified range.
# Failed to fetch rating history for RemberMe. Status code: 503
# Failed to fetch rating history for jeyan_s. Status code: 503
# Failed to fetch rating history for smeey. Status code: 503
# Failed to fetch rating history for Doncho_Bonboncho. Status code: 503
# Failed to fetch rating history for Taam. Status code: 503
# YudoTLE did not cross the rating margin within the specified range.
# Failed to fetch rating history for dat. Status code: 503
# teoet6 did not cross the rating margin within the specified range.
# Failed to fetch rating history for yashverma_3. Status code: 503
# Failed to fetch rating history for Mysterious-genius. Status code: 503
# Failed to fetch rating history for alphaK-u. Status code: 503
#               Handle  Max Rating Result
# 0            pRaVsha        1444     No
# 1    realphamanhtuan        1521    Yes
# 2               ty09        1487     No
# 3          yingjiayu        1454     No
# 4             yuYgen        1536    Yes
# ..               ...         ...    ...
# 495         Vannn168        1520    Yes
# 496          _Raiko_        1517     No
# 497         alphaK-u        1423    N/A
# 498         bridge71        1441     No
# 499            efdsa        1506     No
#
# [500 rows x 3 columns]
