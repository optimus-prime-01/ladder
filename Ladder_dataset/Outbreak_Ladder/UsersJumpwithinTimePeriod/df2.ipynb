# %%
import requests
from datetime import datetime
import pandas as pd

# %%
df=pd.read_csv('df2.csv')

# %%
import json
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1200
    target_upper = 1400

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 20 <= days_taken <= 40:
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
# Out:
# zzpcd did not cross the rating margin within the specified range.
# paula did not cross the rating margin within the specified range.
# Gassa did not cross the rating margin within the specified range.
# Lskkkno3 did not cross the rating margin within the specified range.
# Ilya_MSU did not cross the rating margin within the specified range.
# yutabi did not cross the rating margin within the specified range.
# CSHwang did not cross the rating margin within the specified range.
# KDVinit did not cross the rating margin within the specified range.
# awoo did not cross the rating margin within the specified range.
# ethening did not cross the rating margin within the specified range.
# Failed to fetch rating history for Gorgo. Status code: 503
# TimeEmergency did not cross the rating margin within the specified range.
# sayo did not cross the rating margin within the specified range.
# Failed to fetch rating history for Kaey. Status code: 503
# chenyanbo did not cross the rating margin within the specified range.
# DeaphetS did not cross the rating margin within the specified range.
# Failed to fetch rating history for 5sb. Status code: 503
# PaperCloud did not cross the rating margin within the specified range.
# Failed to fetch rating history for krzysztov. Status code: 503
# Failed to fetch rating history for DimmyT. Status code: 503
# Hyperbolic did not cross the rating margin within the specified range.
# zaq1xsw2tktk did not cross the rating margin within the specified range.
# Failed to fetch rating history for Anakamira. Status code: 503
# marat.snowbear did not cross the rating margin within the specified range.
# Failed to fetch rating history for ParsaDox. Status code: 503
# Failed to fetch rating history for Ant_Man. Status code: 503
# Failed to fetch rating history for amsen. Status code: 503
# jefrai did not cross the rating margin within the specified range.
# tnowak did not cross the rating margin within the specified range.
# Failed to fetch rating history for wutongchun. Status code: 503
# JeffreyLC did not cross the rating margin within the specified range.
# Failed to fetch rating history for __Misuki. Status code: 503
# hamamu did not cross the rating margin within the specified range.
# houzhe did not cross the rating margin within the specified range.
# FrenkiedeJong21 did not cross the rating margin within the specified range.
# Failed to fetch rating history for max67. Status code: 503
# -1e11 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Tringmo. Status code: 503
# rt3 did not cross the rating margin within the specified range.
# Failed to fetch rating history for TahmKench. Status code: 503
# serotonin did not cross the rating margin within the specified range.
# yyf_0404 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Beelzebub_blue. Status code: 503
# Fortitude did not cross the rating margin within the specified range.
# faustaadp did not cross the rating margin within the specified range.
# Gediminas did not cross the rating margin within the specified range.
# socho did not cross the rating margin within the specified range.
# hyman00 did not cross the rating margin within the specified range.
# LTL_td did not cross the rating margin within the specified range.
# dannyboy20031204 did not cross the rating margin within the specified range.
# Lawali did not cross the rating margin within the specified range.
# jhzjk did not cross the rating margin within the specified range.
# vito1036 did not cross the rating margin within the specified range.
# Fidisk did not cross the rating margin within the specified range.
# Changyu did not cross the rating margin within the specified range.
# muratt did not cross the rating margin within the specified range.
# kymmykym did not cross the rating margin within the specified range.
# BirthdayParadox did not cross the rating margin within the specified range.
# applese did not cross the rating margin within the specified range.
# Geobiyye did not cross the rating margin within the specified range.
# Mdominykas did not cross the rating margin within the specified range.
# ivatopuria did not cross the rating margin within the specified range.
# knightL did not cross the rating margin within the specified range.
# b6e0 did not cross the rating margin within the specified range.
# Hakiobo did not cross the rating margin within the specified range.
# Sedmoklasnikut did not cross the rating margin within the specified range.
# TrivialMan did not cross the rating margin within the specified range.
# HNO2 did not cross the rating margin within the specified range.
# Raiden did not cross the rating margin within the specified range.
# 2337559178 did not cross the rating margin within the specified range.
# steven.novaryo did not cross the rating margin within the specified range.
# Failed to fetch rating history for JohnVictor. Status code: 503
# shiven did not cross the rating margin within the specified range.
# lucasxia01 did not cross the rating margin within the specified range.
# Failed to fetch rating history for DisconnectedGraph. Status code: 503
# aryanc403 did not cross the rating margin within the specified range.
# Failed to fetch rating history for lddlinan. Status code: 503
# Grzmot did not cross the rating margin within the specified range.
# lexiyvv did not cross the rating margin within the specified range.
# szb did not cross the rating margin within the specified range.
# Failed to fetch rating history for albatross_errantia. Status code: 503
# dyukha did not cross the rating margin within the specified range.
# Failed to fetch rating history for Hypercube07. Status code: 503
# Failed to fetch rating history for ErdemKirez. Status code: 503
# FEDIKUS did not cross the rating margin within the specified range.
# Failed to fetch rating history for pavement. Status code: 503
# VladaMG98 did not cross the rating margin within the specified range.
# Failed to fetch rating history for YoshikaMiyafuji. Status code: 503
# Failed to fetch rating history for xioxio. Status code: 503
# Failed to fetch rating history for QMG_link. Status code: 503
# Failed to fetch rating history for Sakuyalove. Status code: 503
# -2x9_21- did not cross the rating margin within the specified range.
# Failed to fetch rating history for Superposition. Status code: 503
# kefaa did not cross the rating margin within the specified range.
# Failed to fetch rating history for YunQian. Status code: 503
# Failed to fetch rating history for WLZ. Status code: 503
# YouKn0wWho did not cross the rating margin within the specified range.
# Failed to fetch rating history for HHY_zZhu. Status code: 503
# Failed to fetch rating history for Ali.Kh. Status code: 503
# Failed to fetch rating history for DLUT_Zeratul. Status code: 503
# Failed to fetch rating history for cfhj. Status code: 503
# onufryw did not cross the rating margin within the specified range.
# Failed to fetch rating history for Huyum_nik_fan. Status code: 503
# Failed to fetch rating history for apoorv_me. Status code: 503
# Giselus did not cross the rating margin within the specified range.
# Failed to fetch rating history for Xaxixin. Status code: 503
# alexwice did not cross the rating margin within the specified range.
# Failed to fetch rating history for andrei_iorgulescu. Status code: 503
# czyarl did not cross the rating margin within the specified range.
# Failed to fetch rating history for dbsic211. Status code: 503
# Failed to fetch rating history for BlackAnt. Status code: 503
# Failed to fetch rating history for UnoK. Status code: 503
# Failed to fetch rating history for gxj114514. Status code: 503
# Failed to fetch rating history for zacharychao. Status code: 503
# yaufung did not cross the rating margin within the specified range.
# Failed to fetch rating history for fmota. Status code: 503
# johannesk did not cross the rating margin within the specified range.
# Failed to fetch rating history for KoreaL2KStRiKe. Status code: 503
# Failed to fetch rating history for zlc1114_v2. Status code: 503
# Failed to fetch rating history for lotusblume. Status code: 503
# DAV3R did not cross the rating margin within the specified range.
# Failed to fetch rating history for 1kri. Status code: 503
# Timur2006 did not cross the rating margin within the specified range.
# Drice did not cross the rating margin within the specified range.
# Failed to fetch rating history for ExpertHunter. Status code: 503
# Terryjoy did not cross the rating margin within the specified range.
# YxqK did not cross the rating margin within the specified range.
# Failed to fetch rating history for suta. Status code: 503
# 18985012367 did not cross the rating margin within the specified range.
# CommandMaster did not cross the rating margin within the specified range.
# Failed to fetch rating history for MattTheNub. Status code: 503
# NegaTeeF did not cross the rating margin within the specified range.
# Failed to fetch rating history for do_while_not_not_true. Status code: 503
# Failed to fetch rating history for WGYHMFkZyA02. Status code: 503
# Failed to fetch rating history for tobias.glimmerfors. Status code: 503
# ebi_fly did not cross the rating margin within the specified range.
# Failed to fetch rating history for LittleTB. Status code: 503
# Tima did not cross the rating margin within the specified range.
# ahoraSoyPeor did not cross the rating margin within the specified range.
# Failed to fetch rating history for kiranraj.kkb. Status code: 503
# platypus179 did not cross the rating margin within the specified range.
# Failed to fetch rating history for quan7929. Status code: 503
# Failed to fetch rating history for Nisanth. Status code: 503
# Failed to fetch rating history for Spitfire_F_Mk_24. Status code: 503
# kaikey did not cross the rating margin within the specified range.
# Failed to fetch rating history for vaaven. Status code: 503
# Imdie did not cross the rating margin within the specified range.
# anil9717 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Good_WeekDay_. Status code: 503
# Kira_1234 did not cross the rating margin within the specified range.
# Monarchuwu did not cross the rating margin within the specified range.
# Failed to fetch rating history for bkdn23.vodacbaoan. Status code: 503
# leo020630 did not cross the rating margin within the specified range.
# Sugarii did not cross the rating margin within the specified range.
# Failed to fetch rating history for WonderfulWhale. Status code: 503
# ZPAYAUR did not cross the rating margin within the specified range.
# __shaun_0124 did not cross the rating margin within the specified range.
# cnyzz did not cross the rating margin within the specified range.
# Failed to fetch rating history for DippleThree. Status code: 503
# Failed to fetch rating history for jurao. Status code: 503
# Jerry__Jiang did not cross the rating margin within the specified range.
# Failed to fetch rating history for Msstt. Status code: 503
# Mtaylor did not cross the rating margin within the specified range.
# Failed to fetch rating history for joww. Status code: 503
# Failed to fetch rating history for tofudra. Status code: 503
# Failed to fetch rating history for ligaydima. Status code: 503
# wenkaijie did not cross the rating margin within the specified range.
# Aldas25 did not cross the rating margin within the specified range.
# HCPS42 did not cross the rating margin within the specified range.
# lorenzoferrari did not cross the rating margin within the specified range.
# GrishaIvanenko did not cross the rating margin within the specified range.
# Nika_Tamliani did not cross the rating margin within the specified range.
# _Komorebi_ did not cross the rating margin within the specified range.
# mihleonid did not cross the rating margin within the specified range.
# miss_robot did not cross the rating margin within the specified range.
# Failed to fetch rating history for Lerpin. Status code: 503
# Failed to fetch rating history for VHTung. Status code: 503
# Failed to fetch rating history for TimonKnigge. Status code: 503
# Failed to fetch rating history for jacobtpl. Status code: 503
# shadow9236 did not cross the rating margin within the specified range.
# Failed to fetch rating history for akua. Status code: 503
# Lain did not cross the rating margin within the specified range.
# TwoFx did not cross the rating margin within the specified range.
# psruk did not cross the rating margin within the specified range.
# Failed to fetch rating history for ATM12345. Status code: 503
# sysulby did not cross the rating margin within the specified range.
# Failed to fetch rating history for tiinpeng. Status code: 503
# Failed to fetch rating history for MvKaio. Status code: 503
# Failed to fetch rating history for catforces. Status code: 503
# gmusya did not cross the rating margin within the specified range.
# Failed to fetch rating history for lmqzzz. Status code: 503
# TooTrashyToCompete did not cross the rating margin within the specified range.
# KNB. did not cross the rating margin within the specified range.
# Failed to fetch rating history for DJ2006. Status code: 503
# NaOH_Frog did not cross the rating margin within the specified range.
# depr13y0 did not cross the rating margin within the specified range.
# IsaacMoris did not cross the rating margin within the specified range.
# Failed to fetch rating history for little_brush. Status code: 503
# Failed to fetch rating history for Qsauce. Status code: 503
# Failed to fetch rating history for vbobrov. Status code: 503
# CoDeRoK did not cross the rating margin within the specified range.
# Haa did not cross the rating margin within the specified range.
# Failed to fetch rating history for Kaibad. Status code: 503
# Failed to fetch rating history for Master--when. Status code: 503
# Failed to fetch rating history for T4M0FEY. Status code: 503
# jiangtaizhe001 did not cross the rating margin within the specified range.
# Failed to fetch rating history for kiritan. Status code: 503
# Failed to fetch rating history for whdywjd. Status code: 503
# Failed to fetch rating history for Badint. Status code: 503
# TearsFreeze did not cross the rating margin within the specified range.
# Failed to fetch rating history for Ynoi. Status code: 503
# Failed to fetch rating history for fs20091003. Status code: 503
# de_while_que did not cross the rating margin within the specified range.
# jhhope1 did not cross the rating margin within the specified range.
# mr.kolya did not cross the rating margin within the specified range.
# xiaruize did not cross the rating margin within the specified range.
# Failed to fetch rating history for yagoo. Status code: 503
# Gellertke did not cross the rating margin within the specified range.
# MikhailKapitov did not cross the rating margin within the specified range.
# Failed to fetch rating history for for_sx_e_1. Status code: 503
# Failed to fetch rating history for Ferume. Status code: 503
# Wolam did not cross the rating margin within the specified range.
# Failed to fetch rating history for mban259. Status code: 503
# JOliva did not cross the rating margin within the specified range.
# Failed to fetch rating history for MnTm. Status code: 503
# Yunlong_Li did not cross the rating margin within the specified range.
# Failed to fetch rating history for awesomeguy856. Status code: 503
# pac-man21 did not cross the rating margin within the specified range.
# Failed to fetch rating history for rickbaishuak. Status code: 503
# CodigoL did not cross the rating margin within the specified range.
# Failed to fetch rating history for golions. Status code: 503
# Failed to fetch rating history for 1234huang. Status code: 503
# KKT_89 did not cross the rating margin within the specified range.
# SecondThread did not cross the rating margin within the specified range.
# Failed to fetch rating history for taran_1407. Status code: 503
# Error-42 did not cross the rating margin within the specified range.
# Failed to fetch rating history for lg_zhou. Status code: 503
# Failed to fetch rating history for 2018liuzhiyuan. Status code: 503
# ForwardJ did not cross the rating margin within the specified range.
# N.N_2004 did not cross the rating margin within the specified range.
# Failed to fetch rating history for keyurchd_11. Status code: 503
# John_zyj did not cross the rating margin within the specified range.
# Failed to fetch rating history for LskkknoAce. Status code: 503
# _Wallace_61430 did not cross the rating margin within the specified range.
# hopsfb did not cross the rating margin within the specified range.
# Failed to fetch rating history for parkky. Status code: 503
# EvgenKarpov did not cross the rating margin within the specified range.
# surajchip2 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Proofy. Status code: 503
# Lucina did not cross the rating margin within the specified range.
# Failed to fetch rating history for Prostoegor239. Status code: 503
# ilia-ivanov did not cross the rating margin within the specified range.
# Failed to fetch rating history for Alfeh2. Status code: 503
# Failed to fetch rating history for Wael_Zaiback. Status code: 503
# cyaegha did not cross the rating margin within the specified range.
# Failed to fetch rating history for yingxue. Status code: 503
# Failed to fetch rating history for gingers. Status code: 503
# huxch135 did not cross the rating margin within the specified range.
# Failed to fetch rating history for 123ZDQ. Status code: 503
# Gheal did not cross the rating margin within the specified range.
# Failed to fetch rating history for Phantom_Deluxe. Status code: 503
# tinca_matei did not cross the rating margin within the specified range.
# Failed to fetch rating history for Wall_breaker. Status code: 503
# Failed to fetch rating history for AlexanderL. Status code: 503
# WaterColor2037 did not cross the rating margin within the specified range.
# apgpsoop did not cross the rating margin within the specified range.
# Failed to fetch rating history for silv723. Status code: 503
# Failed to fetch rating history for Hosen_ba. Status code: 503
# Vectors_Master did not cross the rating margin within the specified range.
# Failed to fetch rating history for coconut99. Status code: 503
# nana7mi_channel did not cross the rating margin within the specified range.
# Fuzen527 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Nanani. Status code: 503
# Yuki726 did not cross the rating margin within the specified range.
# tonegawa did not cross the rating margin within the specified range.
# WCG did not cross the rating margin within the specified range.
# Failed to fetch rating history for BIT_smzzl. Status code: 503
# dahoon46 did not cross the rating margin within the specified range.
# pavlekn did not cross the rating margin within the specified range.
# EasyRed29 did not cross the rating margin within the specified range.
# arvindr9 did not cross the rating margin within the specified range.
# Lavine did not cross the rating margin within the specified range.
# Failed to fetch rating history for Roll_Num_56. Status code: 503
# Wielomian did not cross the rating margin within the specified range.
# ub33 did not cross the rating margin within the specified range.
#               Handle  Max Rating Result
# 0            RNS_KSR        2306     No
# 1              zzpcd        2306    N/A
# 2              paula        2500    N/A
# 3        Ricki_White        2311     No
# 4              Gassa        2581    N/A
# ..               ...         ...    ...
# 495      AhmedEzzatG        2148     No
# 496         Air_Wind        2134     No
# 497         Alihan_8        2200     No
# 498        Irmuun.Ch        2348     No
# 499  Luminolic_Black        2134     No
#
# [500 rows x 3 columns]

# %%
df.head()
# Out:
#         Handle  Max Rating Result
# 0      RNS_KSR        2306     No
# 1        zzpcd        2306    N/A
# 2        paula        2500    N/A
# 3  Ricki_White        2311     No
# 4        Gassa        2581    N/A

# %%
df.to_csv('outdf2.csv', index=False)
