# %%
import requests
from datetime import datetime
import pandas as pd
df=pd.read_csv('df9.csv')
import json
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1200
    target_upper = 1400

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 20 <= days_taken <= 40:
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
# Out:
# _deadinside did not cross the rating margin within the specified range.
# eddyboy did not cross the rating margin within the specified range.
# shoryak did not cross the rating margin within the specified range.
# Alear did not cross the rating margin within the specified range.
# Failed to fetch rating history for G_Ayan7. Status code: 503
# Failed to fetch rating history for Mamalesh. Status code: 503
# Failed to fetch rating history for ShyGuy. Status code: 503
# Failed to fetch rating history for cxcyl. Status code: 503
# deuteridayo did not cross the rating margin within the specified range.
# Failed to fetch rating history for iling_. Status code: 503
# Failed to fetch rating history for sultan__. Status code: 503
# Failed to fetch rating history for wjxAKIOI. Status code: 503
# Failed to fetch rating history for Leftist_G. Status code: 503
# Failed to fetch rating history for RainSure. Status code: 503
# Failed to fetch rating history for akritovandrey. Status code: 503
# cxhscst2 did not cross the rating margin within the specified range.
# harshjaiswalcr7 did not cross the rating margin within the specified range.
# Failed to fetch rating history for PinoF. Status code: 503
# Failed to fetch rating history for The-N-word. Status code: 503
# Failed to fetch rating history for _agKc_. Status code: 503
# Failed to fetch rating history for c_plus_plus. Status code: 503
# Failed to fetch rating history for cuenta_secundaria. Status code: 503
# fake_name did not cross the rating margin within the specified range.
# Failed to fetch rating history for lizhous. Status code: 503
# sak_kn did not cross the rating margin within the specified range.
# Failed to fetch rating history for scutsky. Status code: 503
# Failed to fetch rating history for PeruvianCartel. Status code: 503
# Failed to fetch rating history for Seahorc. Status code: 503
# pavlukivan did not cross the rating margin within the specified range.
# Failed to fetch rating history for sheldonn. Status code: 503
# Kawchar85 did not cross the rating margin within the specified range.
# Failed to fetch rating history for SUII. Status code: 503
# Failed to fetch rating history for baichui. Status code: 503
# Failed to fetch rating history for moise_alexandru. Status code: 503
# Failed to fetch rating history for greensignal. Status code: 503
# Failed to fetch rating history for Lealzinho. Status code: 503
# Failed to fetch rating history for dolphin2025. Status code: 503
# Failed to fetch rating history for hacker.NO.1. Status code: 503
# rqbqbqb did not cross the rating margin within the specified range.
# Failed to fetch rating history for umezo. Status code: 503
# safiullinzufar did not cross the rating margin within the specified range.
# spectrra did not cross the rating margin within the specified range.
# FilatovYura did not cross the rating margin within the specified range.
# Failed to fetch rating history for jz796. Status code: 503
# Failed to fetch rating history for omsincoconut. Status code: 503
# Naim_Elias did not cross the rating margin within the specified range.
# SuperSat0001 did not cross the rating margin within the specified range.
# Failed to fetch rating history for njupt_zy. Status code: 503
# Failed to fetch rating history for Garendaxe. Status code: 503
# Failed to fetch rating history for hipereg. Status code: 503
# Failed to fetch rating history for pipiaker. Status code: 503
# Failed to fetch rating history for yolx. Status code: 503
# Ernest0_0Abreu did not cross the rating margin within the specified range.
# Failed to fetch rating history for SmartMonky. Status code: 503
# andreumat did not cross the rating margin within the specified range.
# Failed to fetch rating history for j30. Status code: 503
# Failed to fetch rating history for kaislash.. Status code: 503
# Failed to fetch rating history for I_CE_IOI. Status code: 503
# Failed to fetch rating history for TheCypher. Status code: 503
# Failed to fetch rating history for cyc_43346. Status code: 503
# tojra did not cross the rating margin within the specified range.
# Failed to fetch rating history for Apiram. Status code: 503
# Gegege337 did not cross the rating margin within the specified range.
# Failed to fetch rating history for _Solyman. Status code: 503
# Failed to fetch rating history for red_jiu. Status code: 503
# ssid8802 did not cross the rating margin within the specified range.
# FeetTester did not cross the rating margin within the specified range.
# Failed to fetch rating history for modinte. Status code: 503
# recuraki did not cross the rating margin within the specified range.
# Sakamoto45 did not cross the rating margin within the specified range.
# weastur did not cross the rating margin within the specified range.
# Bruteforcekid did not cross the rating margin within the specified range.
# fredy10 did not cross the rating margin within the specified range.
# infinity0 did not cross the rating margin within the specified range.
# naeem4265 did not cross the rating margin within the specified range.
# Emper0r_of_East did not cross the rating margin within the specified range.
# Failed to fetch rating history for Layn. Status code: 503
# Failed to fetch rating history for Velikan. Status code: 503
# Failed to fetch rating history for bkdn23.huhuu. Status code: 503
# Failed to fetch rating history for Aytien. Status code: 503
# Failed to fetch rating history for Lazy_Labs. Status code: 503
# Failed to fetch rating history for oloy. Status code: 503
# Failed to fetch rating history for IDontWantToPlayAnymore. Status code: 503
# Pbezz did not cross the rating margin within the specified range.
# Failed to fetch rating history for Perta. Status code: 503
# Failed to fetch rating history for Xiaoxx. Status code: 503
# Failed to fetch rating history for d-O.O-b. Status code: 503
# kim_young_hyun did not cross the rating margin within the specified range.
# Failed to fetch rating history for moikfer. Status code: 503
# Failed to fetch rating history for the_stone_dawg. Status code: 503
# Failed to fetch rating history for yashss1. Status code: 503
# Failed to fetch rating history for GR1ZLER. Status code: 503
# Failed to fetch rating history for bhatnagar.mradul. Status code: 503
# Failed to fetch rating history for samriddhjn. Status code: 503
# Failed to fetch rating history for Eslam_Ahmed. Status code: 503
# JJaewon did not cross the rating margin within the specified range.
# Failed to fetch rating history for Logic_. Status code: 503
# Failed to fetch rating history for buxiang-qichuang. Status code: 503
# Failed to fetch rating history for tr1ten. Status code: 503
# Failed to fetch rating history for xobe19. Status code: 503
# Failed to fetch rating history for Cream_cake. Status code: 503
# Failed to fetch rating history for Karavaiev. Status code: 503
# Mooshroom did not cross the rating margin within the specified range.
# Failed to fetch rating history for ___Sherry___. Status code: 503
# Failed to fetch rating history for beer2. Status code: 503
# Failed to fetch rating history for mbae060. Status code: 503
# Failed to fetch rating history for pushpavel. Status code: 503
# Failed to fetch rating history for Shri_874. Status code: 503
# Failed to fetch rating history for homefjy. Status code: 503
# Failed to fetch rating history for AnmolPabla. Status code: 503
# Hisu did not cross the rating margin within the specified range.
# Failed to fetch rating history for Kladrr. Status code: 503
# Failed to fetch rating history for noobcityboy. Status code: 503
# windreaper did not cross the rating margin within the specified range.
# Failed to fetch rating history for IbrahimHabib. Status code: 503
# Failed to fetch rating history for Vishnu_Tiwari. Status code: 503
# Failed to fetch rating history for grzloveac. Status code: 503
# Failed to fetch rating history for 1eonscount. Status code: 503
# Failed to fetch rating history for KonoDioDa_Wrryyyy. Status code: 503
# Failed to fetch rating history for bans1mp. Status code: 503
# Failed to fetch rating history for sakib.safwan. Status code: 503
# Naot did not cross the rating margin within the specified range.
# Failed to fetch rating history for SeptaCube. Status code: 503
# pb_messi did not cross the rating margin within the specified range.
# Failed to fetch rating history for .Danet. Status code: 503
# Failed to fetch rating history for LuoMoGuYun. Status code: 503
# Failed to fetch rating history for dewana310. Status code: 503
# Failed to fetch rating history for notvidut_206_CNH. Status code: 503
# trqrizu did not cross the rating margin within the specified range.
# Failed to fetch rating history for zhligzweru. Status code: 503
# Failed to fetch rating history for AEcreator. Status code: 503
# laduiw did not cross the rating margin within the specified range.
# 2019-12-21 did not cross the rating margin within the specified range.
# Failed to fetch rating history for AlexRex0. Status code: 503
# Failed to fetch rating history for Eva.Q711. Status code: 503
# Failed to fetch rating history for ShaurabhTiwari. Status code: 503
# Failed to fetch rating history for rating_keliye_besharam. Status code: 503
# Failed to fetch rating history for unexpected07. Status code: 503
# Nyse did not cross the rating margin within the specified range.
# Failed to fetch rating history for PhantomSniper. Status code: 503
# Failed to fetch rating history for _QWS_. Status code: 503
# Failed to fetch rating history for liujunyi123. Status code: 503
# mihael1peklar did not cross the rating margin within the specified range.
# Failed to fetch rating history for Amaterasu_720. Status code: 503
# Failed to fetch rating history for Nefelibata__. Status code: 503
# Failed to fetch rating history for Zandler. Status code: 503
# Failed to fetch rating history for hnust_linzhenbin. Status code: 503
# Failed to fetch rating history for namandamani3112. Status code: 503
# pigpigger did not cross the rating margin within the specified range.
# unnoticable_guy did not cross the rating margin within the specified range.
# Failed to fetch rating history for FingerEleven. Status code: 503
# Failed to fetch rating history for at_80. Status code: 503
# Failed to fetch rating history for ritikjainrj18. Status code: 503
# Lectra did not cross the rating margin within the specified range.
# pyy156941 did not cross the rating margin within the specified range.
#             Handle  Max Rating Result
# 0           tvladm        1695     No
# 1          Arpitkr        1779     No
# 2          Elgoker        1769     No
# 3         Sambasai        1753    Yes
# 4      Ssaranshh13        1694     No
# ..             ...         ...    ...
# 495      buffering        1666     No
# 496   chetan_saini        1773     No
# 497      chorachcf        1658     No
# 498  elephant_1016        1658     No
# 499      pyy156941        1658    N/A
#
# [500 rows x 3 columns]

# %%
df.head()
# Out:
#         Handle  Max Rating Result
# 0       tvladm        1695     No
# 1      Arpitkr        1779     No
# 2      Elgoker        1769     No
# 3     Sambasai        1753    Yes
# 4  Ssaranshh13        1694     No

# %%
df.to_csv('outdf9.csv', index=False)
