# %%
import requests
from datetime import datetime
import pandas as pd
df=pd.read_csv('df20.csv')
import json
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1200
    target_upper = 1400

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 20 <= days_taken <= 40:
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
df.to_csv('outdf20.csv', index=False)
# Out:
# CY0531 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Dert30. Status code: 503
# Failed to fetch rating history for Mixnight. Status code: 503
# Failed to fetch rating history for adonkey. Status code: 503
# Failed to fetch rating history for govufpb. Status code: 503
# kiteretsu did not cross the rating margin within the specified range.
# Failed to fetch rating history for omtrivedioo3. Status code: 503
# Rad1x did not cross the rating margin within the specified range.
# Failed to fetch rating history for bhavyacontractor. Status code: 503
# Failed to fetch rating history for shreyam7713. Status code: 503
# Failed to fetch rating history for sunzhangchang. Status code: 503
# Failed to fetch rating history for Aaayc.. Status code: 503
# Failed to fetch rating history for Gold_Fridge. Status code: 503
# Failed to fetch rating history for Utsavk02. Status code: 503
# Failed to fetch rating history for ggnG.... Status code: 503
# lebron87 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Ayman_khaled. Status code: 503
# Failed to fetch rating history for Cyclopes. Status code: 503
# Failed to fetch rating history for OO7. Status code: 503
# Failed to fetch rating history for TheTV. Status code: 503
# Failed to fetch rating history for UnknownFear. Status code: 503
# Failed to fetch rating history for karandeep09. Status code: 503
# Failed to fetch rating history for zfx1569_HCl_2023. Status code: 503
# Failed to fetch rating history for I_love_Iloveseeleforever. Status code: 503
# Khody did not cross the rating margin within the specified range.
# Failed to fetch rating history for Questmark. Status code: 503
# Failed to fetch rating history for Trumling_hasnotime. Status code: 503
# Failed to fetch rating history for pranav_raichur. Status code: 503
# Failed to fetch rating history for woofyer. Status code: 503
# Failed to fetch rating history for aditya4905. Status code: 503
# Failed to fetch rating history for jsarva. Status code: 503
# Failed to fetch rating history for qbad. Status code: 503
# Failed to fetch rating history for smallxu. Status code: 503
# Failed to fetch rating history for LuchXDD. Status code: 503
# Failed to fetch rating history for _qiling. Status code: 503
# Failed to fetch rating history for bubaduba. Status code: 503
# Failed to fetch rating history for harshithch36. Status code: 503
# pycpp did not cross the rating margin within the specified range.
# Failed to fetch rating history for shubasur. Status code: 503
# Failed to fetch rating history for DrHadenstein. Status code: 503
# Puspak-Sahu did not cross the rating margin within the specified range.
# Failed to fetch rating history for aizen_sosuke_. Status code: 503
# gakkigakki did not cross the rating margin within the specified range.
# Failed to fetch rating history for gbula. Status code: 503
# Failed to fetch rating history for rAnD0MA. Status code: 503
# wings_of_demon did not cross the rating margin within the specified range.
# Failed to fetch rating history for AliYM. Status code: 503
# Failed to fetch rating history for Nhatthang27. Status code: 503
# Failed to fetch rating history for Simba. Status code: 503
# Failed to fetch rating history for Srinish. Status code: 503
# Failed to fetch rating history for doupleganger. Status code: 503
# sunshineAgain did not cross the rating margin within the specified range.
# Failed to fetch rating history for topala.andrei. Status code: 503
# Failed to fetch rating history for vjcp. Status code: 503
# Failed to fetch rating history for G_liver. Status code: 503
# Failed to fetch rating history for LogSingleDog. Status code: 503
# Failed to fetch rating history for _Uncertain_. Status code: 503
# Failed to fetch rating history for anujk20. Status code: 503
# Failed to fetch rating history for devansh_ladha. Status code: 503
# Failed to fetch rating history for ig_notus. Status code: 503
# Failed to fetch rating history for zhangjiang. Status code: 503
# Failed to fetch rating history for IsaL. Status code: 503
# Failed to fetch rating history for danielvitor23. Status code: 503
# doctor-strange did not cross the rating margin within the specified range.
# Failed to fetch rating history for yearbyyear. Status code: 503
# Failed to fetch rating history for KAZE_mae. Status code: 503
# One_Two_Dog did not cross the rating margin within the specified range.
# Yuanqi did not cross the rating margin within the specified range.
# Failed to fetch rating history for arnavwinner. Status code: 503
# Failed to fetch rating history for lcs2020068. Status code: 503
# Failed to fetch rating history for xfrog. Status code: 503
# Failed to fetch rating history for PH0T0N. Status code: 503
# Failed to fetch rating history for Yashhhh_Gupta. Status code: 503
# ZNOL did not cross the rating margin within the specified range.
# Failed to fetch rating history for are_roses_rosie. Status code: 503
# Failed to fetch rating history for mangooooo. Status code: 503
# Dinrod did not cross the rating margin within the specified range.
# Failed to fetch rating history for _.wizard._. Status code: 503
# arjun_9426 did not cross the rating margin within the specified range.
# codinger did not cross the rating margin within the specified range.
# Failed to fetch rating history for Kel_Mahmut. Status code: 503
# Failed to fetch rating history for _ek_. Status code: 503
# Failed to fetch rating history for prashant449. Status code: 503
# Dreamer96 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Lu-li. Status code: 503
# Failed to fetch rating history for alicanyaz. Status code: 503
# fmj_123 did not cross the rating margin within the specified range.
# mateberishvili did not cross the rating margin within the specified range.
# nlazouski did not cross the rating margin within the specified range.
# vdanh7277 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Lavish_Sachdeva. Status code: 503
# Failed to fetch rating history for _Roronoa_Zoro. Status code: 503
# Failed to fetch rating history for codingIsFun1234. Status code: 503
# Failed to fetch rating history for nyyjshcz. Status code: 503
# Failed to fetch rating history for KatrinaU7. Status code: 503
# Failed to fetch rating history for dhruv_g04. Status code: 503
# Failed to fetch rating history for pro_ratan. Status code: 503
# Failed to fetch rating history for JoksimKaktus. Status code: 503
# Failed to fetch rating history for Maryto. Status code: 503
# Failed to fetch rating history for harsh_2_0_0_2. Status code: 503
# Failed to fetch rating history for AaronLin. Status code: 503
# Failed to fetch rating history for MarStr. Status code: 503
# Failed to fetch rating history for d2s2. Status code: 503
# Failed to fetch rating history for i_am_wiz. Status code: 503
# r-tron18 did not cross the rating margin within the specified range.
# Failed to fetch rating history for seisiroNagi. Status code: 503
# Failed to fetch rating history for ArsNova. Status code: 503
# Failed to fetch rating history for _Shrey_Hehe_. Status code: 503
# Failed to fetch rating history for xINFERNOx. Status code: 503
# Failed to fetch rating history for amit_291. Status code: 503
# Failed to fetch rating history for chengxiangqu. Status code: 503
# cjh2018 did not cross the rating margin within the specified range.
# Failed to fetch rating history for kaustabhmishra. Status code: 503
# Failed to fetch rating history for w.codeforces. Status code: 503
# Failed to fetch rating history for Lasternxu. Status code: 503
# Failed to fetch rating history for PratyushJha254. Status code: 503
# Failed to fetch rating history for arman_garg_03. Status code: 503
# Failed to fetch rating history for itztooeasy. Status code: 503
# Failed to fetch rating history for MohamedMamdouh19. Status code: 503
# Failed to fetch rating history for liuaaa. Status code: 503
# WaterSpellbinder did not cross the rating margin within the specified range.
# emptyboxs did not cross the rating margin within the specified range.
# Failed to fetch rating history for intsad. Status code: 503
# Failed to fetch rating history for yijiezhu. Status code: 503
# Failed to fetch rating history for blackcoder0212. Status code: 503
# Failed to fetch rating history for srahulsriram. Status code: 503
# Failed to fetch rating history for decentcoder. Status code: 503
# Failed to fetch rating history for nischithp2003. Status code: 503
# Failed to fetch rating history for WaWAKing2023. Status code: 503
# Failed to fetch rating history for whatisthis132. Status code: 503
# Emperor_Nazer did not cross the rating margin within the specified range.
# ManFromMoon did not cross the rating margin within the specified range.
# Failed to fetch rating history for Osama.Rafat100. Status code: 503
#              Handle  Max Rating Result
# 0          nsp-0111        1465     No
# 1             ota09        1407     No
# 2        paglupanda        1436     No
# 3        pawan_8120        1495     No
# 4    prathamvasani1        1405     No
# ..              ...         ...    ...
# 495   whatisthis132        1466    N/A
# 496       0codeGod0        1774     No
# 497   Emperor_Nazer        1419    N/A
# 498     ManFromMoon        1541    N/A
# 499  Osama.Rafat100        1435    N/A
#
# [500 rows x 3 columns]
