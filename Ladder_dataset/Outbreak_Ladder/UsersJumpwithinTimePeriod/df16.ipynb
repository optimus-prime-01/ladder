# %%
import requests
from datetime import datetime
import pandas as pd
df=pd.read_csv('df16.csv')
import json
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1200
    target_upper = 1400

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 20 <= days_taken <= 40:
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
df.to_csv('outdf16.csv', index=False)
# Out:
# ylcs did not cross the rating margin within the specified range.
# Nagasai74 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Nurex_001. Status code: 503
# Failed to fetch rating history for SopaconK. Status code: 503
# Failed to fetch rating history for an310. Status code: 503
# Failed to fetch rating history for luohhhhh. Status code: 503
# Failed to fetch rating history for Aiden_02. Status code: 503
# Failed to fetch rating history for KevinNgocNinh. Status code: 503
# Failed to fetch rating history for Salo_. Status code: 503
# Failed to fetch rating history for TheWpingMonk. Status code: 503
# _Ali_ did not cross the rating margin within the specified range.
# Failed to fetch rating history for aditya0610. Status code: 503
# Failed to fetch rating history for depressive_kid. Status code: 503
# Failed to fetch rating history for karashi_. Status code: 503
# Failed to fetch rating history for max0n. Status code: 503
# Failed to fetch rating history for reboot_jocker. Status code: 503
# rockoanna did not cross the rating margin within the specified range.
# Failed to fetch rating history for tahm_id. Status code: 503
# Failed to fetch rating history for 123456L. Status code: 503
# Failed to fetch rating history for HonaNguyen. Status code: 503
# Kian_1t did not cross the rating margin within the specified range.
# Failed to fetch rating history for ankur0508. Status code: 503
# Failed to fetch rating history for blackole. Status code: 503
# Failed to fetch rating history for hungcubuso3vn. Status code: 503
# Failed to fetch rating history for khushi1000. Status code: 503
# Failed to fetch rating history for nemutai. Status code: 503
# Failed to fetch rating history for temporaryidhai. Status code: 503
# Failed to fetch rating history for ymmm_. Status code: 503
# Failed to fetch rating history for DIPANKAR-123. Status code: 503
# Dcln did not cross the rating margin within the specified range.
# Failed to fetch rating history for HGENDAS. Status code: 503
# Failed to fetch rating history for L1bra. Status code: 503
# Failed to fetch rating history for aanjaneyeah. Status code: 503
# Failed to fetch rating history for ngma. Status code: 503
# song did not cross the rating margin within the specified range.
# Failed to fetch rating history for wolf359y. Status code: 503
# Failed to fetch rating history for NICCspy. Status code: 503
# Failed to fetch rating history for heittpr. Status code: 503
# Failed to fetch rating history for md_hakim. Status code: 503
# nazmuShakib did not cross the rating margin within the specified range.
# Failed to fetch rating history for razoncdr. Status code: 503
# Failed to fetch rating history for Alleb. Status code: 503
# Failed to fetch rating history for Goku-_-. Status code: 503
# Failed to fetch rating history for Tangle-d. Status code: 503
# Failed to fetch rating history for eyfmharb. Status code: 503
# Failed to fetch rating history for mindstuck. Status code: 503
# nai_he did not cross the rating margin within the specified range.
# Failed to fetch rating history for shubhraneel. Status code: 503
# Failed to fetch rating history for xYang_a1a2. Status code: 503
# Failed to fetch rating history for Chiradi. Status code: 503
# Failed to fetch rating history for MohamedG4. Status code: 503
# Failed to fetch rating history for adannklgdnglk. Status code: 503
# Failed to fetch rating history for Anuj2909. Status code: 503
# Failed to fetch rating history for Itisa. Status code: 503
# Failed to fetch rating history for RedSnow389. Status code: 503
# Failed to fetch rating history for algohary. Status code: 503
# Failed to fetch rating history for i_am_pratik. Status code: 503
# Failed to fetch rating history for maldhanio. Status code: 503
# Failed to fetch rating history for 00Noob. Status code: 503
# Failed to fetch rating history for EKPDF. Status code: 503
# IrisQAQ did not cross the rating margin within the specified range.
# Failed to fetch rating history for MD0. Status code: 503
# Failed to fetch rating history for _captain_awesome_. Status code: 503
# Failed to fetch rating history for az77927792. Status code: 503
# Failed to fetch rating history for izzet_RalZarek. Status code: 503
# Failed to fetch rating history for mamenta. Status code: 503
# Failed to fetch rating history for 201716080213. Status code: 503
# Bad_beans did not cross the rating margin within the specified range.
# Failed to fetch rating history for Eradaw_Ajup. Status code: 503
# Failed to fetch rating history for Sandeepbollepally. Status code: 503
# Failed to fetch rating history for That_Boy_khem. Status code: 503
# Xutzu358 did not cross the rating margin within the specified range.
# Failed to fetch rating history for icpy. Status code: 503
# Failed to fetch rating history for manavminsk. Status code: 503
# Failed to fetch rating history for CodingPokemon. Status code: 503
# IngaleAnkur10 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Iruri. Status code: 503
# Failed to fetch rating history for Lyn.ch_. Status code: 503
# Failed to fetch rating history for MOHIR_MBSTU. Status code: 503
# Failed to fetch rating history for Pendem. Status code: 503
# Failed to fetch rating history for chandan_. Status code: 503
# cho12 did not cross the rating margin within the specified range.
# Failed to fetch rating history for dazlersan1. Status code: 503
# Failed to fetch rating history for killerddy. Status code: 503
# Failed to fetch rating history for puremg. Status code: 503
# Failed to fetch rating history for vijender_8601. Status code: 503
# Failed to fetch rating history for Aryaman91126. Status code: 503
# Failed to fetch rating history for amirrezashams. Status code: 503
# Failed to fetch rating history for rkpcode. Status code: 503
# Failed to fetch rating history for yash.. Status code: 503
# Failed to fetch rating history for SzotkowskiJ. Status code: 503
# Failed to fetch rating history for candy34. Status code: 503
# Failed to fetch rating history for giaminh8368. Status code: 503
# Failed to fetch rating history for nhatnh.hust. Status code: 503
# Failed to fetch rating history for vada_pav. Status code: 503
# Aymane_Moutei did not cross the rating margin within the specified range.
# Failed to fetch rating history for Ccm1225. Status code: 503
# Failed to fetch rating history for Mostima_Y. Status code: 503
# Failed to fetch rating history for OneLast. Status code: 503
# RasnaOrMojito did not cross the rating margin within the specified range.
# Failed to fetch rating history for VincentZh. Status code: 503
# Failed to fetch rating history for hoiii. Status code: 503
# Failed to fetch rating history for loiyabsko. Status code: 503
# Failed to fetch rating history for Mohamed_Waheed_Saeed. Status code: 503
# Failed to fetch rating history for XiCen. Status code: 503
# Failed to fetch rating history for ash88. Status code: 503
# Failed to fetch rating history for chenjjjrrr. Status code: 503
# Failed to fetch rating history for jixingtian111. Status code: 503
# Failed to fetch rating history for shekharsudhanshu8352. Status code: 503
# Failed to fetch rating history for JOE362. Status code: 503
# Failed to fetch rating history for Kill_WA. Status code: 503
# Failed to fetch rating history for aleber451. Status code: 503
# Failed to fetch rating history for gargshivam204. Status code: 503
# Failed to fetch rating history for ilost2code. Status code: 503
# Failed to fetch rating history for iuop. Status code: 503
# Failed to fetch rating history for BomberKing. Status code: 503
# Failed to fetch rating history for Deep_23_02. Status code: 503
# Failed to fetch rating history for Khoulio. Status code: 503
# Failed to fetch rating history for Moustafa-Mohamed. Status code: 503
# Failed to fetch rating history for chronicsvss. Status code: 503
# Failed to fetch rating history for supers_star. Status code: 503
# Failed to fetch rating history for tchuana4. Status code: 503
# Failed to fetch rating history for HarshRaj29. Status code: 503
# Failed to fetch rating history for Ken1000minus7. Status code: 503
# Failed to fetch rating history for MeEzOo_. Status code: 503
# Failed to fetch rating history for MysticSlice. Status code: 503
# RamInBoots did not cross the rating margin within the specified range.
# Failed to fetch rating history for ashibh. Status code: 503
# Failed to fetch rating history for bdyby101. Status code: 503
# Failed to fetch rating history for mdfaabrar257. Status code: 503
# p5imoes did not cross the rating margin within the specified range.
# Failed to fetch rating history for rafi. Status code: 503
# sanchit24 did not cross the rating margin within the specified range.
# Failed to fetch rating history for sigmamale. Status code: 503
# Failed to fetch rating history for Antila. Status code: 503
# Failed to fetch rating history for Hex_10EFFB_. Status code: 503
# Failed to fetch rating history for NayakPenguin. Status code: 503
# Failed to fetch rating history for Neel-Prabhanjan. Status code: 503
# Failed to fetch rating history for _Findo_. Status code: 503
# Failed to fetch rating history for aadityaraj. Status code: 503
# Failed to fetch rating history for dhruvgupta03. Status code: 503
# Failed to fetch rating history for nectarl. Status code: 503
# Failed to fetch rating history for rezidentura. Status code: 503
# Failed to fetch rating history for sorry_hardstone. Status code: 503
# Pawan_29 did not cross the rating margin within the specified range.
# Sandeep_P did not cross the rating margin within the specified range.
# Failed to fetch rating history for javiergm06. Status code: 503
# Failed to fetch rating history for little_ge. Status code: 503
# Failed to fetch rating history for shao_h_y. Status code: 503
# Failed to fetch rating history for Dhruv_Garg07. Status code: 503
# Failed to fetch rating history for MuQ. Status code: 503
# Failed to fetch rating history for Remote_Dream. Status code: 503
# Failed to fetch rating history for alt_abhi. Status code: 503
# Failed to fetch rating history for legend_palash. Status code: 503
# Failed to fetch rating history for stubborn_1. Status code: 503
# Arthas did not cross the rating margin within the specified range.
# Failed to fetch rating history for czkxiaoxiaohao. Status code: 503
# Failed to fetch rating history for onkar_somani. Status code: 503
# Failed to fetch rating history for skarr4616. Status code: 503
# Failed to fetch rating history for AlokPurbey. Status code: 503
# SakuyaQwQ did not cross the rating margin within the specified range.
# Failed to fetch rating history for Siunkyo. Status code: 503
# Failed to fetch rating history for 202261008000226. Status code: 503
# Failed to fetch rating history for KIRA_p01. Status code: 503
# Failed to fetch rating history for RaisingMoon. Status code: 503
#               Handle  Max Rating Result
# 0           giao_abc        1492    Yes
# 1    mridulkaran2014        1527    Yes
# 2     nasir_bashirov        1492    Yes
# 3        nicecoder37        1660     No
# 4        rahilshah17        1529    Yes
# ..               ...         ...    ...
# 495   Moonshine_sake        1604     No
# 496     PrakshalJain        1467     No
# 497      RaisingMoon        1488    N/A
# 498          Ritik24        1529    Yes
# 499      Ruthvik2835        1497    Yes
#
# [500 rows x 3 columns]
