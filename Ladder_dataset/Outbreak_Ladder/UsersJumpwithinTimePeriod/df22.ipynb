# %%
import requests
from datetime import datetime
import pandas as pd
df=pd.read_csv('df22.csv')
import json
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1200
    target_upper = 1400

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 20 <= days_taken <= 40:
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
df.to_csv('outdf22.csv', index=False)
# Out:
# dthieu did not cross the rating margin within the specified range.
# Failed to fetch rating history for llaminator. Status code: 503
# sp4c3_c0wb0y did not cross the rating margin within the specified range.
# arutsudar did not cross the rating margin within the specified range.
# Failed to fetch rating history for ErenYeagar. Status code: 503
# Failed to fetch rating history for MJavad. Status code: 503
# Failed to fetch rating history for monji. Status code: 503
# sibuna did not cross the rating margin within the specified range.
# Andrevv did not cross the rating margin within the specified range.
# Failed to fetch rating history for Zzyzzx38. Status code: 503
# saddam did not cross the rating margin within the specified range.
# Failed to fetch rating history for siamsplash5. Status code: 503
# Failed to fetch rating history for Hatem25. Status code: 503
# sandro.dia did not cross the rating margin within the specified range.
# Failed to fetch rating history for Contest_Mess. Status code: 503
# Failed to fetch rating history for killer4585654. Status code: 503
# leoair did not cross the rating margin within the specified range.
# nuclear did not cross the rating margin within the specified range.
# Failed to fetch rating history for rajatupadhyay9. Status code: 503
# Failed to fetch rating history for Llop. Status code: 503
# Failed to fetch rating history for akie_123. Status code: 503
# whoisthat did not cross the rating margin within the specified range.
# Failed to fetch rating history for Knob_123. Status code: 503
# Failed to fetch rating history for Tri2k6. Status code: 503
# Failed to fetch rating history for anas_allaham. Status code: 503
# Failed to fetch rating history for H_a_r_M_i_t. Status code: 503
# Failed to fetch rating history for _heisenberg. Status code: 503
# Failed to fetch rating history for death4monarch. Status code: 503
# Failed to fetch rating history for henry25. Status code: 503
# Failed to fetch rating history for yeling. Status code: 503
# Heisenberg_71 did not cross the rating margin within the specified range.
# Failed to fetch rating history for LuckyCc.. Status code: 503
# Failed to fetch rating history for infinity567. Status code: 503
# Failed to fetch rating history for Frankczy. Status code: 503
# Failed to fetch rating history for naman_cf. Status code: 503
# Failed to fetch rating history for OgataShumaHiroyuki. Status code: 503
# ikeha did not cross the rating margin within the specified range.
# weird_penguin did not cross the rating margin within the specified range.
# EDkinGG did not cross the rating margin within the specified range.
# Failed to fetch rating history for Farewell1022. Status code: 503
# Failed to fetch rating history for Rafael_Y. Status code: 503
# zenwraight did not cross the rating margin within the specified range.
# Failed to fetch rating history for Lets_Anjoy. Status code: 503
# Failed to fetch rating history for kingsenior. Status code: 503
# Failed to fetch rating history for rating_underflow_error. Status code: 503
# tautology did not cross the rating margin within the specified range.
# Failed to fetch rating history for AAI. Status code: 503
# Failed to fetch rating history for Faizan_43. Status code: 503
# Kemo_ did not cross the rating margin within the specified range.
# Failed to fetch rating history for Manav_27. Status code: 503
# Failed to fetch rating history for PremRathod. Status code: 503
# Failed to fetch rating history for _destiny_. Status code: 503
# Failed to fetch rating history for freaksier. Status code: 503
# Failed to fetch rating history for kssabhinav. Status code: 503
# Failed to fetch rating history for laysky. Status code: 503
# roadbike80 did not cross the rating margin within the specified range.
# Failed to fetch rating history for shiny_sur_co. Status code: 503
# Failed to fetch rating history for CodeGod1202. Status code: 503
# Failed to fetch rating history for Ghostdog. Status code: 503
# Failed to fetch rating history for gaidash. Status code: 503
# Failed to fetch rating history for imsnto. Status code: 503
# Chilllll did not cross the rating margin within the specified range.
# Failed to fetch rating history for ILovveyyou. Status code: 503
# Failed to fetch rating history for sacave. Status code: 503
# Failed to fetch rating history for Evadra_tourist. Status code: 503
# LordAditya did not cross the rating margin within the specified range.
# Failed to fetch rating history for MallaSailesh. Status code: 503
# gsomani did not cross the rating margin within the specified range.
# Failed to fetch rating history for type-N. Status code: 503
# Failed to fetch rating history for Lilichar. Status code: 503
# Failed to fetch rating history for Mocaa. Status code: 503
# Failed to fetch rating history for TANJIR0U. Status code: 503
# jiaxingCookie did not cross the rating margin within the specified range.
# Failed to fetch rating history for koder100. Status code: 503
# trash7007 did not cross the rating margin within the specified range.
# Failed to fetch rating history for swami48. Status code: 503
# Failed to fetch rating history for Descend. Status code: 503
# Inception02 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Jarvis2000. Status code: 503
# Mahbub_Rafi did not cross the rating margin within the specified range.
# Failed to fetch rating history for prahladhareddyramireddy. Status code: 503
# Failed to fetch rating history for Hi_im_Su. Status code: 503
# Mangoj did not cross the rating margin within the specified range.
# Failed to fetch rating history for Yagnik_Dhameliya. Status code: 503
# Failed to fetch rating history for fwheyun. Status code: 503
# Failed to fetch rating history for chalex2k. Status code: 503
# nikhil97agra did not cross the rating margin within the specified range.
# paveltrty did not cross the rating margin within the specified range.
# Failed to fetch rating history for yihang_01. Status code: 503
# 2018339901318 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Radon23. Status code: 503
# Failed to fetch rating history for ace055. Status code: 503
# pathan_coder did not cross the rating margin within the specified range.
# Failed to fetch rating history for vidittayal. Status code: 503
# Failed to fetch rating history for TheBlueFriend. Status code: 503
# Failed to fetch rating history for breaktheshell. Status code: 503
# Failed to fetch rating history for kamenshik. Status code: 503
# samarth_tandon did not cross the rating margin within the specified range.
# Failed to fetch rating history for vedprakashsingh216. Status code: 503
# RF_Faisal did not cross the rating margin within the specified range.
# Vitaliya did not cross the rating margin within the specified range.
# emanuel2700 did not cross the rating margin within the specified range.
# Failed to fetch rating history for furon. Status code: 503
# HarshKh_13 did not cross the rating margin within the specified range.
# Failed to fetch rating history for PoseiDon_10. Status code: 503
# Failed to fetch rating history for abcd_1234. Status code: 503
# misleader did not cross the rating margin within the specified range.
# Failed to fetch rating history for mkv29. Status code: 503
# Failed to fetch rating history for BeDuck. Status code: 503
# Zhanzhe_Lee did not cross the rating margin within the specified range.
# dustindward did not cross the rating margin within the specified range.
# Failed to fetch rating history for ultimatepk. Status code: 503
# Failed to fetch rating history for mukesh_v12. Status code: 503
# yatharth_ did not cross the rating margin within the specified range.
# Failed to fetch rating history for TLE_MAN. Status code: 503
# Failed to fetch rating history for greed024. Status code: 503
# ymm did not cross the rating margin within the specified range.
# __vladimir__ did not cross the rating margin within the specified range.
# Failed to fetch rating history for sarvu_don37. Status code: 503
# Failed to fetch rating history for sunny_76. Status code: 503
# Failed to fetch rating history for abhay_135. Status code: 503
# amnsng did not cross the rating margin within the specified range.
# manuver did not cross the rating margin within the specified range.
# Failed to fetch rating history for ponmari. Status code: 503
# Failed to fetch rating history for ando. Status code: 503
# Failed to fetch rating history for wuuuz. Status code: 503
# shvetsovamd did not cross the rating margin within the specified range.
# Failed to fetch rating history for thasin_sheikh. Status code: 503
# Failed to fetch rating history for wKai000. Status code: 503
# Prince_of_Azkaban did not cross the rating margin within the specified range.
# ZobninVladislav_It-Team did not cross the rating margin within the specified range.
# Failed to fetch rating history for sansk3003. Status code: 503
# Failed to fetch rating history for pdthang2000. Status code: 503
# yaroslavspid2 did not cross the rating margin within the specified range.
# Failed to fetch rating history for dipakbaghel47. Status code: 503
# Failed to fetch rating history for guesshere. Status code: 503
# Failed to fetch rating history for KienPS. Status code: 503
# Failed to fetch rating history for _ZERO____. Status code: 503
# jyjy1229 did not cross the rating margin within the specified range.
# Failed to fetch rating history for kr_vishal. Status code: 503
# Failed to fetch rating history for skroll. Status code: 503
# Failed to fetch rating history for Mhmud_Sameh24. Status code: 503
# kipling did not cross the rating margin within the specified range.
# Failed to fetch rating history for stasemv. Status code: 503
# Failed to fetch rating history for ankit_0407. Status code: 503
# Failed to fetch rating history for Harmony666. Status code: 503
# Failed to fetch rating history for I_Will_Succeed_Some_Day. Status code: 503
# Failed to fetch rating history for Bhscer. Status code: 503
# botayhard did not cross the rating margin within the specified range.
# Failed to fetch rating history for handofgod. Status code: 503
# Failed to fetch rating history for varshney.nishkam2909. Status code: 503
# Failed to fetch rating history for GREED_VI. Status code: 503
# Failed to fetch rating history for anuragkumar06243. Status code: 503
# Failed to fetch rating history for nutella_Palestine. Status code: 503
# Failed to fetch rating history for Nuagen. Status code: 503
# Failed to fetch rating history for Mac_prime. Status code: 503
# ibraGYM did not cross the rating margin within the specified range.
# Failed to fetch rating history for lazywitt. Status code: 503
# Failed to fetch rating history for Shamim97. Status code: 503
# 28th did not cross the rating margin within the specified range.
# Failed to fetch rating history for FeelMywrath. Status code: 503
# Failed to fetch rating history for RootCareer. Status code: 503
# Failed to fetch rating history for do_full_stuffs. Status code: 503
# Failed to fetch rating history for sameeh.hussein. Status code: 503
# Ichimaru31 did not cross the rating margin within the specified range.
# NewbieMisis did not cross the rating margin within the specified range.
# Failed to fetch rating history for SixSing_CHOC. Status code: 503
# Failed to fetch rating history for qfxrsnkbg. Status code: 503
# MaxWelll did not cross the rating margin within the specified range.
# Failed to fetch rating history for Soccer_7. Status code: 503
# __johnwick did not cross the rating margin within the specified range.
# red_one_fine_day did not cross the rating margin within the specified range.
# Failed to fetch rating history for Himanshu_13. Status code: 503
# MERSH did not cross the rating margin within the specified range.
# Failed to fetch rating history for Spawnpoint. Status code: 503
# __FireBlade__ did not cross the rating margin within the specified range.
# Failed to fetch rating history for HustleAura. Status code: 503
# Failed to fetch rating history for sumijie. Status code: 503
# Failed to fetch rating history for SQRock. Status code: 503
# sanban did not cross the rating margin within the specified range.
# Gurjeet did not cross the rating margin within the specified range.
# Failed to fetch rating history for anandiscoding. Status code: 503
# Failed to fetch rating history for Anchord. Status code: 503
# Failed to fetch rating history for lazyhash. Status code: 503
# Failed to fetch rating history for georgii03. Status code: 503
# tivancev did not cross the rating margin within the specified range.
# Failed to fetch rating history for Keramine. Status code: 503
# Taik0 did not cross the rating margin within the specified range.
# Govardhan did not cross the rating margin within the specified range.
# Viper35 did not cross the rating margin within the specified range.
# himanshubhardwaj169 did not cross the rating margin within the specified range.
# Failed to fetch rating history for surya001. Status code: 503
# Eagle_7 did not cross the rating margin within the specified range.
# Failed to fetch rating history for MOHAMED--KHALED. Status code: 503
# Failed to fetch rating history for CRUSD. Status code: 503
# Failed to fetch rating history for TheYoung. Status code: 503
# nawin did not cross the rating margin within the specified range.
# Failed to fetch rating history for DarkLancer. Status code: 503
# phongan105 did not cross the rating margin within the specified range.
# Failed to fetch rating history for KamruL_Hasan_. Status code: 503
# Failed to fetch rating history for Litzed. Status code: 503
# erkhaan did not cross the rating margin within the specified range.
# Failed to fetch rating history for M-Alijon. Status code: 503
# Failed to fetch rating history for HarshitShukla__. Status code: 503
#                Handle  Max Rating Result
# 0        sasidhar_msr        1408     No
# 1      silenttkillerr        1721     No
# 2             thsinak        1416     No
# 3              Kacchi        1538     No
# 4            TheILICH        1435     No
# ..                ...         ...    ...
# 495          M-Alijon        1591    N/A
# 496        aozeritsky        1410     No
# 497  ibrahimsalman277        1424     No
# 498   HarshitShukla__        1432    N/A
# 499              MHDS        1428     No
#
# [500 rows x 3 columns]
