# %%
import requests
from datetime import datetime
import pandas as pd
df=pd.read_csv('df21.csv')
import json
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1200
    target_upper = 1400

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 20 <= days_taken <= 40:
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
df.to_csv('outdf21.csv', index=False)
# Out:
# onlyhim did not cross the rating margin within the specified range.
# Failed to fetch rating history for KritarthBatra. Status code: 503
# presnakovoleg0768 did not cross the rating margin within the specified range.
# Failed to fetch rating history for AkramKhan. Status code: 503
# Failed to fetch rating history for Tim2004. Status code: 503
# Failed to fetch rating history for tcskiran. Status code: 503
# Arcan3 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Arju_365i. Status code: 503
# Gjc_wq_cj did not cross the rating margin within the specified range.
# PapelFlame did not cross the rating margin within the specified range.
# Failed to fetch rating history for TJSW. Status code: 503
# Failed to fetch rating history for mini-knight. Status code: 503
# Failed to fetch rating history for Fangio. Status code: 503
# Genin_Konoha did not cross the rating margin within the specified range.
# Failed to fetch rating history for Huascar. Status code: 503
# Failed to fetch rating history for catlover1. Status code: 503
# Failed to fetch rating history for symmetrybreaking. Status code: 503
# Failed to fetch rating history for mbhuiyan071. Status code: 503
# Failed to fetch rating history for yushae3405. Status code: 503
# Kalle did not cross the rating margin within the specified range.
# Failed to fetch rating history for ayushsahu_124. Status code: 503
# Failed to fetch rating history for ritik_patel05. Status code: 503
# Failed to fetch rating history for CYFly. Status code: 503
# Failed to fetch rating history for Zephyr94. Status code: 503
# Failed to fetch rating history for corn_salad. Status code: 503
# Failed to fetch rating history for neganega. Status code: 503
# Denis_Hurski did not cross the rating margin within the specified range.
# Failed to fetch rating history for TFKls. Status code: 503
# cbaaabc did not cross the rating margin within the specified range.
# Failed to fetch rating history for ks89417. Status code: 503
# Failed to fetch rating history for ITcharDo. Status code: 503
# Failed to fetch rating history for I_am_Jacks_FOMO. Status code: 503
# Failed to fetch rating history for anubhavkambojmrt. Status code: 503
# dp_man did not cross the rating margin within the specified range.
# Failed to fetch rating history for elEctroWolf. Status code: 503
# Failed to fetch rating history for shiranui_. Status code: 503
# Failed to fetch rating history for Ishi07. Status code: 503
# Lukagen did not cross the rating margin within the specified range.
# Failed to fetch rating history for SriVitthal8. Status code: 503
# Failed to fetch rating history for forever-striver. Status code: 503
# Failed to fetch rating history for m_yousuf123. Status code: 503
# Failed to fetch rating history for speed_geek. Status code: 503
# Failed to fetch rating history for HFlenz. Status code: 503
# Failed to fetch rating history for Platanito_Frito. Status code: 503
# Failed to fetch rating history for chrislaiisme. Status code: 503
# Failed to fetch rating history for spacetone. Status code: 503
# ConvexChill did not cross the rating margin within the specified range.
# LastStade did not cross the rating margin within the specified range.
# Failed to fetch rating history for Radioactive_. Status code: 503
# WorldKeeper did not cross the rating margin within the specified range.
# Failed to fetch rating history for blankh. Status code: 503
# sirawitch222 did not cross the rating margin within the specified range.
# Failed to fetch rating history for EslamSamy2002. Status code: 503
# Necromacer did not cross the rating margin within the specified range.
# Failed to fetch rating history for Yumesekai239. Status code: 503
# Failed to fetch rating history for mornstar. Status code: 503
# Failed to fetch rating history for ritvik369. Status code: 503
# zlatan_7 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Pratham2908. Status code: 503
# Failed to fetch rating history for Wonder_08. Status code: 503
# Failed to fetch rating history for Armita.Alimardani. Status code: 503
# Failed to fetch rating history for Sid__. Status code: 503
# Failed to fetch rating history for dvkcool. Status code: 503
# Failed to fetch rating history for savyasachi. Status code: 503
# Failed to fetch rating history for abusayeid. Status code: 503
# Failed to fetch rating history for jiangqiao. Status code: 503
# Failed to fetch rating history for mihiragrawal2012. Status code: 503
# abhishekark17 did not cross the rating margin within the specified range.
# Failed to fetch rating history for dexter3542.0. Status code: 503
# Failed to fetch rating history for purplelemon. Status code: 503
# Failed to fetch rating history for nlk_12. Status code: 503
# LegendLooser did not cross the rating margin within the specified range.
# Michaelowski did not cross the rating margin within the specified range.
# Failed to fetch rating history for StenSoSmol. Status code: 503
# sahil9032 did not cross the rating margin within the specified range.
# Failed to fetch rating history for vishalsingh24. Status code: 503
# Failed to fetch rating history for AktanTursunbaev. Status code: 503
# NADIDADIT did not cross the rating margin within the specified range.
# Failed to fetch rating history for talent_not_defined. Status code: 503
# gsvana13 did not cross the rating margin within the specified range.
# Failed to fetch rating history for tikhar. Status code: 503
# Failed to fetch rating history for PrerakPro7. Status code: 503
# nethish did not cross the rating margin within the specified range.
# Failed to fetch rating history for rus345. Status code: 503
# Masud-Parvez did not cross the rating margin within the specified range.
# Failed to fetch rating history for am.i.laughing. Status code: 503
# Failed to fetch rating history for starback24. Status code: 503
# Failed to fetch rating history for Frozen-wjl. Status code: 503
# miniac did not cross the rating margin within the specified range.
# Failed to fetch rating history for kikcer. Status code: 503
# Failed to fetch rating history for warm4C0. Status code: 503
# Failed to fetch rating history for Dominic10. Status code: 503
# Failed to fetch rating history for MinGW_JDC. Status code: 503
# Volume999 did not cross the rating margin within the specified range.
# Failed to fetch rating history for atharvaayir. Status code: 503
# Failed to fetch rating history for BrokenBlade. Status code: 503
# Failed to fetch rating history for LU_Hridoy. Status code: 503
# Failed to fetch rating history for deepanshu.singhal16. Status code: 503
# Failed to fetch rating history for maikey007. Status code: 503
# Failed to fetch rating history for BEinTLE. Status code: 503
# Failed to fetch rating history for toomatho. Status code: 503
# Failed to fetch rating history for Amitc78f. Status code: 503
# denisvosipov did not cross the rating margin within the specified range.
# Failed to fetch rating history for escanor_DDD. Status code: 503
# Failed to fetch rating history for kush_cf. Status code: 503
# Failed to fetch rating history for qrupafjzvm1. Status code: 503
# DonSilvio did not cross the rating margin within the specified range.
# Failed to fetch rating history for DumbbAlgo. Status code: 503
# Failed to fetch rating history for Sevak.Yegoryan. Status code: 503
# Failed to fetch rating history for spicybutter123. Status code: 503
# 5555aled did not cross the rating margin within the specified range.
# Failed to fetch rating history for heaven2808h. Status code: 503
# thomoncik did not cross the rating margin within the specified range.
# Failed to fetch rating history for wangchongyue. Status code: 503
# Failed to fetch rating history for Wekasbeniwal. Status code: 503
# Failed to fetch rating history for laullelien. Status code: 503
# Failed to fetch rating history for piyuagr. Status code: 503
# Failed to fetch rating history for Chiefash. Status code: 503
# Failed to fetch rating history for _.pain._. Status code: 503
# Failed to fetch rating history for r_us. Status code: 503
# Failed to fetch rating history for Sussybaka228. Status code: 503
# Failed to fetch rating history for Al_Helal_. Status code: 503
# Kishan_143 did not cross the rating margin within the specified range.
# Failed to fetch rating history for niquefa. Status code: 503
# Failed to fetch rating history for Adnanboii. Status code: 503
# Failed to fetch rating history for cohadar. Status code: 503
# fengyuheng did not cross the rating margin within the specified range.
# Failed to fetch rating history for thelastdevil. Status code: 503
# Failed to fetch rating history for Hunt15H. Status code: 503
# Failed to fetch rating history for PrateekTewary. Status code: 503
# Failed to fetch rating history for betusingh890. Status code: 503
# Failed to fetch rating history for noob1204. Status code: 503
# Failed to fetch rating history for xiezijie. Status code: 503
# Failed to fetch rating history for Jackofalltradess. Status code: 503
# Failed to fetch rating history for arsh_v. Status code: 503
# Failed to fetch rating history for rho01. Status code: 503
# Melecichu did not cross the rating margin within the specified range.
# Failed to fetch rating history for Saurav_Kumar. Status code: 503
# Failed to fetch rating history for The_first_in_the_world. Status code: 503
# Failed to fetch rating history for ardeshirelahdadi. Status code: 503
# Failed to fetch rating history for k_ano. Status code: 503
# Failed to fetch rating history for lamdungvngdz. Status code: 503
# Failed to fetch rating history for novaa. Status code: 503
# Failed to fetch rating history for SADIQ_insD. Status code: 503
# Failed to fetch rating history for ampish. Status code: 503
# Failed to fetch rating history for greenbinjack. Status code: 503
# Failed to fetch rating history for petertromso. Status code: 503
#                 Handle  Max Rating Result
# 0            Schmoople        1442     No
# 1               adiyer        1454    Yes
# 2                 br0n        1446     No
# 3          dr.strange0        1506     No
# 4                  jV_        1605    Yes
# ..                 ...         ...    ...
# 495         ekeshwarj5        1473    Yes
# 496       greenbinjack        1599    N/A
# 497            lregion        1420    Yes
# 498        petertromso        1650    N/A
# 499  pranpotatocracker        1421     No
#
# [500 rows x 3 columns]
