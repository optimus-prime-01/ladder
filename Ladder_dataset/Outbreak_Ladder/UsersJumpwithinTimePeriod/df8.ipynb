# %%
import requests
from datetime import datetime
import pandas as pd
df=pd.read_csv('df8.csv')
import json
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1200
    target_upper = 1400

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 20 <= days_taken <= 40:
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
# Out:
# kanakgautam did not cross the rating margin within the specified range.
# Doremivs did not cross the rating margin within the specified range.
# GreenKitty did not cross the rating margin within the specified range.
# __james1 did not cross the rating margin within the specified range.
# Failed to fetch rating history for cypher_king. Status code: 503
# Failed to fetch rating history for MTX_AS. Status code: 503
# Failed to fetch rating history for hnust_liuyunzhi1. Status code: 503
# Failed to fetch rating history for samuel.coulomb. Status code: 503
# Failed to fetch rating history for Irene. Status code: 503
# Failed to fetch rating history for lamter. Status code: 503
# plastical did not cross the rating margin within the specified range.
# Failed to fetch rating history for tan45. Status code: 503
# Failed to fetch rating history for Jacksonrr. Status code: 503
# Failed to fetch rating history for WildWeasel. Status code: 503
# Failed to fetch rating history for atak1. Status code: 503
# Failed to fetch rating history for vijay270619. Status code: 503
# Failed to fetch rating history for xujindong1. Status code: 503
# Failed to fetch rating history for LarrixAntofanin. Status code: 503
# Failed to fetch rating history for ParhamTadayon. Status code: 503
# anonymous_01 did not cross the rating margin within the specified range.
# Failed to fetch rating history for lftroq. Status code: 503
# Failed to fetch rating history for tempid.. Status code: 503
# Failed to fetch rating history for MuRongzhang. Status code: 503
# Failed to fetch rating history for Xarma. Status code: 503
# Failed to fetch rating history for dajeff. Status code: 503
# Failed to fetch rating history for Chrisedyong. Status code: 503
# Failed to fetch rating history for Kakarrot-. Status code: 503
# Failed to fetch rating history for helioWorld. Status code: 503
# Failed to fetch rating history for ishwarendra. Status code: 503
# Failed to fetch rating history for Stormersyle. Status code: 503
# Failed to fetch rating history for YKheifets. Status code: 503
# Failed to fetch rating history for emir_raze. Status code: 503
# Failed to fetch rating history for fantasma. Status code: 503
# Failed to fetch rating history for sourav_suku. Status code: 503
# Failed to fetch rating history for wtc. Status code: 503
# Ben_shooter2 did not cross the rating margin within the specified range.
# Failed to fetch rating history for El_Medonho. Status code: 503
# Failed to fetch rating history for __Secret. Status code: 503
# Failed to fetch rating history for aryan1602. Status code: 503
# Failed to fetch rating history for liby. Status code: 503
# lobo_prix did not cross the rating margin within the specified range.
# Failed to fetch rating history for query_. Status code: 503
# Failed to fetch rating history for ZomaSmurf. Status code: 503
# Failed to fetch rating history for gcx12012. Status code: 503
# katalonecfly did not cross the rating margin within the specified range.
# Failed to fetch rating history for newone2023. Status code: 503
# Failed to fetch rating history for trash2026. Status code: 503
# 111vad111 did not cross the rating margin within the specified range.
# Chaska did not cross the rating margin within the specified range.
# Failed to fetch rating history for MrLolthe1st. Status code: 503
# Failed to fetch rating history for chunzhifeng. Status code: 503
# Failed to fetch rating history for Akshatvj. Status code: 503
# Failed to fetch rating history for Niolle_Semis. Status code: 503
# Failed to fetch rating history for NoiceFi. Status code: 503
# Failed to fetch rating history for a999999. Status code: 503
# hrishabh314 did not cross the rating margin within the specified range.
# sanchitjain333 did not cross the rating margin within the specified range.
# Failed to fetch rating history for edwardnvv57k. Status code: 503
# Failed to fetch rating history for iamdiv5. Status code: 503
# Failed to fetch rating history for shlokagrawal. Status code: 503
# Failed to fetch rating history for sjhi00. Status code: 503
# Failed to fetch rating history for Abraxos. Status code: 503
# Failed to fetch rating history for ICPC_Menofia. Status code: 503
# Failed to fetch rating history for MongHwa. Status code: 503
# Vitaly503 did not cross the rating margin within the specified range.
# Failed to fetch rating history for fOrFUnN. Status code: 503
# Failed to fetch rating history for wifi32767. Status code: 503
# Failed to fetch rating history for ASincereCoder. Status code: 503
# Failed to fetch rating history for Jasonwei08. Status code: 503
# Failed to fetch rating history for KrisjanisP. Status code: 503
# Failed to fetch rating history for Paul-Andre. Status code: 503
# Failed to fetch rating history for namelessly. Status code: 503
# Failed to fetch rating history for quangminh64. Status code: 503
# Failed to fetch rating history for 15372583O23. Status code: 503
# Failed to fetch rating history for FLAME.. Status code: 503
# Failed to fetch rating history for I_am_balancing. Status code: 503
# Metallic did not cross the rating margin within the specified range.
# Failed to fetch rating history for Nahida__. Status code: 503
# Thinkbuge did not cross the rating margin within the specified range.
# Failed to fetch rating history for ajayreddy12123. Status code: 503
# Failed to fetch rating history for drexdelta1. Status code: 503
# Failed to fetch rating history for libolin1. Status code: 503
# Failed to fetch rating history for CodeChild. Status code: 503
# Failed to fetch rating history for Headshooot. Status code: 503
# Failed to fetch rating history for ooscode. Status code: 503
# r_chesnokov did not cross the rating margin within the specified range.
# AmamiyaYuuko did not cross the rating margin within the specified range.
# Failed to fetch rating history for jackson.souza. Status code: 503
# Failed to fetch rating history for naniim. Status code: 503
# Failed to fetch rating history for Gaurav3478. Status code: 503
# Failed to fetch rating history for kb_00. Status code: 503
# _Dragon_ did not cross the rating margin within the specified range.
# Failed to fetch rating history for ailes. Status code: 503
# Failed to fetch rating history for Aukotiq. Status code: 503
# Failed to fetch rating history for DragonO_o. Status code: 503
# omikad did not cross the rating margin within the specified range.
# Failed to fetch rating history for Abo_Samrah. Status code: 503
# Failed to fetch rating history for JaidenShin. Status code: 503
# Failed to fetch rating history for Saanteye. Status code: 503
# Failed to fetch rating history for mathsworm. Status code: 503
# Failed to fetch rating history for vahmad. Status code: 503
# TooManyMind did not cross the rating margin within the specified range.
# Failed to fetch rating history for __FRIDAY__. Status code: 503
# Failed to fetch rating history for trjyyds. Status code: 503
# Failed to fetch rating history for opPO. Status code: 503
# Failed to fetch rating history for tepamid. Status code: 503
# 7oSkaaa did not cross the rating margin within the specified range.
# Failed to fetch rating history for Ansh777. Status code: 503
# Failed to fetch rating history for Greedious. Status code: 503
# Silly did not cross the rating margin within the specified range.
# Failed to fetch rating history for YuXiao. Status code: 503
# i.Pear did not cross the rating margin within the specified range.
# Failed to fetch rating history for muxiuyulin. Status code: 503
# Failed to fetch rating history for GabiTulba. Status code: 503
# Ismail_Alrifai did not cross the rating margin within the specified range.
# Failed to fetch rating history for ulorew. Status code: 503
# Failed to fetch rating history for EthanZYF. Status code: 503
# Failed to fetch rating history for Musab1Blaser. Status code: 503
# Failed to fetch rating history for RatingIsJustANumber. Status code: 503
# Failed to fetch rating history for bananade1. Status code: 503
# Failed to fetch rating history for ilyaytrewq. Status code: 503
# Failed to fetch rating history for nitya9714. Status code: 503
# Failed to fetch rating history for shstyle. Status code: 503
# Failed to fetch rating history for 930851771G. Status code: 503
# Failed to fetch rating history for I_LOVE_RNG. Status code: 503
# Failed to fetch rating history for miniL. Status code: 503
# Failed to fetch rating history for surung9898. Status code: 503
# Bob did not cross the rating margin within the specified range.
# Failed to fetch rating history for LLZZKK. Status code: 503
# Failed to fetch rating history for _Golem_. Status code: 503
# littlegirl112 did not cross the rating margin within the specified range.
# Failed to fetch rating history for orange_juice_1024. Status code: 503
# Failed to fetch rating history for yeaDonaby. Status code: 503
# Failed to fetch rating history for AutumnMist. Status code: 503
# Failed to fetch rating history for Fremder. Status code: 503
# Failed to fetch rating history for RestlessPsycho. Status code: 503
# Failed to fetch rating history for Xinjiang1944. Status code: 503
# avatsavirsa did not cross the rating margin within the specified range.
# Failed to fetch rating history for crzy. Status code: 503
# Failed to fetch rating history for llking. Status code: 503
# r_q did not cross the rating margin within the specified range.
# Failed to fetch rating history for zhtzshhh666. Status code: 503
# Failed to fetch rating history for Rachel_in. Status code: 503
# TLE_Automat did not cross the rating margin within the specified range.
# Failed to fetch rating history for animish01. Status code: 503
# Failed to fetch rating history for 1ightwhite. Status code: 503
# Failed to fetch rating history for Alumin1um. Status code: 503
# Failed to fetch rating history for ShirosakiMieru. Status code: 503
# i3ta did not cross the rating margin within the specified range.
# Failed to fetch rating history for jalalium. Status code: 503
# Failed to fetch rating history for Spidy01. Status code: 503
# _WannaLoveyou did not cross the rating margin within the specified range.
# Failed to fetch rating history for jaxongir0914. Status code: 503
# last_christmas_I_... did not cross the rating margin within the specified range.
# Failed to fetch rating history for somanaik. Status code: 503
# Failed to fetch rating history for Amirreza-Fakhri. Status code: 503
# Failed to fetch rating history for CJ17. Status code: 503
# Failed to fetch rating history for Knightshade. Status code: 503
# Failed to fetch rating history for PyAlpha. Status code: 503
# Failed to fetch rating history for farhan95104. Status code: 503
# Failed to fetch rating history for newbie114514. Status code: 503
# Failed to fetch rating history for radi__07. Status code: 503
# shdut0901 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Cursed_Doughnut. Status code: 503
# Failed to fetch rating history for Oinng. Status code: 503
# Failed to fetch rating history for dreamjoker. Status code: 503
# Failed to fetch rating history for igeee. Status code: 503
# jiangnaihui did not cross the rating margin within the specified range.
# Failed to fetch rating history for mewnya. Status code: 503
# Failed to fetch rating history for s3n. Status code: 503
# Failed to fetch rating history for Hero777. Status code: 503
# Failed to fetch rating history for Juanm1. Status code: 503
# Failed to fetch rating history for PedroGallo. Status code: 503
# Sasha0738 did not cross the rating margin within the specified range.
# Failed to fetch rating history for its_pranjal_83. Status code: 503
# Failed to fetch rating history for liupengsay. Status code: 503
# sebach did not cross the rating margin within the specified range.
# Failed to fetch rating history for trh0630. Status code: 503
# Michailus did not cross the rating margin within the specified range.
# Failed to fetch rating history for Radan. Status code: 503
# Failed to fetch rating history for bhukyatharun216. Status code: 503
# Failed to fetch rating history for jingxi. Status code: 503
# Failed to fetch rating history for margo820. Status code: 503
#               Handle  Max Rating Result
# 0              fanyi        1734     No
# 1     jhaprashant079        1802     No
# 2        kanakgautam        1889    N/A
# 3         luckmaster        1742     No
# 4       pranabpandey        1846     No
# ..               ...         ...    ...
# 495            _enzo        1860     No
# 496  bhukyatharun216        1826    N/A
# 497           jingxi        1695    N/A
# 498         lcf12345        1698     No
# 499         margo820        1737    N/A
#
# [500 rows x 3 columns]

# %%
df.head()
# Out:
#            Handle  Max Rating Result
# 0           fanyi        1734     No
# 1  jhaprashant079        1802     No
# 2     kanakgautam        1889    N/A
# 3      luckmaster        1742     No
# 4    pranabpandey        1846     No

# %%
df.to_csv('outdf8.csv', index=False)
