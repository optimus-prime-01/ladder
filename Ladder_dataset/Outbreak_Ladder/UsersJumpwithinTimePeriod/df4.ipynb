# %%
import requests
from datetime import datetime
import pandas as pd

# %%
df=pd.read_csv('df4.csv')

# %%
import json
def get_codeforces_rating_history(username):
    url = f"https://codeforces.com/api/user.rating?handle={username}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data["status"] == "OK":
                return data["result"]
            else:
                print(f"API Error: {data.get('comment', 'No specific error message provided')}")
        except json.JSONDecodeError:
            print("Invalid JSON response from the API")
    else:
        print(f"Failed to fetch rating history for {username}. Status code: {response.status_code}")

    return None

def days_to_cross_margin(username, target_lower, target_upper):
    rating_history = get_codeforces_rating_history(username)
    
    if rating_history is None:
        return None

    current_rating = None
    start_date = None
    end_date = None

    for entry in rating_history:
        rating = entry["newRating"]
        contest_time = entry["ratingUpdateTimeSeconds"]
        contest_date = datetime.fromtimestamp(contest_time)

        if rating <= target_lower:
            start_date = contest_date
        elif rating >= target_upper:
            end_date = contest_date
            break

    if start_date and end_date:
        days_taken = (end_date - start_date).days
        return days_taken
    else:
        print(f"{username} did not cross the rating margin within the specified range.")
        return None

def add_result_to_dataframe(df):
    df['Result'] = ""
    target_lower = 1200
    target_upper = 1400

    for index, row in df.iterrows():
        username = row['Handle']
        days_taken = days_to_cross_margin(username, target_lower, target_upper)
        
        if days_taken is not None:
            if 20 <= days_taken <= 40:
                df.at[index, 'Result'] = "Yes"
            else:
                df.at[index, 'Result'] = "No"
        else:
            df.at[index, 'Result'] = "N/A"

    return df

if __name__ == "__main__":
    
    df = add_result_to_dataframe(df)

    print(df)
# Out:
# szbszbszb did not cross the rating margin within the specified range.
# markysha did not cross the rating margin within the specified range.
# TianCaiJieJieHaoKeAi did not cross the rating margin within the specified range.
# RED_INSIDE did not cross the rating margin within the specified range.
# Failed to fetch rating history for brown_toad. Status code: 503
# Failed to fetch rating history for sejun. Status code: 503
# Failed to fetch rating history for tanprodium. Status code: 503
# Failed to fetch rating history for slonichobot. Status code: 503
# Failed to fetch rating history for derpwaffle21. Status code: 503
# NiceTryMan did not cross the rating margin within the specified range.
# Failed to fetch rating history for SashaT9. Status code: 503
# TimeWarp101 did not cross the rating margin within the specified range.
# Failed to fetch rating history for fangahawk. Status code: 503
# npip99 did not cross the rating margin within the specified range.
# G00DCOD3R did not cross the rating margin within the specified range.
# Failed to fetch rating history for RoomTemperatureIQ. Status code: 503
# HCCH did not cross the rating margin within the specified range.
# Failed to fetch rating history for Redqwq. Status code: 503
# kzyKT did not cross the rating margin within the specified range.
# Failed to fetch rating history for Dou-Happy. Status code: 503
# JustasZ did not cross the rating margin within the specified range.
# Failed to fetch rating history for MeGustaElArroz23. Status code: 503
# Failed to fetch rating history for stalker120. Status code: 503
# Failed to fetch rating history for 2514631360a. Status code: 503
# Failed to fetch rating history for jamesbamber. Status code: 503
# Failed to fetch rating history for m0nster.eXe. Status code: 503
# Failed to fetch rating history for espr1t. Status code: 503
# Failed to fetch rating history for squaredog. Status code: 503
# ultizet did not cross the rating margin within the specified range.
# Early did not cross the rating margin within the specified range.
# tgehr did not cross the rating margin within the specified range.
# Failed to fetch rating history for PoPularPlusPlus. Status code: 503
# smalyarovsky did not cross the rating margin within the specified range.
# Failed to fetch rating history for blacksquare144. Status code: 503
# Failed to fetch rating history for huangwenyu0301. Status code: 503
# tanao_ did not cross the rating margin within the specified range.
# Failed to fetch rating history for zhuoxingmu. Status code: 503
# Failed to fetch rating history for shibohan. Status code: 503
# Failed to fetch rating history for KiFaH_HeLaL. Status code: 503
# MagentaCobra did not cross the rating margin within the specified range.
# Failed to fetch rating history for cqbz_xsh. Status code: 503
# Failed to fetch rating history for owoovo.shih. Status code: 503
# ventilator13 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Mohamed-Arous. Status code: 503
# Failed to fetch rating history for dorulean. Status code: 503
# minhnguyenxuan60 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Ayalla. Status code: 503
# Failed to fetch rating history for Krypto_Ray. Status code: 503
# Loging did not cross the rating margin within the specified range.
# Failed to fetch rating history for gyouzasushi. Status code: 503
# henry_y did not cross the rating margin within the specified range.
# Failed to fetch rating history for jwkim0108. Status code: 503
# Failed to fetch rating history for sycqwq. Status code: 503
# Failed to fetch rating history for Ricky2021. Status code: 503
# hehepig did not cross the rating margin within the specified range.
# jpetrovcic did not cross the rating margin within the specified range.
# Failed to fetch rating history for rajchd_11. Status code: 503
# Failed to fetch rating history for N_eB. Status code: 503
# Failed to fetch rating history for joylintp. Status code: 503
# Failed to fetch rating history for tRoehr. Status code: 503
# Failed to fetch rating history for FLself. Status code: 503
# Failed to fetch rating history for SyruLoveNewTechnology. Status code: 503
# Wibo did not cross the rating margin within the specified range.
# Restricted did not cross the rating margin within the specified range.
# dranjohn did not cross the rating margin within the specified range.
# Failed to fetch rating history for amokrousov. Status code: 503
# 3z_sky did not cross the rating margin within the specified range.
# Chelovek9 did not cross the rating margin within the specified range.
# Failed to fetch rating history for MaxVerstappen1. Status code: 503
# Failed to fetch rating history for ljr1234. Status code: 503
# Failed to fetch rating history for ExplodingFreeze. Status code: 503
# Uagu did not cross the rating margin within the specified range.
# Failed to fetch rating history for andreyDagger. Status code: 503
# Failed to fetch rating history for Andy_Lin. Status code: 503
# Failed to fetch rating history for MatheusAB. Status code: 503
# s-lissov did not cross the rating margin within the specified range.
# Failed to fetch rating history for xhytom. Status code: 503
# NickH did not cross the rating margin within the specified range.
# Failed to fetch rating history for Ryshi. Status code: 503
# Failed to fetch rating history for Mohamed308. Status code: 503
# Failed to fetch rating history for byunjaewoo. Status code: 503
# Failed to fetch rating history for ChenTianxing. Status code: 503
# Failed to fetch rating history for V4V. Status code: 503
# gigabuffoon did not cross the rating margin within the specified range.
# Failed to fetch rating history for lovely-ckj. Status code: 503
# Failed to fetch rating history for zuno. Status code: 503
# Ami_Nafi did not cross the rating margin within the specified range.
# Failed to fetch rating history for FantasyNumber. Status code: 503
# Failed to fetch rating history for dimash1. Status code: 503
# dyxx did not cross the rating margin within the specified range.
# Failed to fetch rating history for haze. Status code: 503
# kissgergely did not cross the rating margin within the specified range.
# Failed to fetch rating history for NO_SAD. Status code: 503
# muhammadhasan01 did not cross the rating margin within the specified range.
# Failed to fetch rating history for ssjie. Status code: 503
# Failed to fetch rating history for SalihSahin. Status code: 503
# Soultaker did not cross the rating margin within the specified range.
# Failed to fetch rating history for Khronos_. Status code: 503
# Failed to fetch rating history for Bedoo. Status code: 503
# Failed to fetch rating history for Profect. Status code: 503
# Failed to fetch rating history for cajolery. Status code: 503
# Failed to fetch rating history for qpwoeirut. Status code: 503
# Failed to fetch rating history for ETO_leader. Status code: 503
# Failed to fetch rating history for JKF_ZZ. Status code: 503
# Linqi05 did not cross the rating margin within the specified range.
# Failed to fetch rating history for MysticPanda. Status code: 503
# Failed to fetch rating history for xx001. Status code: 503
# LGXXGL did not cross the rating margin within the specified range.
# Failed to fetch rating history for NightSky. Status code: 503
# gansixeneh did not cross the rating margin within the specified range.
# gcfer did not cross the rating margin within the specified range.
# Failed to fetch rating history for little_tomato. Status code: 503
# pmt2018 did not cross the rating margin within the specified range.
# Failed to fetch rating history for 113113113aaasssddd. Status code: 503
# Wandoka did not cross the rating margin within the specified range.
# Russian_Pank did not cross the rating margin within the specified range.
# Failed to fetch rating history for brenner1. Status code: 503
# Failed to fetch rating history for Ivan_len. Status code: 503
# Failed to fetch rating history for apostoldaniel854. Status code: 503
# Failed to fetch rating history for Mantra7. Status code: 503
# Failed to fetch rating history for Citnaris. Status code: 503
# ahshafi did not cross the rating margin within the specified range.
# Failed to fetch rating history for GoFullRetard. Status code: 503
# Happy_New_2023 did not cross the rating margin within the specified range.
# cxzxslh did not cross the rating margin within the specified range.
# Failed to fetch rating history for pluie. Status code: 503
# Failed to fetch rating history for DaniraSilla. Status code: 503
# TheQuantiX did not cross the rating margin within the specified range.
# Failed to fetch rating history for handy.rose. Status code: 503
# Failed to fetch rating history for LinkWish. Status code: 503
# Failed to fetch rating history for Ryougi-Shiki. Status code: 503
# jahangard did not cross the rating margin within the specified range.
# Failed to fetch rating history for NewLul. Status code: 503
# shiro53 did not cross the rating margin within the specified range.
# Failed to fetch rating history for AliFarhat. Status code: 503
# Failed to fetch rating history for Kyooooma. Status code: 503
# Failed to fetch rating history for VaibhavAg31. Status code: 503
# Failed to fetch rating history for graph1te. Status code: 503
# lunw1024 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Arturo. Status code: 503
# SUN.LOVE did not cross the rating margin within the specified range.
# Failed to fetch rating history for _Magallan. Status code: 503
# tikhon_grinev did not cross the rating margin within the specified range.
# Failed to fetch rating history for aaa12321. Status code: 503
# yamake did not cross the rating margin within the specified range.
# Failed to fetch rating history for 9.86960440109. Status code: 503
# Failed to fetch rating history for ARegularCoder. Status code: 503
# Failed to fetch rating history for WRKWRK. Status code: 503
# Failed to fetch rating history for EnBiiii. Status code: 503
# Failed to fetch rating history for mathdude42. Status code: 503
# Failed to fetch rating history for SunsetGlow95. Status code: 503
# Failed to fetch rating history for Xumy. Status code: 503
# RakibJoy did not cross the rating margin within the specified range.
# Failed to fetch rating history for Samadeol. Status code: 503
# Failed to fetch rating history for AdiAnand. Status code: 503
# Failed to fetch rating history for Kblp_COCu4kA. Status code: 503
# wilson_ did not cross the rating margin within the specified range.
# Failed to fetch rating history for jianq1y. Status code: 503
# martins did not cross the rating margin within the specified range.
# Mateo did not cross the rating margin within the specified range.
# Failed to fetch rating history for dark__moon. Status code: 503
# Failed to fetch rating history for BRUHHHHHHH. Status code: 503
# Failed to fetch rating history for crpQwQ. Status code: 503
# Failed to fetch rating history for zp7CFbot1. Status code: 503
# Failed to fetch rating history for zyhhelen. Status code: 503
# Failed to fetch rating history for marcOS. Status code: 503
# Failed to fetch rating history for sss. Status code: 503
# Failed to fetch rating history for Arsa. Status code: 503
# Failed to fetch rating history for balakrishnan. Status code: 503
# Failed to fetch rating history for yowai. Status code: 503
# Failed to fetch rating history for Hanghang007. Status code: 503
# Imenkey did not cross the rating margin within the specified range.
# Failed to fetch rating history for NourElleithy. Status code: 503
# Failed to fetch rating history for huyhau6a2. Status code: 503
# Failed to fetch rating history for GusFring. Status code: 503
# Failed to fetch rating history for Xun_Xiaoyao. Status code: 503
# Failed to fetch rating history for zezoo050. Status code: 503
# Failed to fetch rating history for dlwocks31. Status code: 503
# amir7777 did not cross the rating margin within the specified range.
# Riqirez did not cross the rating margin within the specified range.
# Failed to fetch rating history for Schi2oid. Status code: 503
# Failed to fetch rating history for ppps. Status code: 503
# Failed to fetch rating history for Rinors. Status code: 503
# Failed to fetch rating history for canonica1. Status code: 503
# Failed to fetch rating history for PC_E1052. Status code: 503
# Failed to fetch rating history for WritingEve. Status code: 503
# Failed to fetch rating history for qdryx. Status code: 503
# Failed to fetch rating history for ShayanSh. Status code: 503
# Failed to fetch rating history for still_me. Status code: 503
# Failed to fetch rating history for Cai_Guang. Status code: 503
# Handsome2004 did not cross the rating margin within the specified range.
# Failed to fetch rating history for amirhozaifa. Status code: 503
# carryup did not cross the rating margin within the specified range.
# fanfly did not cross the rating margin within the specified range.
# huangxuanao did not cross the rating margin within the specified range.
# Failed to fetch rating history for qq11123334. Status code: 503
# Failed to fetch rating history for sergejgraf. Status code: 503
# ace-in-the-hole did not cross the rating margin within the specified range.
# Failed to fetch rating history for kigash. Status code: 503
# Failed to fetch rating history for FlyBell. Status code: 503
# Failed to fetch rating history for Homura_jar. Status code: 503
# Failed to fetch rating history for Piokemon. Status code: 503
# the_cow did not cross the rating margin within the specified range.
# veleboks did not cross the rating margin within the specified range.
# Failed to fetch rating history for monkeyswithmoney. Status code: 503
# nice_doggos did not cross the rating margin within the specified range.
# HEXU234 did not cross the rating margin within the specified range.
# Failed to fetch rating history for sinsop90. Status code: 503
# NatInTheHat did not cross the rating margin within the specified range.
# Failed to fetch rating history for odneitiwta. Status code: 503
# stefanbalaz2 did not cross the rating margin within the specified range.
# Dremix10 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Mindeveloped. Status code: 503
# Failed to fetch rating history for Peanut.Tang. Status code: 503
# Failed to fetch rating history for hcng. Status code: 503
# lfw did not cross the rating margin within the specified range.
# Failed to fetch rating history for mal37. Status code: 503
# solver11 did not cross the rating margin within the specified range.
# Failed to fetch rating history for xxcdsgyes. Status code: 503
# Georgiy1108 did not cross the rating margin within the specified range.
# Failed to fetch rating history for Moomins. Status code: 503
# Failed to fetch rating history for deptrai2k7. Status code: 503
# Failed to fetch rating history for gmr. Status code: 503
# Failed to fetch rating history for greenhand.n. Status code: 503
# MuhammadHassan did not cross the rating margin within the specified range.
# Failed to fetch rating history for Romy67. Status code: 503
# Failed to fetch rating history for TLEtoAC2001. Status code: 503
# Failed to fetch rating history for AAK. Status code: 503
# NotaKoala did not cross the rating margin within the specified range.
# Zain did not cross the rating margin within the specified range.
# Failed to fetch rating history for aytony. Status code: 503
# Failed to fetch rating history for mcbanana. Status code: 503
# Failed to fetch rating history for southcaribou. Status code: 503
# Failed to fetch rating history for UIT.NguyenThaiSon. Status code: 503
# Failed to fetch rating history for wwlw. Status code: 503
# JoseSoto did not cross the rating margin within the specified range.
# gauss2718281 did not cross the rating margin within the specified range.
# Failed to fetch rating history for richard_bachman. Status code: 503
# Failed to fetch rating history for Edu175. Status code: 503
# Failed to fetch rating history for Lazy1_. Status code: 503
# Sorin1932 did not cross the rating margin within the specified range.
# Failed to fetch rating history for coder_supreme. Status code: 503
# kumakumaaaaa did not cross the rating margin within the specified range.
# Failed to fetch rating history for 1L1YA. Status code: 503
# DarLam did not cross the rating margin within the specified range.
# Failed to fetch rating history for MateiKing80. Status code: 503
# Failed to fetch rating history for Saquariu. Status code: 503
# flowwolf did not cross the rating margin within the specified range.
# kulmak41 did not cross the rating margin within the specified range.
# Failed to fetch rating history for little_young. Status code: 503
# Failed to fetch rating history for syk070531. Status code: 503
# Failed to fetch rating history for Mohammad.gholamzade. Status code: 503
#                   Handle  Max Rating Result
# 0              szbszbszb        2171    N/A
# 1                ArtAlex        2349     No
# 2             cpbeginner        2114    Yes
# 3               markysha        2320    N/A
# 4                sia1024        2059     No
# ..                   ...         ...    ...
# 495  Mohammad.gholamzade        1993    N/A
# 496              Mr..Bot        1964    Yes
# 497   TravellingSalesman        2080     No
# 498                fexla        2050     No
# 499           mymelochan        1922     No
#
# [500 rows x 3 columns]

# %%
df.head()
# Out:
#        Handle  Max Rating Result
# 0   szbszbszb        2171    N/A
# 1     ArtAlex        2349     No
# 2  cpbeginner        2114    Yes
# 3    markysha        2320    N/A
# 4     sia1024        2059     No

# %%
df.to_csv('outdf4.csv', index=False)
